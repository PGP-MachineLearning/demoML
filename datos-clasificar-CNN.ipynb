# %% [markdown]
# # Demo Convolutional Neural Network (CNN) para identificar clases
# Adaptado de https://www.tensorflow.org/tutorials/estimator/premade

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, BatchNormalization 
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.layers import Reshape, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

import os
import csv

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Cargar los datos:

# %%
# monta Google Drive:
# Nota: la primera vez se debe confirmar el uso logueandose en "Google Drive File Stream" y obteniendo código de autentificación.
from google.colab import drive
drive.mount('/content/gdrive')

# directorio local en Google Drive
path = '/content/gdrive/My Drive/IA/demoML/datos/'  #@param {type:"string"}
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
## selección de los parámetros 

def cargarNombreClases(path, archivo_datos, atributo_clase, nombre_clases):
  # importa definición de la clase
  arClasesFN = archivo_datos.split('.')[0] + '_nombreClases.txt'
  if os.path.isfile( path + '/' + arClasesFN ):
    with open( path + '/' + arClasesFN, mode='r') as csvfile:
        r = csv.reader(csvfile, delimiter=',')
        auxAtributo = r.__next__()
        auxClases = r.__next__()
    print('\n> Definición de los valores discretos para la clase cargada de ' + arClasesFN +'.\n')
    return auxAtributo[0], ','.join(auxClases)
  else:
    return atributo_clase, nombre_clases


#@markdown ### Archivo de datos a utilizar:
archivo_datos = 'IRIS.csv'  #@param {type:"string"}
#@markdown ### Nombre del atributo clase / objetivo:
atributo_clase = '-' #@param {type:"string"}
#@markdown ### Descripción de los valores del atributo clase / objetivo:  (nota: siempre debe comienzar en 0, por lo que si no tiene valor 0, agregar "na")
nombre_clases = '-' #@param {type:"string"}
#@markdown ### Porcentaje de datos para usar en el entrenamiento:
proporcion_porcentaje_datos_entrenamiento =   70#@param {type:"integer"}

## aplicación de los parámetros elegidos

if atributo_clase == '' or  atributo_clase == '-':
  # trata de obtener la configuración del archivo asociado
  atributo_clase, nombre_clases = cargarNombreClases(path, archivo_datos, atributo_clase, nombre_clases)

# define nombre atributo de CLASE para ejemplo IRIS
ClassAttributeName = atributo_clase

# define valores de clases para ejemplo IRIS
CLASES = [ ]
for val in nombre_clases.split(','):
  CLASES.append( val )

# determina la proporción a usar para entrenar y probar
if proporcion_porcentaje_datos_entrenamiento>100:
  propTrain = 1
elif proporcion_porcentaje_datos_entrenamiento<1:
  propTrain = 0.1
else:
  propTrain = proporcion_porcentaje_datos_entrenamiento/100

print("Configuración definida de ", archivo_datos)
print("Atributo clase: ", ClassAttributeName, ": ", CLASES)
# Out:
# > Definición de los valores discretos para la clase cargada de IRIS_nombreClases.txt.
#
# Configuración definida de  IRIS.csv
# Atributo clase:  Clase :  ['na', 'Setosa', 'Versicolor', 'Virginica']

# %%
#@title Cargar datos

# configura para que muestre todas las columnas y filas
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# Carga los datos del CSV y muestra los primeros
df = pd.read_csv(path + archivo_datos)
print("\n> Cabecera: ")
print(df.head())
print("\n> Características: ")
print(df.describe())

# genera los datos solo con la clase para entrenar y probar
Y = np.array(df.pop(ClassAttributeName))
X = np.array(df)
# Out:
# > Cabecera:
#    LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo  Clase
# 0          5.1          3.5          1.4          0.2      1
# 1          4.9          3.0          1.4          0.2      1
# 2          4.7          3.2          1.3          0.2      1
# 3          4.6          3.1          1.5          0.2      1
# 4          5.0          3.6          1.4          0.2      1
#
# > Características:
#        LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo       Clase
# count   150.000000   150.000000   150.000000   150.000000  150.000000
# mean      5.843333     3.054000     3.758667     1.198667    2.000000
# std       0.828066     0.433594     1.764420     0.763161    0.819232
# min       4.300000     2.000000     1.000000     0.100000    1.000000
# 25%       5.100000     2.800000     1.600000     0.300000    1.000000
# 50%       5.800000     3.000000     4.350000     1.300000    2.000000
# 75%       6.400000     3.300000     5.100000     1.800000    3.000000
# max       7.900000     4.400000     6.900000     2.500000    3.000000

# %%
#@title Normalizar datos de entrada (opcional)

aplica_normalizacion = False #@param {type:"boolean"}
#@markdown Si se aplica, seleccione el tipo de método de normalización a aplicar:
tipo_normalizacion = "Standard Scaler" #@param ["Standard Scaler", "MinMax Scaler", "MaxAbs Scaler", "Robust Scaler"]

if aplica_normalizacion:

  print("10 primeros datos de Entrada antes de normalizar: ")
  print(X[:10])

  from sklearn import preprocessing

  # elegir el método de normalización
  if tipo_normalizacion == "Standard Scaler": 
    scaler = preprocessing.StandardScaler()
  elif tipo_normalizacion == "MinMax Scaler": 
    scaler = preprocessing.MinMaxScaler()
  elif tipo_normalizacion == "MaxMax Scaler": 
    scaler = preprocessing.MaxAbsScaler()
  elif tipo_normalizacion == "Robust Scaler": 
    scaler = preprocessing.RobustScaler()
  
  # normaliza los datos de entrada
  X = scaler.fit_transform(X)

  print("\n\n10 primeros datos de Entrada después de normalizar: ")
  print(X[:10])

# %%
#@title Preparar datos

# separa al azar usando muestreo estratificado con proporción indicada
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=(1-propTrain), stratify=Y)

# genera salida codificada para softMax
y_trainEnc =  np_utils.to_categorical(y_train)
y_testEnc =  np_utils.to_categorical(y_test)

# muestra resultados
print("> Para Ambos: ")
print(" - dictMapeo: ", CLASES)

print("\n> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
print(" - y_train (cant): ", len(y_train))
for i in range(len(CLASES)):
  cant = 0
  for y in y_train:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)

print("\n Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
print(" - y_test (cant): ", len(y_test))
for i in range(len(CLASES)):
  cant = 0
  for y in y_test:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)
# Out:
# > Para Ambos:
#  - dictMapeo:  ['na', 'Setosa', 'Versicolor', 'Virginica']
#
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (104, 4)
#  - y_train (cant):  104
#      na [ 0 ]: 0
#      Setosa [ 1 ]: 35
#      Versicolor [ 2 ]: 35
#      Virginica [ 3 ]: 34
#
#  Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (46, 4)
#  - y_test (cant):  46
#      na [ 0 ]: 0
#      Setosa [ 1 ]: 15
#      Versicolor [ 2 ]: 15
#      Virginica [ 3 ]: 16

# %%
#@title Preparar datos - convertir a matriz
cols = x_train.shape[1]

if (cols%2)==0:
  matrixShape = [2,(cols//2)]
else:
  matrixShape = [3,(cols//3)]
print("\n Forma de la matriz: ", matrixShape)

matrixTrain = []
matrixTest = []

# cambia la forma de la matriz
matrixTrain = x_train.reshape((len(x_train), matrixShape[0], matrixShape[1]))  
matrixTest = x_test.reshape((len(x_test), matrixShape[0], matrixShape[1]))  

print("\n Datos de entrada convertidos matriz: ")
print(" - matrixTrain (cant ejemplos, forma): ", matrixTrain.shape)
print(" - matrixTest (cant ejemplos, forma): ", matrixTest.shape)
# Out:
#  Forma de la matriz:  [2, 2]
#
#  Datos de entrada convertidos matriz:
#  - matrixTrain (cant ejemplos, forma):  (104, 2, 2)
#  - matrixTest (cant ejemplos, forma):  (46, 2, 2)

# %% [markdown]
# 3) Establecer el modelo para la RNA

# %%
#@markdown ### Parámetros de la red:
cnn_tamaño_kernel = 2 #@param {type:"integer"}
cnn_tamaño_pooling = 2 #@param {type:"integer"}
cnn_cantidad_capas_ocultas = 3 #@param {type:"integer"}
cnn_agregar_capa_BatchNormalization = True #@param {type:"boolean"}
cnn_cantidad_neuronas_Dense = 16 #@param {type:"integer"}
cnn_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]
cnn_cant_epocas_entrenamiento = 350 #@param {type:"integer"}

## aplicación de los parámetros elegidos

# tamaño de los kernels y pooling (para simplificar son todas iguales)
if cnn_tamaño_kernel<1:
  cnn_tamaño_kernel = 1
cnn_kernel_shape = (cnn_tamaño_kernel)
if cnn_tamaño_pooling<1:
  cnn_tamaño_pooling=1
cnn_pooling_shape = (cnn_tamaño_pooling)

# indica la configuración para la parte Encoder 
#   (cada elemento de las listas son la configuración de las capas Conv)
if cnn_cantidad_capas_ocultas<1:
  cnn_cantidad_capas_ocultas = 1
cnn_filters = []
for i in range(cnn_cantidad_capas_ocultas, 0, -1):
  cnn_filters.append( 2**(i+2) )

# define tamaño de capa densa previa a la de salida
num_Dense_out = (8 if cnn_cantidad_neuronas_Dense<1 else cnn_cantidad_neuronas_Dense)

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (cnn_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if cnn_cant_epocas_entrenamiento<1 else cnn_cant_epocas_entrenamiento)

print("Configuración de la CNN definida: ")
print ("     -Kernels + Pooling: [", cnn_kernel_shape, "+", cnn_pooling_shape, "] ")
print ("     -Capas: [ ", matrixShape, ", Conv", cnn_filters, (", BatchNormalization" if  cnn_agregar_capa_BatchNormalization else "" ), ", FLATTEN, Dense[", num_Dense_out, "], ", ("Softmax" if tipo_output_softMax else "Dense[1] "))
# Out:
# Configuración de la CNN definida:
#      -Kernels + Pooling: [ 2 + 2 ]
#      -Capas: [  [2, 2] , Conv [32, 16, 8] , BatchNormalization , FLATTEN, Dense[ 16 ],  Softmax

# %%
#@title Establecer modelo

# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=((matrixShape[0], matrixShape[1])), name='input') # capa de entrada
eachLay = input_img_Lay
auxId = 1 
for i in range(len(cnn_filters)):  
       
    # define el nombre de la capa oculta
    auxlayerName = 'conv_'+str(auxId)
    auxId = auxId + 1

    # agrega las capas ocultas de tipo Conv2D + MaxPooling 
    eachLay = Conv1D(cnn_filters[i], cnn_kernel_shape, activation='relu', padding='same', name='c_'+auxlayerName)(eachLay) 
    eachLay = MaxPooling1D(cnn_pooling_shape, padding='same', name='p_'+auxlayerName)(eachLay)


if cnn_agregar_capa_BatchNormalization:
  # nota: para convNet no se usa DropOut, conviene usar BatchNormalization
  eachLay = BatchNormalization(name='bn')(eachLay)

#  agrega capa Flatten y Dense 
eachLay = Flatten(name='flat_'+auxlayerName)(eachLay)
eachLay = Dense(num_Dense_out, activation='relu', name='d_'+auxlayerName)(eachLay)

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(CLASES), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
#model.compile(optimizer='rmsprop', loss='mse', metrics=['accuracy'])
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  11  capas:
# Model: "RNA"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 2, 2)]            0
#
#  c_conv_1 (Conv1D)           (None, 2, 32)             160
#
#  p_conv_1 (MaxPooling1D)     (None, 1, 32)             0
#
#  c_conv_2 (Conv1D)           (None, 1, 16)             1040
#
#  p_conv_2 (MaxPooling1D)     (None, 1, 16)             0
#
#  c_conv_3 (Conv1D)           (None, 1, 8)              264
#
#  p_conv_3 (MaxPooling1D)     (None, 1, 8)              0
#
#  bn (BatchNormalization)     (None, 1, 8)              32
#
#  flat_conv_3 (Flatten)       (None, 8)                 0
#
#  d_conv_3 (Dense)            (None, 16)                144
#
#  output (Dense)              (None, 4)                 68
#
# =================================================================
# Total params: 1,708
# Trainable params: 1,692
# Non-trainable params: 16
# _________________________________________________________________

# %% [markdown]
# 4) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(matrixTrain, 
                                       (y_trainEnc if tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,) ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  104 ejemplos de entrenamiento:
#             se usan  93 ejemplos para entrenar
#             y  11 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/350
# 3/3 [==============================] - 3s 286ms/step - loss: 1.4398 - accuracy: 0.1720 - val_loss: 1.3405 - val_accuracy: 0.4545
# Epoch 2/350
# 3/3 [==============================] - 0s 41ms/step - loss: 1.3354 - accuracy: 0.2258 - val_loss: 1.3440 - val_accuracy: 0.4545
# Epoch 3/350
# 3/3 [==============================] - 0s 24ms/step - loss: 1.2962 - accuracy: 0.3011 - val_loss: 1.3494 - val_accuracy: 0.4545
# Epoch 4/350
# 3/3 [==============================] - 0s 21ms/step - loss: 1.2516 - accuracy: 0.3441 - val_loss: 1.3532 - val_accuracy: 0.4545
# Epoch 5/350
# 3/3 [==============================] - 0s 62ms/step - loss: 1.2077 - accuracy: 0.3656 - val_loss: 1.3440 - val_accuracy: 0.4545
# Epoch 6/350
# 3/3 [==============================] - 0s 47ms/step - loss: 1.1622 - accuracy: 0.4086 - val_loss: 1.3300 - val_accuracy: 0.4545
# Epoch 7/350
# 3/3 [==============================] - 0s 40ms/step - loss: 1.1267 - accuracy: 0.6237 - val_loss: 1.3185 - val_accuracy: 0.4545
# Epoch 8/350
# 3/3 [==============================] - 0s 31ms/step - loss: 1.0975 - accuracy: 0.6129 - val_loss: 1.3110 - val_accuracy: 0.4545
# Epoch 9/350
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0663 - accuracy: 0.6559 - val_loss: 1.3056 - val_accuracy: 0.4545
# Epoch 10/350
# 3/3 [==============================] - 0s 42ms/step - loss: 1.0346 - accuracy: 0.7204 - val_loss: 1.2976 - val_accuracy: 0.4545
# Epoch 11/350
# 3/3 [==============================] - 0s 28ms/step - loss: 1.0035 - accuracy: 0.7312 - val_loss: 1.2878 - val_accuracy: 0.7273
# Epoch 12/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.9746 - accuracy: 0.7204 - val_loss: 1.2789 - val_accuracy: 0.8182
# Epoch 13/350
# 3/3 [==============================] - 0s 24ms/step - loss: 0.9438 - accuracy: 0.7312 - val_loss: 1.2712 - val_accuracy: 0.8182
# Epoch 14/350
# 3/3 [==============================] - 0s 30ms/step - loss: 0.9260 - accuracy: 0.7634 - val_loss: 1.2652 - val_accuracy: 0.8182
# Epoch 15/350
# 3/3 [==============================] - 0s 36ms/step - loss: 0.8948 - accuracy: 0.7957 - val_loss: 1.2583 - val_accuracy: 0.8182
# Epoch 16/350
# 3/3 [==============================] - 0s 32ms/step - loss: 0.8753 - accuracy: 0.7849 - val_loss: 1.2482 - val_accuracy: 0.8182
# Epoch 17/350
# 3/3 [==============================] - 0s 25ms/step - loss: 0.8471 - accuracy: 0.7849 - val_loss: 1.2364 - val_accuracy: 0.8182
# Epoch 18/350
# 3/3 [==============================] - 0s 24ms/step - loss: 0.8245 - accuracy: 0.7849 - val_loss: 1.2248 - val_accuracy: 0.8182
# Epoch 19/350
# 3/3 [==============================] - 0s 31ms/step - loss: 0.
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0393 - accuracy: 0.9892 - val_loss: 0.2209 - val_accuracy: 0.9091
# Epoch 163/350
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.1820 - val_accuracy: 0.9091
# Epoch 164/350
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0384 - accuracy: 0.9892 - val_loss: 0.1432 - val_accuracy: 0.9091
# Epoch 165/350
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9091
# Epoch 166/350
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0380 - accuracy: 0.9892 - val_loss: 0.1551 - val_accuracy: 0.9091
# Epoch 167/350
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0398 - accuracy: 0.9892 - val_loss: 0.1651 - val_accuracy: 0.9091
# Epoch 168/350
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0332 - accuracy: 0.9892 - val_loss: 0.1847 - val_accuracy: 0.9091
# Epoch 169/350
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0546 - accuracy: 0.9785 - val_loss: 0.2217 - val_accuracy: 0.9091
# Epoch 170/350
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0344 - accuracy: 0.9892 - val_loss: 0.3293 - val_accuracy: 0.9091
# Epoch 171/350
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0326 - accuracy: 0.9892 - val_loss: 0.2462 - val_accuracy: 0.9091
# Epoch 172/350
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0480 - accuracy: 0.9785 - val_loss: 0.1740 - val_accuracy: 0.9091
# Epoch 173/350
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0502 - accuracy: 0.9785 - val_loss: 0.1536 - val_accuracy: 0.9091
# Epoch 174/350
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0432 - accuracy: 0.9785 - val_loss: 0.3353 - val_accuracy: 0.9091
# Epoch 175/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0336 - accuracy: 1.0000 - val_loss: 0.3345 - val_accuracy: 0.9091
# Epoch 176/350
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0312 - accuracy: 0.9892 - val_loss: 0.1671 - val_accuracy: 0.9091
# Epoch 177/350
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0395 - accuracy: 0.9892 - val_loss: 0.0851 - val_accuracy: 0.9091
# Epoch 178/350
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0391 - accuracy: 0.9892 - val_loss: 0.0817 - val_accuracy: 1.0000
# Epoch 179/350
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9091
# Epoch 180/350
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0323 - accuracy: 0.9892 - val_loss: 0.1922 - val_accuracy: 0.9091
# Epoch 181/350
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0293 - accuracy: 0.9892 - val_loss: 0.1944 - val_accuracy: 0.9091
# Epoch 182/350
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0413 - accuracy: 0.9892 - val_loss: 0.1969 - val_accuracy: 0.9091
# Epoch 183/350
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0444 - accuracy: 0.9892 - val_loss: 0.0729 - val_accuracy: 1.0000
# Epoch 184/350
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 1.0000
# Epoch 185/350
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0505 - accuracy: 0.9785 - val_loss: 0.0517 - val_accuracy: 1.0000
# Epoch 186/350
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9091
# Epoch 187/350
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0304 - accuracy: 0.9892 - val_loss: 0.1154 - val_accuracy: 0.9091
# Epoch 188/350
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.1059 - val_accuracy: 0.9091
# Epoch 189/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0413 - accuracy: 0.9892 - val_loss: 0.0588 - val_accuracy: 1.0000
# Epoch 190/350
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0383 - accuracy: 0.9892 - val_loss: 0.0592 - val_accuracy: 1.0000
# Epoch 191/350
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0358 - accuracy: 0.9892 - val_loss: 0.1237 - val_accuracy: 0.9091
# Epoch 192/350
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.2169 - val_accuracy: 0.9091
# Epoch 193/350
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0394 - accuracy: 0.9892 - val_loss: 0.2579 - val_accuracy: 0.9091
# Epoch 194/350
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0619 - accuracy: 0.9677 - val_loss: 0.0975 - val_accuracy: 0.9091
# Epoch 195/350
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0466 - accuracy: 0.9785 - val_loss: 0.0982 - val_accuracy: 0.9091
# Epoch 196/350
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0361 - accuracy: 0.9892 - val_loss: 0.0812 - val_accuracy: 0.9091
# Epoch 197/350
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0289 - accuracy: 0.9892 - val_loss: 0.0845 - val_accuracy: 0.9091
# Epoch 198/350
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 0.0992 - val_accuracy: 0.9091
# Epoch 199/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0281 - accuracy: 0.9892 - val_loss: 0.1036 - val_accuracy: 0.9091
# Epoch 200/350
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0382 - accuracy: 0.9785 - val_loss: 0.0590 - val_accuracy: 1.0000
# Epoch 201/350
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0334 - accuracy: 0.9785 - val_loss: 0.0452 - val_accuracy: 1.0000
# Epoch 202/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0288 - accuracy: 0.9892 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 203/350
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0310 - accuracy: 0.9892 - val_loss: 0.0525 - val_accuracy: 1.0000
# Epoch 204/350
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0327 - accuracy: 0.9892 - val_loss: 0.0835 - val_accuracy: 0.9091
# Epoch 205/350
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9091
# Epoch 206/350
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0420 - accuracy: 0.9892 - val_loss: 0.1367 - val_accuracy: 0.9091
# Epoch 207/350
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0344 - accuracy: 0.9892 - val_loss: 0.0914 - val_accuracy: 0.9091
# Epoch 208/350
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0303 - accuracy: 0.9892 - val_loss: 0.0792 - val_accuracy: 0.9091
# Epoch 209/350
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 1.0000
# Epoch 210/350
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0349 - accuracy: 0.9892 - val_loss: 0.1411 - val_accuracy: 0.9091
# Epoch 211/350
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0251 - accuracy: 0.9892 - val_loss: 0.1992 - val_accuracy: 0.9091
# Epoch 212/350
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0477 - accuracy: 0.9785 - val_loss: 0.1856 - val_accuracy: 0.9091
# Epoch 213/350
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0258 - accuracy: 0.9892 - val_loss: 0.2835 - val_accuracy: 0.9091
# Epoch 214/350
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.2437 - val_accuracy: 0.9091
# Epoch 215/350
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9091
# Epoch 216/350
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0251 - accuracy: 0.9892 - val_loss: 0.1540 - val_accuracy: 0.9091
# Epoch 217/350
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9091
# Epoch 218/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0666 - accuracy: 0.9677 - val_loss: 0.1108 - val_accuracy: 0.9091
# Epoch 219/350
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0244 - accuracy: 0.9892 - val_loss: 0.1676 - val_accuracy: 0.9091
# Epoch 220/350
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 0.2449 - val_accuracy: 0.9091
# Epoch 221/350
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0379 - accuracy: 0.9892 - val_loss: 0.1174 - val_accuracy: 0.9091
# Epoch 222/350
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0270 - accuracy: 0.9892 - val_loss: 0.0759 - val_accuracy: 0.9091
# Epoch 223/350
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.1730 - val_accuracy: 0.9091
# Epoch 224/350
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0228 - accuracy: 0.9892 - val_loss: 0.1856 - val_accuracy: 0.9091
# Epoch 225/350
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0257 - accuracy: 0.9892 - val_loss: 0.1937 - val_accuracy: 0.9091
# Epoch 226/350
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0367 - accuracy: 0.9785 - val_loss: 0.2528 - val_accuracy: 0.9091
# Epoch 227/350
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0413 - accuracy: 0.9785 - val_loss: 0.3598 - val_accuracy: 0.9091
# Epoch 228/350
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 0.3005 - val_accuracy: 0.9091
# Epoch 229/350
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.2858 - val_accuracy: 0.9091
# Epoch 230/350
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.1815 - val_accuracy: 0.9091
# Epoch 231/350
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 1.0000
# Epoch 232/350
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0487 - accuracy: 0.9785 - val_loss: 0.0554 - val_accuracy: 1.0000
# Epoch 233/350
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0346 - accuracy: 0.9785 - val_loss: 0.1185 - val_accuracy: 0.9091
# Epoch 234/350
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0283 - accuracy: 0.9785 - val_loss: 0.0852 - val_accuracy: 0.9091
# Epoch 235/350
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.0722 - val_accuracy: 0.9091
# Epoch 236/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 1.0000
# Epoch 237/350
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0524 - accuracy: 0.9785 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 238/350
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.1818 - val_accuracy: 0.9091
# Epoch 239/350
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.2578 - val_accuracy: 0.9091
# Epoch 240/350
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0343 - accuracy: 0.9892 - val_loss: 0.1895 - val_accuracy: 0.9091
# Epoch 241/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0255 - accuracy: 0.9892 - val_loss: 0.0391 - val_accuracy: 1.0000
# Epoch 242/350
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0292 - accuracy: 0.9892 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 243/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0191 - accuracy: 0.9892 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 244/350
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0410 - accuracy: 0.9785 - val_loss: 0.0565 - val_accuracy: 1.0000
# Epoch 245/350
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.3376 - val_accuracy: 0.9091
# Epoch 246/350
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0361 - accuracy: 0.9892 - val_loss: 0.2342 - val_accuracy: 0.9091
# Epoch 247/350
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 1.0000
# Epoch 248/350
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0298 - accuracy: 0.9785 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 249/350
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0249 - accuracy: 0.9892 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 250/350
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0237 - accuracy: 0.9892 - val_loss: 0.0585 - val_accuracy: 1.0000
# Epoch 251/350
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0366 - accuracy: 0.9892 - val_loss: 0.1777 - val_accuracy: 0.9091
# Epoch 252/350
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0301 - accuracy: 0.9892 - val_loss: 0.0825 - val_accuracy: 0.9091
# Epoch 253/350
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 254/350
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 255/350
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 256/350
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0248 - accuracy: 0.9892 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 257/350
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0345 - accuracy: 0.9785 - val_loss: 0.0715 - val_accuracy: 0.9091
# Epoch 258/350
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.0545 - val_accuracy: 1.0000
# Epoch 259/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0203 - accuracy: 0.9892 - val_loss: 0.0343 - val_accuracy: 1.0000
# Epoch 260/350
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0197 - accuracy: 0.9892 - val_loss: 0.0227 - val_accuracy: 1.0000
# Epoch 261/350
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0277 - val_accuracy: 1.0000
# Epoch 262/350
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0423 - accuracy: 0.9892 - val_loss: 0.1511 - val_accuracy: 0.9091
# Epoch 263/350
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.1045 - val_accuracy: 0.9091
# Epoch 264/350
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 265/350
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0204 - accuracy: 0.9892 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 266/350
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 267/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0334 - accuracy: 0.9785 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 268/350
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 269/350
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 270/350
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0156 - accuracy: 0.9892 - val_loss: 0.0380 - val_accuracy: 1.0000
# Epoch 271/350
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.0865 - val_accuracy: 0.9091
# Epoch 272/350
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0195 - accuracy: 0.9892 - val_loss: 0.0696 - val_accuracy: 0.9091
# Epoch 273/350
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0241 - accuracy: 0.9892 - val_loss: 0.0352 - val_accuracy: 1.0000
# Epoch 274/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9091
# Epoch 275/350
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0191 - accuracy: 0.9892 - val_loss: 0.1365 - val_accuracy: 0.9091
# Epoch 276/350
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.1654 - val_accuracy: 0.9091
# Epoch 277/350
# 3/3 [==============================] - 0s 30ms/step - loss: 0.
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0423 - accuracy: 0.9785 - val_loss: 0.2428 - val_accuracy: 0.9091
# Epoch 326/350
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0164 - accuracy: 0.9892 - val_loss: 0.1877 - val_accuracy: 0.9091
# Epoch 327/350
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 1.0000
# Epoch 328/350
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 329/350
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0245 - accuracy: 0.9892 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 330/350
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 1.0000
# Epoch 331/350
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9091
# Epoch 332/350
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0142 - accuracy: 0.9892 - val_loss: 0.1635 - val_accuracy: 0.9091
# Epoch 333/350
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9091
# Epoch 334/350
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9091
# Epoch 335/350
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0243 - accuracy: 0.9892 - val_loss: 0.1598 - val_accuracy: 0.9091
# Epoch 336/350
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2680 - val_accuracy: 0.9091
# Epoch 337/350
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0283 - accuracy: 0.9892 - val_loss: 0.3340 - val_accuracy: 0.9091
# Epoch 338/350
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.4249 - val_accuracy: 0.9091
# Epoch 339/350
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.3989 - val_accuracy: 0.9091
# Epoch 340/350
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0234 - accuracy: 0.9892 - val_loss: 0.3414 - val_accuracy: 0.9091
# Epoch 341/350
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0239 - accuracy: 0.9892 - val_loss: 0.0875 - val_accuracy: 0.9091
# Epoch 342/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.0460 - val_accuracy: 1.0000
# Epoch 343/350
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0164 - accuracy: 0.9892 - val_loss: 0.0498 - val_accuracy: 1.0000
# Epoch 344/350
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 0.9091
# Epoch 345/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0316 - accuracy: 0.9785 - val_loss: 0.2210 - val_accuracy: 0.9091
# Epoch 346/350
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.3014 - val_accuracy: 0.9091
# Epoch 347/350
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0182 - accuracy: 0.9892 - val_loss: 0.2351 - val_accuracy: 0.9091
# Epoch 348/350
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0164 - accuracy: 0.9892 - val_loss: 0.3019 - val_accuracy: 0.9091
# Epoch 349/350
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0175 - accuracy: 0.9892 - val_loss: 0.3098 - val_accuracy: 0.9091
# Epoch 350/350
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.1603 - val_accuracy: 0.9091
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, clases_map):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # prepara salida
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA"
        else:      
            clPred = clases_map[ idclPredRnd ]

        classReal.append( clReal )
        classPreds.append( clPred )

        strTitulo = 'Real: ' + clReal + ' / RNA: ' 
        strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'   
        strTitulo = strTitulo + ": " + ("ok" if (clPred==clReal) else "error!")

        # muestra comparación con la imagen
        print(strTitulo)

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    # agrega para poder mostrar la matrix de confusión completa
    pd.options.display.max_rows = 100
    pd.options.display.max_columns = 100
    print(cmtx)
    print("\n")

    # gráfico de comparación
    plt.title('Gráfico de Confusión:')
    plt.xlabel('Real')
    plt.ylabel('RNA')
    plt.scatter(classReal, classPreds)

# prueba con los datos de entrenamiento
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(matrixTrain, y_train, CLASES)
# Out:
# *** Resultados con datos de Entrenamiento:
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Versicolor (2): error!
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Versicolor (2): error!
# Real: Versicolor / RNA: Versicolor (2): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        35
#   Versicolor       0.95      1.00      0.97        35
#    Virginica       1.00      0.94      0.97        34
#
#     accuracy                           0.98       104
#    macro avg       0.98      0.98      0.98       104
# weighted avg       0.98      0.98      0.98       104
#
#
# Matriz de Confusión:
#               p:na  p:Setosa  p:Versicolor  p:Virginica
# r:na             0         0             0            0
# r:Setosa         0        35             0            0
# r:Versicolor     0         0            35            0
# r:Virginica      0         0             2           32

# %% [markdown]
# 6) Evaluar el modelo de la RNA entrenado con los datos de prueba:

# %%
 #@title Probar red entrenada con datos de prueba
 # evalua al modelo entrenado
resEval = model.evaluate(matrixTest, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de prueba
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(matrixTest, y_test, CLASES)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1759 - accuracy: 0.9130
#
# >Evaluación del Modelo:
#     - Error:  0.17585262656211853
#     - Exactitud:  91.30434989929199
#
#
#
#
# *** Resultados con datos de Prueba:
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Versicolor (2): error!
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Virginica (3): error!
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Versicolor (2): error!
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Versicolor (2): error!
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        15
#   Versicolor       0.82      0.93      0.87        15
#    Virginica       0.93      0.81      0.87        16
#
#     accuracy                           0.91        46
#    macro avg       0.92      0.92      0.91        46
# weighted avg       0.92      0.91      0.91        46
#
#
# Matriz de Confusión:
#               p:na  p:Setosa  p:Versicolor  p:Virginica
# r:na             0         0             0            0
# r:Setosa         0        15             0            0
# r:Versicolor     0         0            14            1
# r:Virginica      0         0             3           13

# %%
#@title Inspeccionar influencia de los Atributos de Entrada
# fuente: https://scikit-learn.org/stable/modules/permutation_importance.html

from sklearn.inspection import permutation_importance
from sklearn.metrics import make_scorer

# define la función para calculo del error
# contando la cantidad de diferencias 
# entre clase real y predecida
def calc_error(realClasses, predClasses):
    res = 0
    for i in range(len(realClasses)):
      # determina la clase predecida
      if tipo_output_softMax:
          ## determina clase predecida de acuerdo a la que tiene mayor valor
          idclPred = int( np.argmax(predClasses[i], axis=0) )
          idclPredRnd = idclPred
          idReal = int( np.argmax(realClasses[i], axis=0) )
      else:
          ## determina clase predecida de acuerdo al umbral de clasificación
          idclPred = predClasses[i][0]       
          idclPredRnd = int(idclPred)
          if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(CLASES):
                  idclPredRnd = idclPredRnd + 1
          idReal = int(realClasses[i])
      res = res + abs(idReal-idclPredRnd)
    return res
errorScorer = make_scorer(calc_error, greater_is_better=False)

def realizarInspeccion(tipoDatos, xScoring, yScoring):
  print("")
  # Genera el scoring usando permutaciones 
  # para realizar el cálculo del scoring
  scoring = {'R2 score':'r2', 
             'Error de Clase':errorScorer}
  r_multi  = permutation_importance(model, xScoring, yScoring,
                              n_repeats=30,
                              random_state=0,
                              scoring=scoring)

  # muesta las métricas
  print("> Cálculo de influencia con datos de " + tipoDatos + ":")
  for metric in r_multi:
    print("- Métrica "+metric+":")
    r = r_multi[metric]
    i = 0
    for imp in r.importances:
        print(f"\tAtributo {i:<2} [ {df.columns[i]} ]:  "
              f"{np.mean(imp):.3f} ± {np.std(imp):.3f}"
              f" [ {np.min(imp):.3f}; {np.max(imp):.3f} ]"
              )
        i = i + 1
  return

# Ejecuta con ambos sets de datos
realizarInspeccion(tipoDatos="Entrenamiento",  
                  xScoring = matrixTrain,
                  yScoring = (y_trainEnc if tipo_output_softMax else y_train))

realizarInspeccion(tipoDatos="Prueba",  
                  xScoring = matrixTest,
                  yScoring = (y_testEnc if tipo_output_softMax else y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-5634d584abcc> in <module>()
#      56 realizarInspeccion(tipoDatos="Entrenamiento",
#      57                   xScoring = matrixTrain,
# ---> 58                   yScoring = (y_trainEnc if tipo_output_softMax else y_train))
#      59
#      60 realizarInspeccion(tipoDatos="Prueba",
#
# <ipython-input-14-5634d584abcc> in realizarInspeccion(tipoDatos, xScoring, yScoring)
#      37                               n_repeats=30,
#      38                               random_state=0,
# ---> 39                               scoring=scoring)
#      40
#      41   # muesta las métricas
#
# /usr/local/lib/python3.7/dist-packages/sklearn/inspection/_permutation_importance.py in permutation_importance(estimator, X, y, scoring, n_repeats, n_jobs, random_state, sample_weight, max_samples)
#     232     """
#     233     if not hasattr(X, "iloc"):
# --> 234         X = check_array(X, force_all_finite="allow-nan", dtype=None)
#     235
#     236     # Precompute random seed from the random state to be used
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     794             raise ValueError(
#     795                 "Found array with dim %d. %s expected <= 2."
# --> 796                 % (array.ndim, estimator_name)
#     797             )
#     798
#
# ValueError: Found array with dim 3. Estimator expected <= 2.
