# %% [markdown]
# # Demo Convolutional Neural Network (CNN) para identificar clases
# Adaptado de https://www.tensorflow.org/tutorials/estimator/premade

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, BatchNormalization 
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.layers import Reshape, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

import os
import csv

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Cargar los datos:

# %%
# monta Google Drive:
# Nota: la primera vez se debe confirmar el uso logueandose en "Google Drive File Stream" y obteniendo código de autentificación.
from google.colab import drive
drive.mount('/content/gdrive')

# directorio local en Google Drive
path = '/content/gdrive/My Drive/IA/demoML/datos/'  #@param {type:"string"}
# Out:
# Mounted at /content/gdrive

# %%
## selección de los parámetros 

def cargarNombreClases(path, archivo_datos, atributo_clase, nombre_clases):
  # importa definición de la clase
  arClasesFN = archivo_datos.split('.')[0] + '_nombreClases.txt'
  if os.path.isfile( path + '/' + arClasesFN ):
    with open( path + '/' + arClasesFN, mode='r') as csvfile:
        r = csv.reader(csvfile, delimiter=',')
        auxAtributo = r.__next__()
        auxClases = r.__next__()
    print('\n> Definición de los valores discretos para la clase cargada de ' + arClasesFN +'.\n')
    return auxAtributo[0], ','.join(auxClases)
  else:
    return atributo_clase, nombre_clases


#@markdown ### Archivo de datos a utilizar:
archivo_datos = 'IRIS.csv'  #@param {type:"string"}
#@markdown ### Nombre del atributo clase / objetivo:
atributo_clase = '-' #@param {type:"string"}
#@markdown ### Descripción de los valores del atributo clase / objetivo:  (nota: siempre debe comienzar en 0, por lo que si no tiene valor 0, agregar "na")
nombre_clases = '-' #@param {type:"string"}
#@markdown ### Porcentaje de datos para usar en el entrenamiento:
proporcion_porcentaje_datos_entrenamiento =   70#@param {type:"integer"}

## aplicación de los parámetros elegidos

if atributo_clase == '' or  atributo_clase == '-':
  # trata de obtener la configuración del archivo asociado
  atributo_clase, nombre_clases = cargarNombreClases(path, archivo_datos, atributo_clase, nombre_clases)

# define nombre atributo de CLASE para ejemplo IRIS
ClassAttributeName = atributo_clase

# define valores de clases para ejemplo IRIS
CLASES = [ ]
for val in nombre_clases.split(','):
  CLASES.append( val )

# determina la proporción a usar para entrenar y probar
if proporcion_porcentaje_datos_entrenamiento>100:
  propTrain = 1
elif proporcion_porcentaje_datos_entrenamiento<1:
  propTrain = 0.1
else:
  propTrain = proporcion_porcentaje_datos_entrenamiento/100

print("Configuración definida de ", archivo_datos)
print("Atributo clase: ", ClassAttributeName, ": ", CLASES)
# Out:
# > Definición de los valores discretos para la clase cargada de IRIS_nombreClases.txt.
#
# Configuración definida de  IRIS.csv
# Atributo clase:  Clase :  ['na', 'Setosa', 'Versicolor', 'Virginica']

# %%
#@title Cargar datos

# configura para que muestre todas las columnas y filas
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# Carga los datos del CSV y muestra los primeros
df = pd.read_csv(path + archivo_datos)
print("\n> Cabecera: ")
print(df.head())
print("\n> Características: ")
print(df.describe())

# genera los datos solo con la clase para entrenar y probar
Y = np.array(df.pop(ClassAttributeName))
X = np.array(df)
# Out:
# > Cabecera:
#    LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo  Clase
# 0          5.1          3.5          1.4          0.2      1
# 1          4.9          3.0          1.4          0.2      1
# 2          4.7          3.2          1.3          0.2      1
# 3          4.6          3.1          1.5          0.2      1
# 4          5.0          3.6          1.4          0.2      1
#
# > Características:
#        LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo       Clase
# count   150.000000   150.000000   150.000000   150.000000  150.000000
# mean      5.843333     3.054000     3.758667     1.198667    2.000000
# std       0.828066     0.433594     1.764420     0.763161    0.819232
# min       4.300000     2.000000     1.000000     0.100000    1.000000
# 25%       5.100000     2.800000     1.600000     0.300000    1.000000
# 50%       5.800000     3.000000     4.350000     1.300000    2.000000
# 75%       6.400000     3.300000     5.100000     1.800000    3.000000
# max       7.900000     4.400000     6.900000     2.500000    3.000000

# %%
#@title Normalizar datos de entrada (opcional)

aplica_normalizacion = False #@param {type:"boolean"}
#@markdown Si se aplica, seleccione el tipo de método de normalización a aplicar:
tipo_normalizacion = "Standard Scaler" #@param ["Standard Scaler", "MinMax Scaler", "MaxAbs Scaler", "Robust Scaler"]

if aplica_normalizacion:

  print("10 primeros datos de Entrada antes de normalizar: ")
  print(X[:10])

  from sklearn import preprocessing

  # elegir el método de normalización
  if tipo_normalizacion == "Standard Scaler": 
    scaler = preprocessing.StandardScaler()
  elif tipo_normalizacion == "MinMax Scaler": 
    scaler = preprocessing.MinMaxScaler()
  elif tipo_normalizacion == "MaxMax Scaler": 
    scaler = preprocessing.MaxAbsScaler()
  elif tipo_normalizacion == "Robust Scaler": 
    scaler = preprocessing.RobustScaler()
  
  # normaliza los datos de entrada
  X = scaler.fit_transform(X)

  print("\n\n10 primeros datos de Entrada después de normalizar: ")
  print(X[:10])

# %%
#@title Preparar datos

# separa al azar usando muestreo estratificado con proporción indicada
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=(1-propTrain), stratify=Y)

# genera salida codificada para softMax
y_trainEnc =  np_utils.to_categorical(y_train)
y_testEnc =  np_utils.to_categorical(y_test)

# muestra resultados
print("> Para Ambos: ")
print(" - dictMapeo: ", CLASES)

print("\n> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
print(" - y_train (cant): ", len(y_train))
for i in range(len(CLASES)):
  cant = 0
  for y in y_train:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)

print("\n Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
print(" - y_test (cant): ", len(y_test))
for i in range(len(CLASES)):
  cant = 0
  for y in y_test:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)
# Out:
# > Para Ambos:
#  - dictMapeo:  ['na', 'Setosa', 'Versicolor', 'Virginica']
#
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (104, 4)
#  - y_train (cant):  104
#      na [ 0 ]: 0
#      Setosa [ 1 ]: 35
#      Versicolor [ 2 ]: 35
#      Virginica [ 3 ]: 34
#
#  Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (46, 4)
#  - y_test (cant):  46
#      na [ 0 ]: 0
#      Setosa [ 1 ]: 15
#      Versicolor [ 2 ]: 15
#      Virginica [ 3 ]: 16

# %%
#@title Preparar datos - convertir a matriz
cols = x_train.shape[1]

if (cols%2)==0:
  matrixShape = [2,(cols//2)]
else:
  matrixShape = [3,(cols//3)]
print("\n Forma de la matriz: ", matrixShape)

matrixTrain = []
matrixTest = []

# cambia la forma de la matriz
matrixTrain = x_train.reshape((len(x_train), matrixShape[0], matrixShape[1]))  
matrixTest = x_test.reshape((len(x_test), matrixShape[0], matrixShape[1]))  

print("\n Datos de entrada convertidos matriz: ")
print(" - matrixTrain (cant ejemplos, forma): ", matrixTrain.shape)
print(" - matrixTest (cant ejemplos, forma): ", matrixTest.shape)
# Out:
#  Forma de la matriz:  [2, 2]
#
#  Datos de entrada convertidos matriz:
#  - matrixTrain (cant ejemplos, forma):  (104, 2, 2)
#  - matrixTest (cant ejemplos, forma):  (46, 2, 2)

# %% [markdown]
# 3) Establecer el modelo para la RNA

# %%
#@markdown ### Parámetros de la red:
cnn_tamaño_kernel = 2 #@param {type:"integer"}
cnn_tamaño_pooling = 2 #@param {type:"integer"}
cnn_cantidad_capas_ocultas = 3 #@param {type:"integer"}
cnn_agregar_capa_BatchNormalization = True #@param {type:"boolean"}
cnn_cantidad_neuronas_Dense = 16 #@param {type:"integer"}
cnn_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]
cnn_cant_epocas_entrenamiento = 350 #@param {type:"integer"}

## aplicación de los parámetros elegidos

# tamaño de los kernels y pooling (para simplificar son todas iguales)
if cnn_tamaño_kernel<1:
  cnn_tamaño_kernel = 1
cnn_kernel_shape = (cnn_tamaño_kernel)
if cnn_tamaño_pooling<1:
  cnn_tamaño_pooling=1
cnn_pooling_shape = (cnn_tamaño_pooling)

# indica la configuración para la parte Encoder 
#   (cada elemento de las listas son la configuración de las capas Conv)
if cnn_cantidad_capas_ocultas<1:
  cnn_cantidad_capas_ocultas = 1
cnn_filters = []
for i in range(cnn_cantidad_capas_ocultas, 0, -1):
  cnn_filters.append( 2**(i+2) )

# define tamaño de capa densa previa a la de salida
num_Dense_out = (8 if cnn_cantidad_neuronas_Dense<1 else cnn_cantidad_neuronas_Dense)

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (cnn_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if cnn_cant_epocas_entrenamiento<1 else cnn_cant_epocas_entrenamiento)

print("Configuración de la CNN definida: ")
print ("     -Kernels + Pooling: [", cnn_kernel_shape, "+", cnn_pooling_shape, "] ")
print ("     -Capas: [ ", matrixShape, ", Conv", cnn_filters, (", BatchNormalization" if  cnn_agregar_capa_BatchNormalization else "" ), ", FLATTEN, Dense[", num_Dense_out, "], ", ("Softmax" if tipo_output_softMax else "Dense[1] "))
# Out:
# Configuración de la CNN definida:
#      -Kernels + Pooling: [ 2 + 2 ]
#      -Capas: [  [2, 2] , Conv [32, 16, 8] , BatchNormalization , FLATTEN, Dense[ 16 ],  Softmax

# %%
#@title Establecer modelo

# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=((matrixShape[0], matrixShape[1])), name='input') # capa de entrada
eachLay = input_img_Lay
auxId = 1 
for i in range(len(cnn_filters)):  
       
    # define el nombre de la capa oculta
    auxlayerName = 'conv_'+str(auxId)
    auxId = auxId + 1

    # agrega las capas ocultas de tipo Conv2D + MaxPooling 
    eachLay = Conv1D(cnn_filters[i], cnn_kernel_shape, activation='relu', padding='same', name='c_'+auxlayerName)(eachLay) 
    eachLay = MaxPooling1D(cnn_pooling_shape, padding='same', name='p_'+auxlayerName)(eachLay)


if cnn_agregar_capa_BatchNormalization:
  # nota: para convNet no se usa DropOut, conviene usar BatchNormalization
  eachLay = BatchNormalization(name='bn')(eachLay)

#  agrega capa Flatten y Dense 
eachLay = Flatten(name='flat_'+auxlayerName)(eachLay)
eachLay = Dense(num_Dense_out, activation='relu', name='d_'+auxlayerName)(eachLay)

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(CLASES), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
#model.compile(optimizer='rmsprop', loss='mse', metrics=['accuracy'])
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  11  capas:
# Model: "RNA"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 2, 2)]            0
#
#  c_conv_1 (Conv1D)           (None, 2, 32)             160
#
#  p_conv_1 (MaxPooling1D)     (None, 1, 32)             0
#
#  c_conv_2 (Conv1D)           (None, 1, 16)             1040
#
#  p_conv_2 (MaxPooling1D)     (None, 1, 16)             0
#
#  c_conv_3 (Conv1D)           (None, 1, 8)              264
#
#  p_conv_3 (MaxPooling1D)     (None, 1, 8)              0
#
#  bn (BatchNormalization)     (None, 1, 8)              32
#
#  flat_conv_3 (Flatten)       (None, 8)                 0
#
#  d_conv_3 (Dense)            (None, 16)                144
#
#  output (Dense)              (None, 4)                 68
#
# =================================================================
# Total params: 1,708
# Trainable params: 1,692
# Non-trainable params: 16
# _________________________________________________________________

# %% [markdown]
# 4) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(matrixTrain, 
                                       (y_trainEnc if tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,) ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  104 ejemplos de entrenamiento:
#             se usan  93 ejemplos para entrenar
#             y  11 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/350
# 3/3 [==============================] - 1s 131ms/step - loss: 1.3654 - accuracy: 0.1935 - val_loss: 1.4280 - val_accuracy: 0.0909
# Epoch 2/350
# 3/3 [==============================] - 0s 14ms/step - loss: 1.2628 - accuracy: 0.4194 - val_loss: 1.4283 - val_accuracy: 0.0909
# Epoch 3/350
# 3/3 [==============================] - 0s 28ms/step - loss: 1.2213 - accuracy: 0.4946 - val_loss: 1.4282 - val_accuracy: 0.0909
# Epoch 4/350
# 3/3 [==============================] - 0s 14ms/step - loss: 1.2021 - accuracy: 0.4946 - val_loss: 1.4306 - val_accuracy: 0.0909
# Epoch 5/350
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1709 - accuracy: 0.5269 - val_loss: 1.4341 - val_accuracy: 0.0909
# Epoch 6/350
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1418 - accuracy: 0.5269 - val_loss: 1.4404 - val_accuracy: 0.0909
# Epoch 7/350
# 3/3 [==============================] - 0s 14ms/step - loss: 1.1076 - accuracy: 0.6022 - val_loss: 1.4476 - val_accuracy: 0.0909
# Epoch 8/350
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0836 - accuracy: 0.6667 - val_loss: 1.4563 - val_accuracy: 0.0909
# Epoch 9/350
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0360 - accuracy: 0.7634 - val_loss: 1.4654 - val_accuracy: 0.0909
# Epoch 10/350
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0095 - accuracy: 0.8387 - val_loss: 1.4733 - val_accuracy: 0.0909
# Epoch 11/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9687 - accuracy: 0.8387 - val_loss: 1.4807 - val_accuracy: 0.0909
# Epoch 12/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9397 - accuracy: 0.9140 - val_loss: 1.4878 - val_accuracy: 0.0909
# Epoch 13/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9094 - accuracy: 0.9462 - val_loss: 1.4907 - val_accuracy: 0.0909
# Epoch 14/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8833 - accuracy: 0.9355 - val_loss: 1.4935 - val_accuracy: 0.0909
# Epoch 15/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.8822 - accuracy: 0.9355 - val_loss: 1.4983 - val_accuracy: 0.0909
# Epoch 16/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8436 - accuracy: 0.9570 - val_loss: 1.5035 - val_accuracy: 0.0909
# Epoch 17/350
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8068 - accuracy: 0.9570 - val_loss: 1.5035 - val_accuracy: 0.0909
# Epoch 18/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7869 - accuracy: 0.9785 - val_loss: 1.5019 - val_accuracy: 0.0909
# Epoch 19/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7706 - accuracy: 0.9570 - val_loss: 1.5002 - val_accuracy: 0.0909
# Epoch 20/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7370 - accuracy: 0.9892 - val_loss: 1.4927 - val_accuracy: 0.0909
# Epoch 21/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7233 - accuracy: 0.9892 - val_loss: 1.4839 - val_accuracy: 0.0909
# Epoch 22/350
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6870 - accuracy: 0.9785 - val_loss: 1.4631 - val_accuracy: 0.0909
# Epoch 23/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6610 - accuracy: 0.9892 - val_loss: 1.4419 - val_accuracy: 0.0909
# Epoch 24/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6346 - accuracy: 0.9892 - val_loss: 1.4362 - val_accuracy: 0.0909
# Epoch 25/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6115 - accuracy: 0.9892 - val_loss: 1.4182 - val_accuracy: 0.0909
# Epoch 26/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5781 - accuracy: 0.9892 - val_loss: 1.4049 - val_accuracy: 0.1818
# Epoch 27/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5470 - accuracy: 0.9892 - val_loss: 1.4011 - val_accuracy: 0.1818
# Epoch 28/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5352 - accuracy: 0.9892 - val_loss: 1.3753 - val_accuracy: 0.2727
# Epoch 29/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5246 - accuracy: 0.9785 - val_loss: 1.3762 - val_accuracy: 0.3636
# Epoch 30/350
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5070 - accuracy: 0.9785 - val_loss: 1.3600 - val_accuracy: 0.3636
# Epoch 31/350
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4673 - accuracy: 0.9785 - val_loss: 1.3421 - val_accuracy: 0.3636
# Epoch 32/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4422 - accuracy: 0.9892 - val_loss: 1.3361 - val_accuracy: 0.3636
# Epoch 33/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4435 - accuracy: 0.9785 - val_loss: 1.3243 - val_accuracy: 0.3636
# Epoch 34/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4055 - accuracy: 0.9892 - val_loss: 1.3119 - val_accuracy: 0.3636
# Epoch 35/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4070 - accuracy: 0.9785 - val_loss: 1.2931 - val_accuracy: 0.3636
# Epoch 36/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3713 - accuracy: 0.9892 - val_loss: 1.3246 - val_accuracy: 0.3636
# Epoch 37/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3616 - accuracy: 0.9892 - val_loss: 1.3298 - val_accuracy: 0.3636
# Epoch 38/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3436 - accuracy: 0.9892 - val_loss: 1.2870 - val_accuracy: 0.3636
# Epoch 39/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3286 - accuracy: 0.9785 - val_loss: 1.2553 - val_accuracy: 0.3636
# Epoch 40/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3111 - accuracy: 0.9785 - val_loss: 1.2864 - val_accuracy: 0.3636
# Epoch 41/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2919 - accuracy: 0.9892 - val_loss: 1.3150 - val_accuracy: 0.3636
# Epoch 42/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2808 - accuracy: 0.9892 - val_loss: 1.3148 - val_accuracy: 0.3636
# Epoch 43/350
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2858 - accuracy: 0.9785 - val_loss: 1.2959 - val_accuracy: 0.3636
# Epoch 44/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2580 - accuracy: 0.9892 - val_loss: 1.2556 - val_accuracy: 0.3636
# Epoch 45/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2853 - accuracy: 0.9785 - val_loss: 1.1941 - val_accuracy: 0.3636
# Epoch 46/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2809 - accuracy: 0.9677 - val_loss: 1.2594 - val_accuracy: 0.3636
# Epoch 47/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2404 - accuracy: 0.9892 - val_loss: 1.2642 - val_accuracy: 0.3636
# Epoch 48/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2217 - accuracy: 0.9892 - val_loss: 1.2258 - val_accuracy: 0.3636
# Epoch 49/350
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2078 - accuracy: 0.9892 - val_loss: 1.1746 - val_accuracy: 0.4545
# Epoch 50/350
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2184 - accuracy: 0.9785 - val_loss: 1.1434 - val_accuracy: 0.4545
# Epoch 51/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1985 - accuracy: 0.9892 - val_loss: 1.1633 - val_accuracy: 0.4545
# Epoch 52/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2173 - accuracy: 0.9892 - val_loss: 1.2092 - val_accuracy: 0.3636
# Epoch 53/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2123 - accuracy: 0.9785 - val_loss: 1.1538 - val_accuracy: 0.4545
# Epoch 54/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1817 - accuracy: 0.9892 - val_loss: 1.1471 - val_accuracy: 0.4545
# Epoch 55/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1853 - accuracy: 0.9892 - val_loss: 1.1431 - val_accuracy: 0.4545
# Epoch 56/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1677 - accuracy: 0.9892 - val_loss: 1.1256 - val_accuracy: 0.4545
# Epoch 57/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1606 - accuracy: 0.9892 - val_loss: 1.1190 - val_accuracy: 0.4545
# Epoch 58/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1494 - accuracy: 0.9892 - val_loss: 1.1124 - val_accuracy: 0.4545
# Epoch 59/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1512 - accuracy: 0.9892 - val_loss: 1.0832 - val_accuracy: 0.4545
# Epoch 60/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1999 - accuracy: 0.9677 - val_loss: 1.0790 - val_accuracy: 0.4545
# Epoch 61/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1624 - accuracy: 0.9570 - val_loss: 1.1416 - val_accuracy: 0.4545
# Epoch 62/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1347 - accuracy: 0.9892 - val_loss: 1.0974 - val_accuracy: 0.4545
# Epoch 63/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1337 - accuracy: 0.9892 - val_loss: 1.0418 - val_accuracy: 0.4545
# Epoch 64/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1311 - accuracy: 0.9892 - val_loss: 1.0151 - val_accuracy: 0.5455
# Epoch 65/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1479 - accuracy: 0.9892 - val_loss: 1.0376 - val_accuracy: 0.4545
# Epoch 66/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1349 - accuracy: 0.9892 - val_loss: 0.9864 - val_accuracy: 0.5455
# Epoch 67/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1238 - accuracy: 0.9892 - val_loss: 1.0367 - val_accuracy: 0.4545
# Epoch 68/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1156 - accuracy: 0.9892 - val_loss: 1.0064 - val_accuracy: 0.5455
# Epoch 69/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1166 - accuracy: 0.9892 - val_loss: 0.9895 - val_accuracy: 0.5455
# Epoch 70/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1340 - accuracy: 0.9785 - val_loss: 1.1285 - val_accuracy: 0.4545
# Epoch 71/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1081 - accuracy: 0.9892 - val_loss: 1.2349 - val_accuracy: 0.4545
# Epoch 72/350
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1081 - accuracy: 0.9785 - val_loss: 1.1269 - val_accuracy: 0.4545
# Epoch 73/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1059 - accuracy: 0.9892 - val_loss: 0.9508 - val_accuracy: 0.5455
# Epoch 74/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1055 - accuracy: 0.9892 - val_loss: 0.8175 - val_accuracy: 0.6364
# Epoch 75/350
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1064 - accuracy: 0.9892 - val_loss: 0.9363 - val_accuracy: 0.5455
# Epoch 76/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1130 - accuracy: 0.9785 - val_loss: 1.0520 - val_accuracy: 0.4545
# Epoch 77/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0995 - accuracy: 0.9892 - val_loss: 1.1540 - val_accuracy: 0.4545
# Epoch 78/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0989 - accuracy: 0.9892 - val_loss: 1.0775 - val_accuracy: 0.4545
# Epoch 79/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0889 - accuracy: 1.0000 - val_loss: 1.0127 - val_accuracy: 0.5455
# Epoch 80/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0818 - accuracy: 1.0000 - val_loss: 1.0201 - val_accuracy: 0.5455
# Epoch 81/350
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0849 - accuracy: 1.0000 - val_loss: 1.1412 - val_accuracy: 0.4545
# Epoch 82/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0835 - accuracy: 0.9892 - val_loss: 1.1529 - val_accuracy: 0.4545
# Epoch 83/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0864 - accuracy: 0.9892 - val_loss: 1.0106 - val_accuracy: 0.5455
# Epoch 84/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0938 - accuracy: 0.9892 - val_loss: 1.0110 - val_accuracy: 0.5455
# Epoch 85/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1009 - accuracy: 0.9785 - val_loss: 1.0250 - val_accuracy: 0.5455
# Epoch 86/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0810 - accuracy: 0.9892 - val_loss: 0.8739 - val_accuracy: 0.6364
# Epoch 87/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0718 - accuracy: 0.9892 - val_loss: 0.9006 - val_accuracy: 0.5455
# Epoch 88/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0702 - accuracy: 0.9892 - val_loss: 0.9202 - val_accuracy: 0.5455
# Epoch 89/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0694 - accuracy: 0.9892 - val_loss: 1.0266 - val_accuracy: 0.5455
# Epoch 90/350
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0897 - accuracy: 0.9892 - val_loss: 0.9481 - val_accuracy: 0.5455
# Epoch 91/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0875 - accuracy: 0.9892 - val_loss: 0.9589 - val_accuracy: 0.5455
# Epoch 92/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0620 - accuracy: 0.9892 - val_loss: 0.8193 - val_accuracy: 0.6364
# Epoch 93/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0989 - accuracy: 0.9785 - val_loss: 0.8010 - val_accuracy: 0.6364
# Epoch 94/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0738 - accuracy: 0.9892 - val_loss: 1.0222 - val_accuracy: 0.5455
# Epoch 95/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0748 - accuracy: 0.9892 - val_loss: 0.9480 - val_accuracy: 0.5455
# Epoch 96/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0640 - accuracy: 0.9892 - val_loss: 0.8419 - val_accuracy: 0.6364
# Epoch 97/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0626 - accuracy: 0.9892 - val_loss: 0.6970 - val_accuracy: 0.7273
# Epoch 98/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0587 - accuracy: 0.9892 - val_loss: 0.6723 - val_accuracy: 0.7273
# Epoch 99/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0577 - accuracy: 0.9892 - val_loss: 0.6899 - val_accuracy: 0.7273
# Epoch 100/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0504 - accuracy: 0.9892 - val_loss: 0.7405 - val_accuracy: 0.7273
# Epoch 101/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0675 - accuracy: 0.9892 - val_loss: 0.7803 - val_accuracy: 0.7273
# Epoch 102/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0518 - accuracy: 0.9892 - val_loss: 0.6964 - val_accuracy: 0.7273
# Epoch 103/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0570 - accuracy: 1.0000 - val_loss: 0.6740 - val_accuracy: 0.7273
# Epoch 104/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0511 - accuracy: 0.9892 - val_loss: 0.7116 - val_accuracy: 0.7273
# Epoch 105/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0641 - accuracy: 0.9892 - val_loss: 0.9032 - val_accuracy: 0.6364
# Epoch 106/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0541 - accuracy: 0.9892 - val_loss: 0.8751 - val_accuracy: 0.6364
# Epoch 107/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0635 - accuracy: 0.9892 - val_loss: 0.7988 - val_accuracy: 0.6364
# Epoch 108/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0552 - accuracy: 0.9892 - val_loss: 0.7639 - val_accuracy: 0.7273
# Epoch 109/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0540 - accuracy: 1.0000 - val_loss: 0.8639 - val_accuracy: 0.6364
# Epoch 110/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0456 - accuracy: 1.0000 - val_loss: 0.9712 - val_accuracy: 0.6364
# Epoch 111/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0661 - accuracy: 0.9892 - val_loss: 1.0354 - val_accuracy: 0.5455
# Epoch 112/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0594 - accuracy: 0.9892 - val_loss: 1.1152 - val_accuracy: 0.5455
# Epoch 113/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0660 - accuracy: 0.9892 - val_loss: 1.0231 - val_accuracy: 0.5455
# Epoch 114/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0458 - accuracy: 0.9892 - val_loss: 0.6580 - val_accuracy: 0.7273
# Epoch 115/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0587 - accuracy: 0.9892 - val_loss: 0.6244 - val_accuracy: 0.7273
# Epoch 116/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.6692 - val_accuracy: 0.7273
# Epoch 117/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0538 - accuracy: 0.9892 - val_loss: 0.7378 - val_accuracy: 0.7273
# Epoch 118/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0447 - accuracy: 0.9892 - val_loss: 0.5941 - val_accuracy: 0.7273
# Epoch 119/350
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0519 - accuracy: 0.9892 - val_loss: 0.8082 - val_accuracy: 0.7273
# Epoch 120/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0393 - accuracy: 1.0000 - val_loss: 1.1177 - val_accuracy: 0.6364
# Epoch 121/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0662 - accuracy: 0.9892 - val_loss: 1.0578 - val_accuracy: 0.6364
# Epoch 122/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 1.0806 - val_accuracy: 0.5455
# Epoch 123/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0614 - accuracy: 0.9892 - val_loss: 1.0146 - val_accuracy: 0.6364
# Epoch 124/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0393 - accuracy: 0.9892 - val_loss: 1.1020 - val_accuracy: 0.6364
# Epoch 125/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0391 - accuracy: 0.9892 - val_loss: 0.8515 - val_accuracy: 0.7273
# Epoch 126/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0406 - accuracy: 0.9892 - val_loss: 0.4919 - val_accuracy: 0.7273
# Epoch 127/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0490 - accuracy: 0.9892 - val_loss: 0.5968 - val_accuracy: 0.7273
# Epoch 128/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0399 - accuracy: 0.9892 - val_loss: 0.6535 - val_accuracy: 0.7273
# Epoch 129/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0591 - accuracy: 0.9892 - val_loss: 0.7984 - val_accuracy: 0.7273
# Epoch 130/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 1.3926 - val_accuracy: 0.5455
# Epoch 131/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0471 - accuracy: 0.9892 - val_loss: 1.2144 - val_accuracy: 0.6364
# Epoch 132/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0334 - accuracy: 0.9892 - val_loss: 0.7407 - val_accuracy: 0.7273
# Epoch 133/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0632 - accuracy: 0.9892 - val_loss: 0.3495 - val_accuracy: 0.9091
# Epoch 134/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0648 - accuracy: 0.9677 - val_loss: 0.8122 - val_accuracy: 0.7273
# Epoch 135/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0528 - accuracy: 0.9892 - val_loss: 1.0613 - val_accuracy: 0.6364
# Epoch 136/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0578 - accuracy: 0.9892 - val_loss: 0.8182 - val_accuracy: 0.7273
# Epoch 137/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0457 - accuracy: 0.9892 - val_loss: 0.4771 - val_accuracy: 0.9091
# Epoch 138/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0768 - accuracy: 0.9677 - val_loss: 0.5445 - val_accuracy: 0.8182
# Epoch 139/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0510 - accuracy: 0.9892 - val_loss: 0.8020 - val_accuracy: 0.7273
# Epoch 140/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0369 - accuracy: 0.9892 - val_loss: 0.9359 - val_accuracy: 0.7273
# Epoch 141/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0380 - accuracy: 0.9892 - val_loss: 0.9596 - val_accuracy: 0.7273
# Epoch 142/350
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0369 - accuracy: 0.9892 - val_loss: 1.2400 - val_accuracy: 0.6364
# Epoch 143/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0542 - accuracy: 0.9892 - val_loss: 1.3316 - val_accuracy: 0.6364
# Epoch 144/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0297 - accuracy: 0.9892 - val_loss: 1.1550 - val_accuracy: 0.6364
# Epoch 145/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0428 - accuracy: 0.9892 - val_loss: 0.9192 - val_accuracy: 0.7273
# Epoch 146/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0290 - accuracy: 0.9892 - val_loss: 0.8195 - val_accuracy: 0.7273
# Epoch 147/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.7970 - val_accuracy: 0.7273
# Epoch 148/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.9496 - val_accuracy: 0.7273
# Epoch 149/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0277 - accuracy: 0.9892 - val_loss: 1.2695 - val_accuracy: 0.6364
# Epoch 150/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0420 - accuracy: 0.9892 - val_loss: 1.1930 - val_accuracy: 0.6364
# Epoch 151/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0332 - accuracy: 0.9892 - val_loss: 1.0418 - val_accuracy: 0.7273
# Epoch 152/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0344 - accuracy: 0.9892 - val_loss: 0.8659 - val_accuracy: 0.7273
# Epoch 153/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0397 - accuracy: 0.9892 - val_loss: 0.6420 - val_accuracy: 0.8182
# Epoch 154/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 1.0142 - val_accuracy: 0.7273
# Epoch 155/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0282 - accuracy: 0.9892 - val_loss: 1.4581 - val_accuracy: 0.6364
# Epoch 156/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 1.5689 - val_accuracy: 0.6364
# Epoch 157/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0384 - accuracy: 0.9892 - val_loss: 1.3877 - val_accuracy: 0.6364
# Epoch 158/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0291 - accuracy: 0.9892 - val_loss: 1.2308 - val_accuracy: 0.6364
# Epoch 159/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0280 - accuracy: 0.9892 - val_loss: 0.9249 - val_accuracy: 0.7273
# Epoch 160/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0312 - accuracy: 0.9892 - val_loss: 0.8224 - val_accuracy: 0.7273
# Epoch 161/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0333 - accuracy: 1.0000 - val_loss: 1.2917 - val_accuracy: 0.6364
# Epoch 162/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0452 - accuracy: 0.9892 - val_loss: 1.4029 - val_accuracy: 0.6364
# Epoch 163/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0363 - accuracy: 0.9892 - val_loss: 0.8364 - val_accuracy: 0.7273
# Epoch 164/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0312 - accuracy: 0.9892 - val_loss: 0.8123 - val_accuracy: 0.7273
# Epoch 165/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0258 - accuracy: 0.9892 - val_loss: 0.8739 - val_accuracy: 0.7273
# Epoch 166/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0284 - accuracy: 0.9892 - val_loss: 1.0644 - val_accuracy: 0.7273
# Epoch 167/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 1.2351 - val_accuracy: 0.7273
# Epoch 168/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0278 - accuracy: 0.9892 - val_loss: 1.2984 - val_accuracy: 0.6364
# Epoch 169/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0340 - accuracy: 0.9892 - val_loss: 1.1116 - val_accuracy: 0.7273
# Epoch 170/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.9092 - val_accuracy: 0.7273
# Epoch 171/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.7776 - val_accuracy: 0.7273
# Epoch 172/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.6993 - val_accuracy: 0.8182
# Epoch 173/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0362 - accuracy: 0.9892 - val_loss: 0.5697 - val_accuracy: 0.8182
# Epoch 174/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.6381 - val_accuracy: 0.8182
# Epoch 175/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.6286 - val_accuracy: 0.8182
# Epoch 176/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0541 - accuracy: 0.9892 - val_loss: 0.6561 - val_accuracy: 0.8182
# Epoch 177/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 1.5048 - val_accuracy: 0.6364
# Epoch 178/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0287 - accuracy: 0.9892 - val_loss: 1.9363 - val_accuracy: 0.5455
# Epoch 179/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0421 - accuracy: 0.9892 - val_loss: 1.2875 - val_accuracy: 0.7273
# Epoch 180/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0298 - accuracy: 0.9892 - val_loss: 0.5752 - val_accuracy: 0.8182
# Epoch 181/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0381 - accuracy: 1.0000 - val_loss: 0.4105 - val_accuracy: 0.9091
# Epoch 182/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.6370 - val_accuracy: 0.8182
# Epoch 183/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 1.1069 - val_accuracy: 0.7273
# Epoch 184/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0366 - accuracy: 0.9892 - val_loss: 1.4475 - val_accuracy: 0.6364
# Epoch 185/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0604 - accuracy: 0.9785 - val_loss: 1.0425 - val_accuracy: 0.7273
# Epoch 186/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0442 - accuracy: 0.9785 - val_loss: 0.3206 - val_accuracy: 0.9091
# Epoch 187/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0579 - accuracy: 0.9677 - val_loss: 0.1641 - val_accuracy: 0.9091
# Epoch 188/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9091
# Epoch 189/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0303 - accuracy: 1.0000 - val_loss: 0.1579 - val_accuracy: 0.9091
# Epoch 190/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0246 - accuracy: 0.9892 - val_loss: 0.4486 - val_accuracy: 0.9091
# Epoch 191/350
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0259 - accuracy: 0.9892 - val_loss: 0.7106 - val_accuracy: 0.8182
# Epoch 192/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.8435 - val_accuracy: 0.7273
# Epoch 193/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0912 - accuracy: 0.9677 - val_loss: 0.6643 - val_accuracy: 0.8182
# Epoch 194/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0573 - accuracy: 0.9677 - val_loss: 0.9605 - val_accuracy: 0.7273
# Epoch 195/350
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0253 - accuracy: 0.9892 - val_loss: 1.2524 - val_accuracy: 0.7273
# Epoch 196/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 1.1389 - val_accuracy: 0.7273
# Epoch 197/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.8721 - val_accuracy: 0.8182
# Epoch 198/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0303 - accuracy: 0.9892 - val_loss: 0.6388 - val_accuracy: 0.8182
# Epoch 199/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0223 - accuracy: 0.9892 - val_loss: 0.5822 - val_accuracy: 0.8182
# Epoch 200/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.6145 - val_accuracy: 0.8182
# Epoch 201/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0813 - accuracy: 0.9677 - val_loss: 1.1193 - val_accuracy: 0.7273
# Epoch 202/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 1.3660 - val_accuracy: 0.7273
# Epoch 203/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0601 - accuracy: 0.9892 - val_loss: 1.1965 - val_accuracy: 0.7273
# Epoch 204/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.4786 - val_accuracy: 0.8182
# Epoch 205/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.4217 - val_accuracy: 0.9091
# Epoch 206/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.5336 - val_accuracy: 0.8182
# Epoch 207/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.7250 - val_accuracy: 0.8182
# Epoch 208/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.8281 - val_accuracy: 0.7273
# Epoch 209/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0275 - accuracy: 0.9892 - val_loss: 0.7435 - val_accuracy: 0.8182
# Epoch 210/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.5985 - val_accuracy: 0.8182
# Epoch 211/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.3905 - val_accuracy: 0.9091
# Epoch 212/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0622 - accuracy: 0.9785 - val_loss: 0.5692 - val_accuracy: 0.8182
# Epoch 213/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0567 - accuracy: 0.9677 - val_loss: 2.0142 - val_accuracy: 0.5455
# Epoch 214/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0541 - accuracy: 0.9785 - val_loss: 2.7562 - val_accuracy: 0.3636
# Epoch 215/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0363 - accuracy: 0.9892 - val_loss: 1.7954 - val_accuracy: 0.5455
# Epoch 216/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.3611 - val_accuracy: 0.8182
# Epoch 217/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 0.0543 - val_accuracy: 1.0000
# Epoch 218/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0584 - accuracy: 0.9892 - val_loss: 0.2859 - val_accuracy: 0.9091
# Epoch 219/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0277 - accuracy: 0.9892 - val_loss: 0.6349 - val_accuracy: 0.8182
# Epoch 220/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.6354 - val_accuracy: 0.8182
# Epoch 221/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0307 - accuracy: 0.9892 - val_loss: 0.3888 - val_accuracy: 0.9091
# Epoch 222/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.2438 - val_accuracy: 0.9091
# Epoch 223/350
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.1118 - val_accuracy: 0.9091
# Epoch 224/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0331 - accuracy: 0.9892 - val_loss: 0.3068 - val_accuracy: 0.9091
# Epoch 225/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.7850 - val_accuracy: 0.8182
# Epoch 226/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0216 - accuracy: 0.9892 - val_loss: 1.6102 - val_accuracy: 0.6364
# Epoch 227/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0269 - accuracy: 0.9892 - val_loss: 1.7424 - val_accuracy: 0.6364
# Epoch 228/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 1.4899 - val_accuracy: 0.7273
# Epoch 229/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.9880 - val_accuracy: 0.7273
# Epoch 230/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.9933 - val_accuracy: 0.7273
# Epoch 231/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 1.3055 - val_accuracy: 0.7273
# Epoch 232/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.4184 - val_accuracy: 0.7273
# Epoch 233/350
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0251 - accuracy: 0.9892 - val_loss: 1.5332 - val_accuracy: 0.7273
# Epoch 234/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0313 - accuracy: 0.9892 - val_loss: 1.0339 - val_accuracy: 0.7273
# Epoch 235/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0248 - accuracy: 0.9892 - val_loss: 0.7343 - val_accuracy: 0.8182
# Epoch 236/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.9701 - val_accuracy: 0.7273
# Epoch 237/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0199 - accuracy: 0.9892 - val_loss: 1.0831 - val_accuracy: 0.7273
# Epoch 238/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 1.1040 - val_accuracy: 0.7273
# Epoch 239/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0242 - accuracy: 0.9892 - val_loss: 0.8130 - val_accuracy: 0.8182
# Epoch 240/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0493 - accuracy: 0.9785 - val_loss: 1.4015 - val_accuracy: 0.7273
# Epoch 241/350
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 1.5242 - val_accuracy: 0.7273
# Epoch 242/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0382 - accuracy: 0.9892 - val_loss: 0.9502 - val_accuracy: 0.7273
# Epoch 243/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0219 - accuracy: 0.9892 - val_loss: 0.9313 - val_accuracy: 0.7273
# Epoch 244/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 1.1839 - val_accuracy: 0.7273
# Epoch 245/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 1.1197 - val_accuracy: 0.7273
# Epoch 246/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0159 - accuracy: 0.9892 - val_loss: 0.6791 - val_accuracy: 0.8182
# Epoch 247/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.3747 - val_accuracy: 0.9091
# Epoch 248/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0201 - accuracy: 0.9892 - val_loss: 0.1514 - val_accuracy: 0.9091
# Epoch 249/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.1778 - val_accuracy: 0.9091
# Epoch 250/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0387 - accuracy: 0.9677 - val_loss: 0.5822 - val_accuracy: 0.8182
# Epoch 251/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 1.3116 - val_accuracy: 0.7273
# Epoch 252/350
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.6153 - val_accuracy: 0.7273
# Epoch 253/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0228 - accuracy: 0.9892 - val_loss: 1.1704 - val_accuracy: 0.7273
# Epoch 254/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.5763 - val_accuracy: 0.8182
# Epoch 255/350
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0297 - accuracy: 0.9892 - val_loss: 0.3843 - val_accuracy: 0.8182
# Epoch 256/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.7517 - val_accuracy: 0.8182
# Epoch 257/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0153 - accuracy: 0.9892 - val_loss: 0.8621 - val_accuracy: 0.8182
# Epoch 258/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.7599 - val_accuracy: 0.8182
# Epoch 259/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.5728 - val_accuracy: 0.8182
# Epoch 260/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0170 - accuracy: 0.9892 - val_loss: 0.4263 - val_accuracy: 0.8182
# Epoch 261/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.4898 - val_accuracy: 0.8182
# Epoch 262/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.7672 - val_accuracy: 0.8182
# Epoch 263/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 1.8699 - val_accuracy: 0.6364
# Epoch 264/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 1.9827 - val_accuracy: 0.6364
# Epoch 265/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0269 - accuracy: 0.9892 - val_loss: 1.3908 - val_accuracy: 0.7273
# Epoch 266/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.7552 - val_accuracy: 0.8182
# Epoch 267/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0386 - accuracy: 0.9785 - val_loss: 1.1604 - val_accuracy: 0.7273
# Epoch 268/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 1.2807 - val_accuracy: 0.7273
# Epoch 269/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0153 - accuracy: 0.9892 - val_loss: 0.8766 - val_accuracy: 0.8182
# Epoch 270/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.4655 - val_accuracy: 0.8182
# Epoch 271/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9091
# Epoch 272/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.3237 - val_accuracy: 0.9091
# Epoch 273/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4978 - val_accuracy: 0.8182
# Epoch 274/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.7366 - val_accuracy: 0.8182
# Epoch 275/350
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.9874 - val_accuracy: 0.7273
# Epoch 276/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.8727 - val_accuracy: 0.8182
# Epoch 277/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 1.0260 - val_accuracy: 0.7273
# Epoch 278/350
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.5611 - val_accuracy: 0.7273
# Epoch 279/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 1.6002 - val_accuracy: 0.7273
# Epoch 280/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.3827 - val_accuracy: 0.7273
# Epoch 281/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 1.7134 - val_accuracy: 0.7273
# Epoch 282/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.5080 - val_accuracy: 0.7273
# Epoch 283/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0439 - accuracy: 0.9785 - val_loss: 1.2643 - val_accuracy: 0.7273
# Epoch 284/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0192 - accuracy: 0.9892 - val_loss: 1.7773 - val_accuracy: 0.7273
# Epoch 285/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0306 - accuracy: 0.9892 - val_loss: 0.8028 - val_accuracy: 0.8182
# Epoch 286/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0302 - accuracy: 0.9785 - val_loss: 1.0029 - val_accuracy: 0.7273
# Epoch 287/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.4300 - val_accuracy: 0.7273
# Epoch 288/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.6977 - val_accuracy: 0.7273
# Epoch 289/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.6807 - val_accuracy: 0.7273
# Epoch 290/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0216 - accuracy: 0.9892 - val_loss: 1.0912 - val_accuracy: 0.7273
# Epoch 291/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.5588 - val_accuracy: 0.8182
# Epoch 292/350
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.7556 - val_accuracy: 0.8182
# Epoch 293/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.0153 - val_accuracy: 0.7273
# Epoch 294/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.1767 - val_accuracy: 0.7273
# Epoch 295/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.2010 - val_accuracy: 0.7273
# Epoch 296/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.1169 - val_accuracy: 0.7273
# Epoch 297/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.9782 - val_accuracy: 0.7273
# Epoch 298/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.8418 - val_accuracy: 0.8182
# Epoch 299/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.8972 - val_accuracy: 0.8182
# Epoch 300/350
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.9860 - val_accuracy: 0.7273
# Epoch 301/350
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0221 - accuracy: 0.9892 - val_loss: 1.0676 - val_accuracy: 0.7273
# Epoch 302/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.8552 - val_accuracy: 0.8182
# Epoch 303/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.6659 - val_accuracy: 0.8182
# Epoch 304/350
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.9680 - val_accuracy: 0.8182
# Epoch 305/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 1.2006 - val_accuracy: 0.7273
# Epoch 306/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.0925 - val_accuracy: 0.7273
# Epoch 307/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0248 - accuracy: 0.9785 - val_loss: 0.5162 - val_accuracy: 0.8182
# Epoch 308/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 1.0538 - val_accuracy: 0.7273
# Epoch 309/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0178 - accuracy: 0.9892 - val_loss: 1.6319 - val_accuracy: 0.7273
# Epoch 310/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.3233 - val_accuracy: 0.7273
# Epoch 311/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.8093 - val_accuracy: 0.8182
# Epoch 312/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0346 - accuracy: 0.9892 - val_loss: 0.3073 - val_accuracy: 0.9091
# Epoch 313/350
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.6168 - val_accuracy: 0.8182
# Epoch 314/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.9876 - val_accuracy: 0.8182
# Epoch 315/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.3336 - val_accuracy: 0.7273
# Epoch 316/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0622 - accuracy: 0.9785 - val_loss: 0.6611 - val_accuracy: 0.8182
# Epoch 317/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.8185 - val_accuracy: 0.8182
# Epoch 318/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.9715 - val_accuracy: 0.8182
# Epoch 319/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0329 - accuracy: 0.9892 - val_loss: 0.7994 - val_accuracy: 0.8182
# Epoch 320/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0482 - accuracy: 0.9677 - val_loss: 1.4333 - val_accuracy: 0.7273
# Epoch 321/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.7869 - val_accuracy: 0.8182
# Epoch 322/350
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.4473 - val_accuracy: 0.8182
# Epoch 323/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.8841 - val_accuracy: 0.8182
# Epoch 324/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0414 - accuracy: 0.9892 - val_loss: 2.0899 - val_accuracy: 0.6364
# Epoch 325/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0527 - accuracy: 0.9892 - val_loss: 1.7045 - val_accuracy: 0.7273
# Epoch 326/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.4062 - val_accuracy: 0.8182
# Epoch 327/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0228 - accuracy: 0.9892 - val_loss: 0.3199 - val_accuracy: 0.9091
# Epoch 328/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.7209 - val_accuracy: 0.8182
# Epoch 329/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0206 - accuracy: 0.9892 - val_loss: 1.2520 - val_accuracy: 0.7273
# Epoch 330/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 1.2097 - val_accuracy: 0.7273
# Epoch 331/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0159 - accuracy: 0.9892 - val_loss: 0.9447 - val_accuracy: 0.8182
# Epoch 332/350
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.4108 - val_accuracy: 0.9091
# Epoch 333/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0854 - val_accuracy: 0.9091
# Epoch 334/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9091
# Epoch 335/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.5438 - val_accuracy: 0.8182
# Epoch 336/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.8672 - val_accuracy: 0.8182
# Epoch 337/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0213 - accuracy: 0.9892 - val_loss: 1.0532 - val_accuracy: 0.7273
# Epoch 338/350
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0254 - accuracy: 0.9892 - val_loss: 0.9413 - val_accuracy: 0.8182
# Epoch 339/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.4247 - val_accuracy: 0.8182
# Epoch 340/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0245 - accuracy: 0.9892 - val_loss: 0.6256 - val_accuracy: 0.8182
# Epoch 341/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.2138 - val_accuracy: 0.7273
# Epoch 342/350
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0161 - accuracy: 0.9892 - val_loss: 1.3810 - val_accuracy: 0.7273
# Epoch 343/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.3030 - val_accuracy: 0.7273
# Epoch 344/350
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.2161 - val_accuracy: 0.7273
# Epoch 345/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.0248 - val_accuracy: 0.8182
# Epoch 346/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0203 - accuracy: 0.9892 - val_loss: 1.4235 - val_accuracy: 0.7273
# Epoch 347/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.4196 - val_accuracy: 0.7273
# Epoch 348/350
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.1817 - val_accuracy: 0.7273
# Epoch 349/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.1785 - val_accuracy: 0.7273
# Epoch 350/350
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.1586 - val_accuracy: 0.7273
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
mostrar_detalle_entrenamiento = False #@param {type:"boolean"}

# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, clases_map, mostrarDetalle=False):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # prepara salida
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA"
        else:      
            clPred = clases_map[ idclPredRnd ]

        classReal.append( clReal )
        classPreds.append( clPred )

        strTitulo = 'Real: ' + clReal + ' / Modelo(RNA): ' 
        strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'   
        strTitulo = strTitulo + ": " + ("ok" if (clPred==clReal) else "error!")

        # muestra comparación con la imagen
        if mostrarDetalle:
          print(strTitulo)

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión ( real / modelo ): ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['m:{:}'.format(x) for x in clases_map]
      )
    # agrega para poder mostrar la matrix de confusión completa
    pd.options.display.max_rows = 100
    pd.options.display.max_columns = 100
    print(cmtx)
    print("\n")

    # gráfico de comparación
    plt.title('Gráfico de Confusión:')
    plt.xlabel('Real')
    plt.ylabel('Modelo')
    plt.scatter(classReal, classPreds)

# prueba con los datos de entrenamiento
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(matrixTrain, y_train, CLASES, mostrar_detalle_entrenamiento)
# Out:
# *** Resultados con datos de Entrenamiento:
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        35
#   Versicolor       1.00      0.89      0.94        35
#    Virginica       0.89      1.00      0.94        34
#
#     accuracy                           0.96       104
#    macro avg       0.96      0.96      0.96       104
# weighted avg       0.97      0.96      0.96       104
#
#
# Matriz de Confusión ( real / modelo ):
#               m:na  m:Setosa  m:Versicolor  m:Virginica
# r:na             0         0             0            0
# r:Setosa         0        35             0            0
# r:Versicolor     0         0            31            4
# r:Virginica      0         0             0           34

# %% [markdown]
# 6) Evaluar el modelo de la RNA entrenado con los datos de prueba:

# %%
#@title Probar red entrenada con datos de prueba
mostrar_detalle_prueba = False #@param {type:"boolean"}

 # evalua al modelo entrenado
resEval = model.evaluate(matrixTest, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de prueba
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(matrixTest, y_test, CLASES, mostrar_detalle_prueba)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1949 - accuracy: 0.8913
#
# >Evaluación del Modelo:
#     - Error:  0.19491568207740784
#     - Exactitud:  89.13043737411499
#
#
#
#
# *** Resultados con datos de Prueba:
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        15
#   Versicolor       0.81      0.87      0.84        15
#    Virginica       0.87      0.81      0.84        16
#
#     accuracy                           0.89        46
#    macro avg       0.89      0.89      0.89        46
# weighted avg       0.89      0.89      0.89        46
#
#
# Matriz de Confusión ( real / modelo ):
#               m:na  m:Setosa  m:Versicolor  m:Virginica
# r:na             0         0             0            0
# r:Setosa         0        15             0            0
# r:Versicolor     0         0            13            2
# r:Virginica      0         0             3           13
