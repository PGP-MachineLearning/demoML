# %% [markdown]
# # Demo Convolutional Neural Network (CNN) para identificar clases
# Adaptado de https://www.tensorflow.org/tutorials/estimator/premade

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, BatchNormalization 
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.layers import Reshape, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

import os
import csv

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Cargar los datos:

# %%
# monta Google Drive:
# Nota: la primera vez se debe confirmar el uso logueandose en "Google Drive File Stream" y obteniendo código de autentificación.
from google.colab import drive
drive.mount('/content/gdrive')

# directorio local en Google Drive
path = '/content/gdrive/My Drive/IA/demoML/datos/'  #@param {type:"string"}
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
## selección de los parámetros 

def cargarNombreClases(path, archivo_datos, atributo_clase, nombre_clases):
  # importa definición de la clase
  arClasesFN = archivo_datos.split('.')[0] + '_nombreClases.txt'
  if os.path.isfile( path + '/' + arClasesFN ):
    with open( path + '/' + arClasesFN, mode='r') as csvfile:
        r = csv.reader(csvfile, delimiter=',')
        auxAtributo = r.__next__()
        auxClases = r.__next__()
    print('\n> Definición de los valores discretos para la clase cargada de ' + arClasesFN +'.\n')
    return auxAtributo[0], ','.join(auxClases)
  else:
    return atributo_clase, nombre_clases


#@markdown ### Archivo de datos a utilizar:
archivo_datos = 'IRIS.csv'  #@param {type:"string"}
#@markdown ### Nombre del atributo clase / objetivo:
atributo_clase = '-' #@param {type:"string"}
#@markdown ### Descripción de los valores del atributo clase / objetivo:  (nota: siempre debe comienzar en 0, por lo que si no tiene valor 0, agregar "na")
nombre_clases = '-' #@param {type:"string"}
#@markdown ### Porcentaje de datos para usar en el entrenamiento:
proporcion_porcentaje_datos_entrenamiento =   70#@param {type:"integer"}

## aplicación de los parámetros elegidos

if atributo_clase == '' or  atributo_clase == '-':
  # trata de obtener la configuración del archivo asociado
  atributo_clase, nombre_clases = cargarNombreClases(path, archivo_datos, atributo_clase, nombre_clases)

# define nombre atributo de CLASE para ejemplo IRIS
ClassAttributeName = atributo_clase

# define valores de clases para ejemplo IRIS
CLASES = [ ]
for val in nombre_clases.split(','):
  CLASES.append( val )

# determina la proporción a usar para entrenar y probar
if proporcion_porcentaje_datos_entrenamiento>100:
  propTrain = 1
elif proporcion_porcentaje_datos_entrenamiento<1:
  propTrain = 0.1
else:
  propTrain = proporcion_porcentaje_datos_entrenamiento/100

print("Configuración definida de ", archivo_datos)
print("Atributo clase: ", ClassAttributeName, ": ", CLASES)
# Out:
# > Definición de los valores discretos para la clase cargada de IRIS_nombreClases.txt.
#
# Configuración definida de  IRIS.csv
# Atributo clase:  Clase :  ['na', 'Setosa', 'Versicolor', 'Virginica']

# %%
#@title Cargar datos

# configura para que muestre todas las columnas y filas
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# Carga los datos del CSV y muestra los primeros
df = pd.read_csv(path + archivo_datos)
print("\n> Cabecera: ")
print(df.head())
print("\n> Características: ")
print(df.describe())

# genera los datos solo con la clase para entrenar y probar
Y = np.array(df.pop(ClassAttributeName))
X = np.array(df)
# Out:
# > Cabecera:
#    LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo  Clase
# 0          5.1          3.5          1.4          0.2      1
# 1          4.9          3.0          1.4          0.2      1
# 2          4.7          3.2          1.3          0.2      1
# 3          4.6          3.1          1.5          0.2      1
# 4          5.0          3.6          1.4          0.2      1
#
# > Características:
#        LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo       Clase
# count   150.000000   150.000000   150.000000   150.000000  150.000000
# mean      5.843333     3.054000     3.758667     1.198667    2.000000
# std       0.828066     0.433594     1.764420     0.763161    0.819232
# min       4.300000     2.000000     1.000000     0.100000    1.000000
# 25%       5.100000     2.800000     1.600000     0.300000    1.000000
# 50%       5.800000     3.000000     4.350000     1.300000    2.000000
# 75%       6.400000     3.300000     5.100000     1.800000    3.000000
# max       7.900000     4.400000     6.900000     2.500000    3.000000

# %%
#@title Normalizar datos de entrada (opcional)

aplica_normalizacion = False #@param {type:"boolean"}
#@markdown Si se aplica, seleccione el tipo de método de normalización a aplicar:
tipo_normalizacion = "Standard Scaler" #@param ["Standard Scaler", "MinMax Scaler", "MaxAbs Scaler", "Robust Scaler"]

if aplica_normalizacion:

  print("10 primeros datos de Entrada antes de normalizar: ")
  print(X[:10])

  from sklearn import preprocessing

  # elegir el método de normalización
  if tipo_normalizacion == "Standard Scaler": 
    scaler = preprocessing.StandardScaler()
  elif tipo_normalizacion == "MinMax Scaler": 
    scaler = preprocessing.MinMaxScaler()
  elif tipo_normalizacion == "MaxMax Scaler": 
    scaler = preprocessing.MaxAbsScaler()
  elif tipo_normalizacion == "Robust Scaler": 
    scaler = preprocessing.RobustScaler()
  
  # normaliza los datos de entrada
  X = scaler.fit_transform(X)

  print("\n\n10 primeros datos de Entrada después de normalizar: ")
  print(X[:10])

# %%
#@title Preparar datos

# separa al azar usando muestreo estratificado con proporción indicada
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=(1-propTrain), stratify=Y)

# genera salida codificada para softMax
y_trainEnc =  np_utils.to_categorical(y_train)
y_testEnc =  np_utils.to_categorical(y_test)

# muestra resultados
print("> Para Ambos: ")
print(" - dictMapeo: ", CLASES)

print("\n> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
print(" - y_train (cant): ", len(y_train))
for i in range(len(CLASES)):
  cant = 0
  for y in y_train:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)

print("\n Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
print(" - y_test (cant): ", len(y_test))
for i in range(len(CLASES)):
  cant = 0
  for y in y_test:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)
# Out:
# > Para Ambos:
#  - dictMapeo:  ['na', 'Setosa', 'Versicolor', 'Virginica']
#
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (104, 4)
#  - y_train (cant):  104
#      na [ 0 ]: 0
#      Setosa [ 1 ]: 35
#      Versicolor [ 2 ]: 34
#      Virginica [ 3 ]: 35
#
#  Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (46, 4)
#  - y_test (cant):  46
#      na [ 0 ]: 0
#      Setosa [ 1 ]: 15
#      Versicolor [ 2 ]: 16
#      Virginica [ 3 ]: 15

# %%
#@title Preparar datos - convertir a matriz
cols = x_train.shape[1]

if (cols%2)==0:
  matrixShape = [2,(cols//2)]
else:
  matrixShape = [3,(cols//3)]
print("\n Forma de la matriz: ", matrixShape)

matrixTrain = []
matrixTest = []

# cambia la forma de la matriz
matrixTrain = x_train.reshape((len(x_train), matrixShape[0], matrixShape[1]))  
matrixTest = x_test.reshape((len(x_test), matrixShape[0], matrixShape[1]))  

print("\n Datos de entrada convertidos matriz: ")
print(" - matrixTrain (cant ejemplos, forma): ", matrixTrain.shape)
print(" - matrixTest (cant ejemplos, forma): ", matrixTest.shape)
# Out:
#  Forma de la matriz:  [2, 2]
#
#  Datos de entrada convertidos matriz:
#  - matrixTrain (cant ejemplos, forma):  (104, 2, 2)
#  - matrixTest (cant ejemplos, forma):  (46, 2, 2)

# %% [markdown]
# 3) Establecer el modelo para la RNA

# %%
#@markdown ### Parámetros de la red:
cnn_tamaño_kernel = 2 #@param {type:"integer"}
cnn_tamaño_pooling = 2 #@param {type:"integer"}
cnn_cantidad_capas_ocultas = 3 #@param {type:"integer"}
cnn_agregar_capa_BatchNormalization = True #@param {type:"boolean"}
cnn_cantidad_neuronas_Dense = 16 #@param {type:"integer"}
cnn_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]
cnn_cant_epocas_entrenamiento = 350 #@param {type:"integer"}

## aplicación de los parámetros elegidos

# tamaño de los kernels y pooling (para simplificar son todas iguales)
if cnn_tamaño_kernel<1:
  cnn_tamaño_kernel = 1
cnn_kernel_shape = (cnn_tamaño_kernel)
if cnn_tamaño_pooling<1:
  cnn_tamaño_pooling=1
cnn_pooling_shape = (cnn_tamaño_pooling)

# indica la configuración para la parte Encoder 
#   (cada elemento de las listas son la configuración de las capas Conv)
if cnn_cantidad_capas_ocultas<1:
  cnn_cantidad_capas_ocultas = 1
cnn_filters = []
for i in range(cnn_cantidad_capas_ocultas, 0, -1):
  cnn_filters.append( 2**(i+2) )

# define tamaño de capa densa previa a la de salida
num_Dense_out = (8 if cnn_cantidad_neuronas_Dense<1 else cnn_cantidad_neuronas_Dense)

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (cnn_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if cnn_cant_epocas_entrenamiento<1 else cnn_cant_epocas_entrenamiento)

print("Configuración de la CNN definida: ")
print ("     -Kernels + Pooling: [", cnn_kernel_shape, "+", cnn_pooling_shape, "] ")
print ("     -Capas: [ ", matrixShape, ", Conv", cnn_filters, (", BatchNormalization" if  cnn_agregar_capa_BatchNormalization else "" ), ", FLATTEN, Dense[", num_Dense_out, "], ", ("Softmax" if tipo_output_softMax else "Dense[1] "))
# Out:
# Configuración de la CNN definida:
#      -Kernels + Pooling: [ 2 + 2 ]
#      -Capas: [  [2, 2] , Conv [32, 16, 8] , BatchNormalization , FLATTEN, Dense[ 16 ],  Softmax

# %%
#@title Establecer modelo

# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=((matrixShape[0], matrixShape[1])), name='input_img') # capa de entrada
eachLay = input_img_Lay
auxId = 1 
for i in range(len(cnn_filters)):  
       
    # define el nombre de la capa oculta
    auxlayerName = 'conv_'+str(auxId)
    auxId = auxId + 1

    # agrega las capas ocultas de tipo Conv2D + MaxPooling 
    eachLay = Conv1D(cnn_filters[i], cnn_kernel_shape, activation='relu', padding='same', name='c_'+auxlayerName)(eachLay) 
    eachLay = MaxPooling1D(cnn_pooling_shape, padding='same', name='p_'+auxlayerName)(eachLay)


if cnn_agregar_capa_BatchNormalization:
  # nota: para convNet no se usa DropOut, conviene usar BatchNormalization
  eachLay = BatchNormalization(name='bn')(eachLay)

#  agrega capa Flatten y Dense 
eachLay = Flatten(name='flat_'+auxlayerName)(eachLay)
eachLay = Dense(num_Dense_out, activation='relu', name='d_'+auxlayerName)(eachLay)

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(CLASES), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
#model.compile(optimizer='rmsprop', loss='mse', metrics=['accuracy'])
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  11  capas:
# Model: "RNA"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_img (InputLayer)       [(None, 2, 2)]            0
# _________________________________________________________________
# c_conv_1 (Conv1D)            (None, 2, 32)             160
# _________________________________________________________________
# p_conv_1 (MaxPooling1D)      (None, 1, 32)             0
# _________________________________________________________________
# c_conv_2 (Conv1D)            (None, 1, 16)             1040
# _________________________________________________________________
# p_conv_2 (MaxPooling1D)      (None, 1, 16)             0
# _________________________________________________________________
# c_conv_3 (Conv1D)            (None, 1, 8)              264
# _________________________________________________________________
# p_conv_3 (MaxPooling1D)      (None, 1, 8)              0
# _________________________________________________________________
# bn (BatchNormalization)      (None, 1, 8)              32
# _________________________________________________________________
# flat_conv_3 (Flatten)        (None, 8)                 0
# _________________________________________________________________
# d_conv_3 (Dense)             (None, 16)                144
# _________________________________________________________________
# output (Dense)               (None, 4)                 68
# =================================================================
# Total params: 1,708
# Trainable params: 1,692
# Non-trainable params: 16
# _________________________________________________________________

# %% [markdown]
# 4) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(matrixTrain, 
                                       (y_trainEnc if tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,) ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  104 ejemplos de entrenamiento:
#             se usan  93 ejemplos para entrenar
#             y  11 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/350
# 3/3 [==============================] - 1s 106ms/step - loss: 1.0360 - accuracy: 0.6559 - val_loss: 1.2986 - val_accuracy: 0.5455
# Epoch 2/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.9680 - accuracy: 0.6667 - val_loss: 1.2769 - val_accuracy: 0.5455
# Epoch 3/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.9284 - accuracy: 0.6667 - val_loss: 1.2594 - val_accuracy: 0.5455
# Epoch 4/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8849 - accuracy: 0.6667 - val_loss: 1.2440 - val_accuracy: 0.5455
# Epoch 5/350
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8667 - accuracy: 0.6667 - val_loss: 1.2304 - val_accuracy: 0.5455
# Epoch 6/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.8456 - accuracy: 0.6667 - val_loss: 1.2193 - val_accuracy: 0.5455
# Epoch 7/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.8010 - accuracy: 0.6667 - val_loss: 1.2089 - val_accuracy: 0.5455
# Epoch 8/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7872 - accuracy: 0.6667 - val_loss: 1.1987 - val_accuracy: 0.5455
# Epoch 9/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.7648 - accuracy: 0.6667 - val_loss: 1.1892 - val_accuracy: 0.5455
# Epoch 10/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7390 - accuracy: 0.6667 - val_loss: 1.1795 - val_accuracy: 0.5455
# Epoch 11/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7263 - accuracy: 0.6667 - val_loss: 1.1698 - val_accuracy: 0.5455
# Epoch 12/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7124 - accuracy: 0.6667 - val_loss: 1.1587 - val_accuracy: 0.5455
# Epoch 13/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6886 - accuracy: 0.6667 - val_loss: 1.1483 - val_accuracy: 0.5455
# Epoch 14/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6781 - accuracy: 0.6774 - val_loss: 1.1373 - val_accuracy: 0.5455
# Epoch 15/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6603 - accuracy: 0.6667 - val_loss: 1.1269 - val_accuracy: 0.5455
# Epoch 16/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6558 - accuracy: 0.6989 - val_loss: 1.1215 - val_accuracy: 0.6364
# Epoch 17/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6390 - accuracy: 0.6882 - val_loss: 1.1161 - val_accuracy: 0.6364
# Epoch 18/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6204 - accuracy: 0.6882 - val_loss: 1.1126 - val_accuracy: 0.6364
# Epoch 19/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6212 - accuracy: 0.7097 - val_loss: 1.1068 - val_accuracy: 0.7273
# Epoch 20/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6093 - accuracy: 0.7204 - val_loss: 1.0909 - val_accuracy: 0.7273
# Epoch 21/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5955 - accuracy: 0.6882 - val_loss: 1.0706 - val_accuracy: 0.7273
# Epoch 22/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5897 - accuracy: 0.7097 - val_loss: 1.0521 - val_accuracy: 0.7273
# Epoch 23/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5788 - accuracy: 0.7634 - val_loss: 1.0438 - val_accuracy: 0.7273
# Epoch 24/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5673 - accuracy: 0.7204 - val_loss: 1.0397 - val_accuracy: 0.7273
# Epoch 25/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.
350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0901 - accuracy: 0.9785 - val_loss: 0.2170 - val_accuracy: 1.0000
# Epoch 118/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1061 - accuracy: 0.9677 - val_loss: 0.2132 - val_accuracy: 1.0000
# Epoch 119/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0717 - accuracy: 0.9677 - val_loss: 0.1916 - val_accuracy: 1.0000
# Epoch 120/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0634 - accuracy: 0.9892 - val_loss: 0.2026 - val_accuracy: 1.0000
# Epoch 121/350
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0615 - accuracy: 0.9892 - val_loss: 0.2289 - val_accuracy: 1.0000
# Epoch 122/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0641 - accuracy: 0.9785 - val_loss: 0.2212 - val_accuracy: 1.0000
# Epoch 123/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0727 - accuracy: 0.9892 - val_loss: 0.2039 - val_accuracy: 1.0000
# Epoch 124/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0737 - accuracy: 0.9677 - val_loss: 0.1922 - val_accuracy: 1.0000
# Epoch 125/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0757 - accuracy: 0.9677 - val_loss: 0.1781 - val_accuracy: 1.0000
# Epoch 126/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0674 - accuracy: 0.9785 - val_loss: 0.1876 - val_accuracy: 1.0000
# Epoch 127/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0655 - accuracy: 0.9677 - val_loss: 0.1886 - val_accuracy: 1.0000
# Epoch 128/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0663 - accuracy: 0.9785 - val_loss: 0.1906 - val_accuracy: 1.0000
# Epoch 129/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0615 - accuracy: 0.9785 - val_loss: 0.1775 - val_accuracy: 1.0000
# Epoch 130/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0780 - accuracy: 0.9785 - val_loss: 0.1812 - val_accuracy: 1.0000
# Epoch 131/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1509 - accuracy: 0.9355 - val_loss: 0.2097 - val_accuracy: 1.0000
# Epoch 132/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0883 - accuracy: 0.9785 - val_loss: 0.1749 - val_accuracy: 0.9091
# Epoch 133/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0879 - accuracy: 0.9570 - val_loss: 0.1586 - val_accuracy: 0.9091
# Epoch 134/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0714 - accuracy: 0.9677 - val_loss: 0.1522 - val_accuracy: 1.0000
# Epoch 135/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1083 - accuracy: 0.9462 - val_loss: 0.1795 - val_accuracy: 0.9091
# Epoch 136/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0746 - accuracy: 0.9570 - val_loss: 0.1855 - val_accuracy: 0.9091
# Epoch 137/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0712 - accuracy: 0.9677 - val_loss: 0.1598 - val_accuracy: 1.0000
# Epoch 138/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0852 - accuracy: 0.9677 - val_loss: 0.1472 - val_accuracy: 1.0000
# Epoch 139/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0708 - accuracy: 0.9785 - val_loss: 0.1463 - val_accuracy: 1.0000
# Epoch 140/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0655 - accuracy: 0.9785 - val_loss: 0.1441 - val_accuracy: 1.0000
# Epoch 141/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0755 - accuracy: 0.9892 - val_loss: 0.1534 - val_accuracy: 1.0000
# Epoch 142/350
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0708 - accuracy: 0.9892 - val_loss: 0.1993 - val_accuracy: 0.9091
# Epoch 143/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0729 - accuracy: 0.9785 - val_loss: 0.1843 - val_accuracy: 0.9091
# Epoch 144/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0650 - accuracy: 0.9785 - val_loss: 0.1379 - val_accuracy: 0.9091
# Epoch 145/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0743 - accuracy: 0.9785 - val_loss: 0.1480 - val_accuracy: 0.9091
# Epoch 146/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0827 - accuracy: 0.9677 - val_loss: 0.1387 - val_accuracy: 0.9091
# Epoch 147/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0817 - accuracy: 0.9677 - val_loss: 0.1323 - val_accuracy: 0.9091
# Epoch 148/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0797 - accuracy: 0.9785 - val_loss: 0.1333 - val_accuracy: 1.0000
# Epoch 149/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0618 - accuracy: 0.9892 - val_loss: 0.1585 - val_accuracy: 1.0000
# Epoch 150/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0698 - accuracy: 0.9785 - val_loss: 0.1430 - val_accuracy: 1.0000
# Epoch 151/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0700 - accuracy: 0.9785 - val_loss: 0.1329 - val_accuracy: 0.9091
# Epoch 152/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0783 - accuracy: 0.9570 - val_loss: 0.1443 - val_accuracy: 0.9091
# Epoch 153/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1096 - accuracy: 0.9570 - val_loss: 0.1411 - val_accuracy: 0.9091
# Epoch 154/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0621 - accuracy: 0.9785 - val_loss: 0.1244 - val_accuracy: 0.9091
# Epoch 155/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0627 - accuracy: 0.9892 - val_loss: 0.1299 - val_accuracy: 1.0000
# Epoch 156/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0883 - accuracy: 0.9570 - val_loss: 0.1276 - val_accuracy: 1.0000
# Epoch 157/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0797 - accuracy: 0.9570 - val_loss: 0.1332 - val_accuracy: 1.0000
# Epoch 158/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0629 - accuracy: 0.9785 - val_loss: 0.1524 - val_accuracy: 1.0000
# Epoch 159/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0733 - accuracy: 0.9677 - val_loss: 0.1382 - val_accuracy: 0.9091
# Epoch 160/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0893 - accuracy: 0.9570 - val_loss: 0.1355 - val_accuracy: 0.9091
# Epoch 161/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0737 - accuracy: 0.9892 - val_loss: 0.1397 - val_accuracy: 0.9091
# Epoch 162/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0601 - accuracy: 0.9785 - val_loss: 0.1351 - val_accuracy: 0.9091
# Epoch 163/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0659 - accuracy: 0.9677 - val_loss: 0.1277 - val_accuracy: 0.9091
# Epoch 164/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0575 - accuracy: 0.9677 - val_loss: 0.1297 - val_accuracy: 0.9091
# Epoch 165/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0830 - accuracy: 0.9785 - val_loss: 0.1281 - val_accuracy: 0.9091
# Epoch 166/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0706 - accuracy: 0.9677 - val_loss: 0.1251 - val_accuracy: 0.9091
# Epoch 167/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0584 - accuracy: 0.9785 - val_loss: 0.1176 - val_accuracy: 1.0000
# Epoch 168/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0741 - accuracy: 0.9677 - val_loss: 0.1276 - val_accuracy: 1.0000
# Epoch 169/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0681 - accuracy: 0.9570 - val_loss: 0.1557 - val_accuracy: 0.9091
# Epoch 170/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0919 - accuracy: 0.9677 - val_loss: 0.1585 - val_accuracy: 0.9091
# Epoch 171/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0969 - accuracy: 0.9570 - val_loss: 0.1210 - val_accuracy: 1.0000
# Epoch 172/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0818 - accuracy: 0.9785 - val_loss: 0.1203 - val_accuracy: 0.9091
# Epoch 173/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0523 - accuracy: 0.9892 - val_loss: 0.1405 - val_accuracy: 0.9091
# Epoch 174/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0783 - accuracy: 0.9677 - val_loss: 0.1398 - val_accuracy: 0.9091
# Epoch 175/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0549 - accuracy: 0.9785 - val_loss: 0.1173 - val_accuracy: 0.9091
# Epoch 176/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0588 - accuracy: 0.9892 - val_loss: 0.1113 - val_accuracy: 1.0000
# Epoch 177/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0514 - accuracy: 0.9892 - val_loss: 0.1213 - val_accuracy: 1.0000
# Epoch 178/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0517 - accuracy: 0.9892 - val_loss: 0.1388 - val_accuracy: 0.9091
# Epoch 179/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0781 - accuracy: 0.9785 - val_loss: 0.1177 - val_accuracy: 0.9091
# Epoch 180/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0859 - accuracy: 0.9785 - val_loss: 0.1157 - val_accuracy: 0.9091
# Epoch 181/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0658 - accuracy: 0.9785 - val_loss: 0.1067 - val_accuracy: 1.0000
# Epoch 182/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0997 - accuracy: 0.9570 - val_loss: 0.1058 - val_accuracy: 0.9091
# Epoch 183/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0549 - accuracy: 0.9785 - val_loss: 0.1065 - val_accuracy: 1.0000
# Epoch 184/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0683 - accuracy: 0.9785 - val_loss: 0.1248 - val_accuracy: 0.9091
# Epoch 185/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0600 - accuracy: 0.9785 - val_loss: 0.1213 - val_accuracy: 1.0000
# Epoch 186/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0591 - accuracy: 0.9785 - val_loss: 0.1006 - val_accuracy: 1.0000
# Epoch 187/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0637 - accuracy: 0.9677 - val_loss: 0.1176 - val_accuracy: 0.9091
# Epoch 188/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0642 - accuracy: 0.9677 - val_loss: 0.1297 - val_accuracy: 0.9091
# Epoch 189/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0673 - accuracy: 0.9785 - val_loss: 0.1078 - val_accuracy: 0.9091
# Epoch 190/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0621 - accuracy: 0.9785 - val_loss: 0.0992 - val_accuracy: 1.0000
# Epoch 191/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0785 - accuracy: 0.9570 - val_loss: 0.0986 - val_accuracy: 1.0000
# Epoch 192/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0526 - accuracy: 0.9677 - val_loss: 0.1117 - val_accuracy: 1.0000
# Epoch 193/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0952 - accuracy: 0.9677 - val_loss: 0.1074 - val_accuracy: 0.9091
# Epoch 194/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0463 - accuracy: 0.9892 - val_loss: 0.0975 - val_accuracy: 1.0000
# Epoch 195/350
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0585 - accuracy: 0.9785 - val_loss: 0.1107 - val_accuracy: 1.0000
# Epoch 196/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0609 - accuracy: 0.9785 - val_loss: 0.1059 - val_accuracy: 1.0000
# Epoch 197/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0565 - accuracy: 0.9677 - val_loss: 0.0985 - val_accuracy: 1.0000
# Epoch 198/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0512 - accuracy: 0.9677 - val_loss: 0.1085 - val_accuracy: 0.9091
# Epoch 199/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0572 - accuracy: 0.9785 - val_loss: 0.1242 - val_accuracy: 0.9091
# Epoch 200/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0550 - accuracy: 0.9892 - val_loss: 0.1326 - val_accuracy: 0.9091
# Epoch 201/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1152 - accuracy: 0.9677 - val_loss: 0.1320 - val_accuracy: 0.9091
# Epoch 202/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0557 - accuracy: 0.9892 - val_loss: 0.0944 - val_accuracy: 1.0000
# Epoch 203/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0546 - accuracy: 0.9785 - val_loss: 0.1344 - val_accuracy: 0.9091
# Epoch 204/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0795 - accuracy: 0.9677 - val_loss: 0.1037 - val_accuracy: 1.0000
# Epoch 205/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0687 - accuracy: 0.9785 - val_loss: 0.1128 - val_accuracy: 1.0000
# Epoch 206/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0597 - accuracy: 0.9677 - val_loss: 0.0979 - val_accuracy: 1.0000
# Epoch 207/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0617 - accuracy: 0.9785 - val_loss: 0.0967 - val_accuracy: 1.0000
# Epoch 208/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0837 - accuracy: 0.9570 - val_loss: 0.1143 - val_accuracy: 0.9091
# Epoch 209/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0447 - accuracy: 0.9892 - val_loss: 0.1066 - val_accuracy: 0.9091
# Epoch 210/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0530 - accuracy: 0.9785 - val_loss: 0.0964 - val_accuracy: 1.0000
# Epoch 211/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1083 - accuracy: 0.9677 - val_loss: 0.1186 - val_accuracy: 0.9091
# Epoch 212/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0664 - accuracy: 0.9677 - val_loss: 0.1447 - val_accuracy: 0.9091
# Epoch 213/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0769 - accuracy: 0.9677 - val_loss: 0.1228 - val_accuracy: 0.9091
# Epoch 214/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0568 - accuracy: 0.9677 - val_loss: 0.1059 - val_accuracy: 1.0000
# Epoch 215/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0582 - accuracy: 0.9677 - val_loss: 0.1415 - val_accuracy: 0.9091
# Epoch 216/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0806 - accuracy: 0.9677 - val_loss: 0.1198 - val_accuracy: 0.9091
# Epoch 217/350
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0856 - accuracy: 0.9570 - val_loss: 0.1331 - val_accuracy: 0.9091
# Epoch 218/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0550 - accuracy: 0.9785 - val_loss: 0.1688 - val_accuracy: 0.9091
# Epoch 219/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0716 - accuracy: 0.9677 - val_loss: 0.1924 - val_accuracy: 0.9091
# Epoch 220/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0550 - accuracy: 0.9677 - val_loss: 0.1818 - val_accuracy: 0.9091
# Epoch 221/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0757 - accuracy: 0.9570 - val_loss: 0.1422 - val_accuracy: 0.9091
# Epoch 222/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0520 - accuracy: 0.9785 - val_loss: 0.1269 - val_accuracy: 0.9091
# Epoch 223/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0706 - accuracy: 0.9570 - val_loss: 0.1192 - val_accuracy: 0.9091
# Epoch 224/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0928 - accuracy: 0.9570 - val_loss: 0.1101 - val_accuracy: 0.9091
# Epoch 225/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0653 - accuracy: 0.9677 - val_loss: 0.1551 - val_accuracy: 0.9091
# Epoch 226/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0586 - accuracy: 0.9785 - val_loss: 0.1736 - val_accuracy: 0.9091
# Epoch 227/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1110 - accuracy: 0.9462 - val_loss: 0.2094 - val_accuracy: 0.8182
# Epoch 228/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0647 - accuracy: 0.9892 - val_loss: 0.1367 - val_accuracy: 0.9091
# Epoch 229/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0712 - accuracy: 0.9677 - val_loss: 0.1446 - val_accuracy: 0.9091
# Epoch 230/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0493 - accuracy: 0.9785 - val_loss: 0.1259 - val_accuracy: 0.9091
# Epoch 231/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0879 - accuracy: 0.9677 - val_loss: 0.1088 - val_accuracy: 0.9091
# Epoch 232/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0569 - accuracy: 0.9785 - val_loss: 0.1093 - val_accuracy: 0.9091
# Epoch 233/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0596 - accuracy: 0.9677 - val_loss: 0.1144 - val_accuracy: 0.9091
# Epoch 234/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0556 - accuracy: 0.9892 - val_loss: 0.1170 - val_accuracy: 0.9091
# Epoch 235/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0555 - accuracy: 0.9785 - val_loss: 0.1131 - val_accuracy: 0.9091
# Epoch 236/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0510 - accuracy: 0.9785 - val_loss: 0.1099 - val_accuracy: 1.0000
# Epoch 237/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0854 - accuracy: 0.9677 - val_loss: 0.1137 - val_accuracy: 1.0000
# Epoch 238/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0640 - accuracy: 0.9785 - val_loss: 0.1143 - val_accuracy: 1.0000
# Epoch 239/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0569 - accuracy: 0.9677 - val_loss: 0.1123 - val_accuracy: 1.0000
# Epoch 240/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0496 - accuracy: 0.9785 - val_loss: 0.1087 - val_accuracy: 1.0000
# Epoch 241/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0547 - accuracy: 0.9785 - val_loss: 0.1061 - val_accuracy: 0.9091
# Epoch 242/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0529 - accuracy: 0.9785 - val_loss: 0.1138 - val_accuracy: 0.9091
# Epoch 243/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0640 - accuracy: 0.9570 - val_loss: 0.1155 - val_accuracy: 0.9091
# Epoch 244/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0660 - accuracy: 0.9677 - val_loss: 0.1104 - val_accuracy: 0.9091
# Epoch 245/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0558 - accuracy: 0.9892 - val_loss: 0.1057 - val_accuracy: 0.9091
# Epoch 246/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0556 - accuracy: 0.9785 - val_loss: 0.1074 - val_accuracy: 0.9091
# Epoch 247/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0515 - accuracy: 0.9785 - val_loss: 0.1005 - val_accuracy: 1.0000
# Epoch 248/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0353 - accuracy: 0.9892 - val_loss: 0.1021 - val_accuracy: 1.0000
# Epoch 249/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0876 - accuracy: 0.9677 - val_loss: 0.1323 - val_accuracy: 0.9091
# Epoch 250/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0724 - accuracy: 0.9677 - val_loss: 0.1460 - val_accuracy: 0.9091
# Epoch 251/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0602 - accuracy: 0.9892 - val_loss: 0.1456 - val_accuracy: 0.9091
# Epoch 252/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0855 - accuracy: 0.9462 - val_loss: 0.1434 - val_accuracy: 0.9091
# Epoch 253/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0516 - accuracy: 0.9785 - val_loss: 0.1118 - val_accuracy: 0.9091
# Epoch 254/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0740 - accuracy: 0.9785 - val_loss: 0.1022 - val_accuracy: 1.0000
# Epoch 255/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0527 - accuracy: 0.9785 - val_loss: 0.1216 - val_accuracy: 0.9091
# Epoch 256/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0457 - accuracy: 0.9785 - val_loss: 0.1027 - val_accuracy: 1.0000
# Epoch 257/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0380 - accuracy: 0.9785 - val_loss: 0.1018 - val_accuracy: 0.9091
# Epoch 258/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0506 - accuracy: 0.9785 - val_loss: 0.1128 - val_accuracy: 0.9091
# Epoch 259/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0512 - accuracy: 0.9892 - val_loss: 0.1033 - val_accuracy: 0.9091
# Epoch 260/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0714 - accuracy: 0.9570 - val_loss: 0.1152 - val_accuracy: 0.9091
# Epoch 261/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0596 - accuracy: 0.9785 - val_loss: 0.1318 - val_accuracy: 0.9091
# Epoch 262/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0643 - accuracy: 0.9677 - val_loss: 0.1508 - val_accuracy: 0.9091
# Epoch 263/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1009 - accuracy: 0.9570 - val_loss: 0.1786 - val_accuracy: 0.9091
# Epoch 264/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0659 - accuracy: 0.9677 - val_loss: 0.1089 - val_accuracy: 0.9091
# Epoch 265/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0729 - accuracy: 0.9570 - val_loss: 0.1285 - val_accuracy: 0.9091
# Epoch 266/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0692 - accuracy: 0.9785 - val_loss: 0.1143 - val_accuracy: 0.9091
# Epoch 267/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0689 - accuracy: 0.9785 - val_loss: 0.1133 - val_accuracy: 0.9091
# Epoch 268/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0605 - accuracy: 0.9677 - val_loss: 0.1375 - val_accuracy: 0.9091
# Epoch 269/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0789 - accuracy: 0.9462 - val_loss: 0.1391 - val_accuracy: 0.9091
# Epoch 270/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.
350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0629 - accuracy: 0.9785 - val_loss: 0.1137 - val_accuracy: 0.9091
# Epoch 302/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0447 - accuracy: 0.9785 - val_loss: 0.1154 - val_accuracy: 0.9091
# Epoch 303/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0515 - accuracy: 0.9785 - val_loss: 0.1209 - val_accuracy: 0.9091
# Epoch 304/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0422 - accuracy: 0.9892 - val_loss: 0.1243 - val_accuracy: 0.9091
# Epoch 305/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0567 - accuracy: 0.9785 - val_loss: 0.1412 - val_accuracy: 0.9091
# Epoch 306/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0576 - accuracy: 0.9570 - val_loss: 0.1237 - val_accuracy: 0.9091
# Epoch 307/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0421 - accuracy: 0.9785 - val_loss: 0.1099 - val_accuracy: 1.0000
# Epoch 308/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0521 - accuracy: 0.9785 - val_loss: 0.1062 - val_accuracy: 1.0000
# Epoch 309/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0500 - accuracy: 0.9785 - val_loss: 0.1011 - val_accuracy: 1.0000
# Epoch 310/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0569 - accuracy: 0.9677 - val_loss: 0.1424 - val_accuracy: 0.9091
# Epoch 311/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0841 - accuracy: 0.9570 - val_loss: 0.1576 - val_accuracy: 0.9091
# Epoch 312/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0519 - accuracy: 0.9892 - val_loss: 0.1084 - val_accuracy: 0.9091
# Epoch 313/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0502 - accuracy: 0.9785 - val_loss: 0.1233 - val_accuracy: 0.9091
# Epoch 314/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0600 - accuracy: 0.9677 - val_loss: 0.1247 - val_accuracy: 0.9091
# Epoch 315/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0483 - accuracy: 0.9785 - val_loss: 0.1139 - val_accuracy: 0.9091
# Epoch 316/350
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0735 - accuracy: 0.9570 - val_loss: 0.1152 - val_accuracy: 0.9091
# Epoch 317/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0658 - accuracy: 0.9677 - val_loss: 0.1189 - val_accuracy: 0.9091
# Epoch 318/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0526 - accuracy: 0.9785 - val_loss: 0.1120 - val_accuracy: 1.0000
# Epoch 319/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1321 - accuracy: 0.9355 - val_loss: 0.1320 - val_accuracy: 0.9091
# Epoch 320/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0518 - accuracy: 0.9785 - val_loss: 0.1209 - val_accuracy: 1.0000
# Epoch 321/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0375 - accuracy: 0.9892 - val_loss: 0.1166 - val_accuracy: 1.0000
# Epoch 322/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0506 - accuracy: 0.9785 - val_loss: 0.1172 - val_accuracy: 0.9091
# Epoch 323/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0488 - accuracy: 0.9785 - val_loss: 0.1298 - val_accuracy: 0.9091
# Epoch 324/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0642 - accuracy: 0.9785 - val_loss: 0.1400 - val_accuracy: 0.9091
# Epoch 325/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0486 - accuracy: 0.9785 - val_loss: 0.1362 - val_accuracy: 0.9091
# Epoch 326/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0525 - accuracy: 0.9677 - val_loss: 0.1079 - val_accuracy: 0.9091
# Epoch 327/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0527 - accuracy: 0.9785 - val_loss: 0.1077 - val_accuracy: 1.0000
# Epoch 328/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0619 - accuracy: 0.9785 - val_loss: 0.1149 - val_accuracy: 1.0000
# Epoch 329/350
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0572 - accuracy: 0.9785 - val_loss: 0.1093 - val_accuracy: 0.9091
# Epoch 330/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0600 - accuracy: 0.9570 - val_loss: 0.1332 - val_accuracy: 0.9091
# Epoch 331/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0500 - accuracy: 0.9785 - val_loss: 0.1101 - val_accuracy: 0.9091
# Epoch 332/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0410 - accuracy: 0.9892 - val_loss: 0.1090 - val_accuracy: 1.0000
# Epoch 333/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0565 - accuracy: 0.9785 - val_loss: 0.1103 - val_accuracy: 1.0000
# Epoch 334/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0406 - accuracy: 0.9785 - val_loss: 0.1206 - val_accuracy: 0.9091
# Epoch 335/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0627 - accuracy: 0.9785 - val_loss: 0.1709 - val_accuracy: 0.9091
# Epoch 336/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0446 - accuracy: 0.9785 - val_loss: 0.1699 - val_accuracy: 0.9091
# Epoch 337/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0851 - accuracy: 0.9677 - val_loss: 0.1479 - val_accuracy: 0.9091
# Epoch 338/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0605 - accuracy: 0.9570 - val_loss: 0.1206 - val_accuracy: 0.9091
# Epoch 339/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0765 - accuracy: 0.9892 - val_loss: 0.1238 - val_accuracy: 0.9091
# Epoch 340/350
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0577 - accuracy: 0.9785 - val_loss: 0.1261 - val_accuracy: 0.9091
# Epoch 341/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0739 - accuracy: 0.9677 - val_loss: 0.0953 - val_accuracy: 0.9091
# Epoch 342/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0505 - accuracy: 0.9785 - val_loss: 0.0929 - val_accuracy: 0.9091
# Epoch 343/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0572 - accuracy: 0.9785 - val_loss: 0.1190 - val_accuracy: 0.9091
# Epoch 344/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0450 - accuracy: 0.9892 - val_loss: 0.1075 - val_accuracy: 0.9091
# Epoch 345/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0712 - accuracy: 0.9785 - val_loss: 0.0976 - val_accuracy: 1.0000
# Epoch 346/350
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0702 - accuracy: 0.9570 - val_loss: 0.1001 - val_accuracy: 1.0000
# Epoch 347/350
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0421 - accuracy: 0.9892 - val_loss: 0.1249 - val_accuracy: 0.9091
# Epoch 348/350
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0518 - accuracy: 0.9892 - val_loss: 0.1591 - val_accuracy: 0.9091
# Epoch 349/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0723 - accuracy: 0.9677 - val_loss: 0.1727 - val_accuracy: 0.9091
# Epoch 350/350
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0562 - accuracy: 0.9785 - val_loss: 0.1860 - val_accuracy: 0.9091
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, clases_map):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # prepara salida
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA"
        else:      
            clPred = clases_map[ idclPredRnd ]

        classReal.append( clReal )
        classPreds.append( clPred )

        strTitulo = 'Real: ' + clReal + ' / RNA: ' 
        strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'   
        strTitulo = strTitulo + ": " + ("ok" if (clPred==clReal) else "error!")

        # muestra comparación con la imagen
        print(strTitulo)

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    # agrega para poder mostrar la matrix de confusión completa
    pd.options.display.max_rows = 100
    pd.options.display.max_columns = 100
    print(cmtx)
    print("\n")

    # gráfico de comparación
    plt.title('Gráfico de Confusión:')
    plt.xlabel('Real')
    plt.ylabel('RNA')
    plt.scatter(classReal, classPreds)

# prueba con los datos de entrenamiento
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(matrixTrain, y_train, CLASES)
# Out:
# *** Resultados con datos de Entrenamiento:
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Virginica (3): error!
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Virginica (3): error!
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Virginica (3): error!
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Virginica (3): error!
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        35
#   Versicolor       1.00      0.88      0.94        34
#    Virginica       0.90      1.00      0.95        35
#
#     accuracy                           0.96       104
#    macro avg       0.97      0.96      0.96       104
# weighted avg       0.97      0.96      0.96       104
#
#
# Matriz de Confusión:
#               p:na  p:Setosa  p:Versicolor  p:Virginica
# r:na             0         0             0            0
# r:Setosa         0        35             0            0
# r:Versicolor     0         0            30            4
# r:Virginica      0         0             0           35

# %% [markdown]
# 6) Evaluar el modelo de la RNA entrenado con los datos de prueba:

# %%
 #@title Probar red entrenada con datos de prueba
 # evalua al modelo entrenado
resEval = model.evaluate(matrixTest, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de prueba
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(matrixTest, y_test, CLASES)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9783
#
# >Evaluación del Modelo:
#     - Error:  0.06525056064128876
#     - Exactitud:  97.826087474823
#
#
#
#
# *** Resultados con datos de Prueba:
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Virginica (3): error!
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Versicolor / RNA: Versicolor (2): ok
# Real: Virginica / RNA: Virginica (3): ok
# Real: Setosa / RNA: Setosa (1): ok
# Real: Virginica / RNA: Virginica (3): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        15
#   Versicolor       1.00      0.94      0.97        16
#    Virginica       0.94      1.00      0.97        15
#
#     accuracy                           0.98        46
#    macro avg       0.98      0.98      0.98        46
# weighted avg       0.98      0.98      0.98        46
#
#
# Matriz de Confusión:
#               p:na  p:Setosa  p:Versicolor  p:Virginica
# r:na             0         0             0            0
# r:Setosa         0        15             0            0
# r:Versicolor     0         0            15            1
# r:Virginica      0         0             0           15
