# %% [markdown]
# # Demo de Deep Convolutional Inverse Graphics Network (DCIGN) para colorear las imágenes

# %% [markdown]
# 1) Importar librerías:

# %%
#@title Librerías a usar
import tensorflow.keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Reshape, Flatten
from tensorflow.keras.layers import UpSampling2D, Conv2DTranspose, BatchNormalization
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

from PIL import Image

print("\nLibrerías importadas")
# Out:
# Librerías importadas

# %% [markdown]
# 2) Definir la configuración del modelo DCIGN:

# %%
## selección de los parámetros 

#@markdown ### Parámetros de imágenes:
imagen_largo_ancho =  128#@param {type:"integer"}

#@markdown ### Parámetros de la red:
dae_tamaño_kernel = 3 #@param {type:"integer"}
dae_tamaño_pooling = 2 #@param {type:"integer"}
dae_cantidad_capas_ocultas = 6 #@param {type:"integer"}
dae_tipo_capas = 'LeakyReLU' #@param [ 'Conv2D + UpSampling', 'Conv2DTranspose + BatchNormalization', 'LeakyReLU']

dae_cant_epocas_entrenamiento = 2500 #@param {type:"integer"}

## aplicación de los parámetros elegidos

# tamaño de las imágenes
if imagen_largo_ancho<=10:
  imagen_largo_ancho = 10
IMAGE_SHAPE = (imagen_largo_ancho, imagen_largo_ancho, 3)

# indica si se usan las imágenes generadas por data augmentation
usarDA = False

# tamaño de los kernels y pooling (para simplificar son todas iguales)
if dae_tamaño_kernel<1:
  dae_tamaño_kernel = 1
dae_kernel_shape = (dae_tamaño_kernel, dae_tamaño_kernel)
if dae_tamaño_pooling<1:
  dae_tamaño_pooling=1
dae_pooling_shape = (dae_tamaño_pooling, dae_tamaño_pooling)

# indica la configuración para la parte Encoder 
#   (cada elemento de las listas son la configuración de las capas Conv)
if dae_cantidad_capas_ocultas<1:
  dae_cantidad_capas_ocultas = 1
dae_filters = []
for i in range(dae_cantidad_capas_ocultas, 0, -1):
  dae_filters.append( 2**(i+2) )

# la capa de features se define automáticamente 
# en base a la información de la última capa del Encoder
dae_filters.append( 'f' ) 
dae_posLayFeat = len(dae_filters)-1

# cantidad de neuronas ocultas para la parte Decoder 
#   (usa la la lista de Encoder inversa)
for eachEncFilter in dae_filters[0:len(dae_filters)-1][::-1]:
      dae_filters.append( eachEncFilter )


# indica si el Decoder usa:
#  ver 1: Conv2D + UpSampling (mejores colores pero fuera de foco)
#  ver 2: Conv2DTranspose + BatchNormalization (mejor nitidez pero como manchada)
if dae_tipo_capas == 'Conv2D + UpSampling':
  verCapasDecoder = 1
elif dae_tipo_capas == 'LeakyReLU':
  verCapasDecoder = 3
else:
  verCapasDecoder = 2

# cantidad de épocas del entrenamiento
cantEpocas = (100 if dae_cant_epocas_entrenamiento<1 else dae_cant_epocas_entrenamiento)

print("Configuración del DAE CNN definida: ")
print ("     -Kernels + Pooling: [", IMAGE_SHAPE, "[", dae_kernel_shape, "+", dae_pooling_shape, "]", IMAGE_SHAPE, "] ")
print ("     -Versión Decoder: ", dae_tipo_capas, "(", verCapasDecoder,  ") ")
print ("     -Cant. de Filters: [ -,", dae_filters,  ",- ] ")
# Out:
# Configuración del DAE CNN definida:
#      -Kernels + Pooling: [ (128, 128, 3) [ (3, 3) + (2, 2) ] (128, 128, 3) ]
#      -Versión Decoder:  LeakyReLU ( 3 )
#      -Cant. de Filters: [ -, [256, 128, 64, 32, 16, 8, 'f', 8, 16, 32, 64, 128, 256] ,- ]

# %% [markdown]
# 3) Montar el Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# directorio local en Google Drive
path = 'gdrive/My Drive/IA/demoML/imagenes/IRIS' #@param {type:"string"}
path_entrenamiento = '/train'  #@param {type:"string"}
path_prueba = '/test'  #@param {type:"string"}

imagPath_train = path + path_entrenamiento
imagPath_test = path + path_prueba
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 4) Cargar imágenes para entrenar el modelo DAE:

# %%
#@title Cargar Imágenes (de entrada en blanco y negro, y de salida en color)
# define función para cargar las imágenes
def cargarImagenes(imagPath):
  classes_ori = [] 
  images_ori = []
  esDA_ori = []
  images_sal = []

  all_dirs = os.listdir( imagPath )
  for each_dir in all_dirs:

      auxiPath = imagPath + '/' + each_dir 
      imagFN  = os.listdir( auxiPath )
      for each_imagFN in imagFN:

            esImagDA = (each_imagFN[:2] == 'da')
                  
            # abre la imagen
            imag = Image.open(auxiPath + "/" + each_imagFN)
            
            # ajusta el tamaño     
            tipoImage = 'RGB'
            imag = imag.convert('RGB')
            imag = imag.resize((IMAGE_SHAPE[0], IMAGE_SHAPE[1]), Image.ANTIALIAS)          
            
            imag2 = imag.convert('L')
            imag2 = imag2.convert('RGB')

            # transforma a un vector de nros
            arImag = np.array(imag)
            arImag2 = np.array(imag2)
            
            # agrega a los vectores
            classes_ori.append( each_dir )
            images_ori.append( arImag2 )
            images_sal.append( arImag )
            esDA_ori.append( esImagDA )

  return classes_ori, images_ori, images_sal, esDA_ori, tipoImage

# carga las imagenes de entrenamiento
classes_train, images_train_x, images_train_y, esDAimag_train, tipoImage_train = cargarImagenes(imagPath_train)
print("> Para Entrenamiento: ")
print("- Clases cargadas: ", len(classes_train))
print("- Imágenes cargadas: ", len(images_train_x))

if len(classes_train)>0:
  print("- Ejemplo ", classes_train[0], " ", images_train_x[0].shape, " ", images_train_y[0].shape,  ": ")
  display( Image.fromarray(images_train_x[0], tipoImage_train) )
  display( Image.fromarray(images_train_y[0], tipoImage_train) )

# carga las imagenes de prueba
classes_test, images_test_x, images_test_y, esDAimag_test, tipoImage_test = cargarImagenes(imagPath_test)
print("\n\n> Para Prueba: ")
print("- Clases cargadas: ", len(classes_test))
print("- Imágenes cargadas: ", len(images_test_x))

if len(classes_test)>0:
  print("- Ejemplo ", classes_test[0], " ", images_test_x[0].shape, " ", images_test_y[0].shape, ": ")
  display( Image.fromarray(images_test_x[0], tipoImage_test) )
  display( Image.fromarray(images_test_y[0], tipoImage_test) )
# Out:
# > Para Entrenamiento:
# - Clases cargadas:  57
# - Imágenes cargadas:  57
# - Ejemplo  versicolor   (128, 128, 3)   (128, 128, 3) :
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FB4A8011F50>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FB4A800A850>
# > Para Prueba:
# - Clases cargadas:  33
# - Imágenes cargadas:  33
# - Ejemplo  virginica   (128, 128, 3)   (128, 128, 3) :
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FB4A802FA50>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FB4A8011F90>

# %%
#@title Preparar imágenes

# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8))
    plt.gray()  
  else:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE).astype(np.uint8)) 
  plt.axis("off")  

# define función auxiliar para preparar la lista de imágenes a procesar
def prepare_imageList(imagList):    
  auxiAr = np.array(imagList).astype('float32') / 255.
  auxiAr = auxiAr.reshape((len(auxiAr), IMAGE_SHAPE[0], IMAGE_SHAPE[1], IMAGE_SHAPE[2]))  
  return auxiAr
  
# define vector auxiliar de datos de entrada para usar en el entrenamiento y prueba
x_train = prepare_imageList(images_train_x)
y_train = prepare_imageList(images_train_y)
x_test = prepare_imageList(images_test_x)
y_test = prepare_imageList(images_test_y)

print("> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
print(" - y_train (cant ejemplos, datos entrada): ", y_train.shape)
print("\n\n> Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
print(" - y_test (cant ejemplos, datos entrada): ", y_test.shape)
if len(x_train)>0:
  plot_image(x_train[0])
  plot_image(y_train[0])
# Out:
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (57, 128, 128, 3)
#  - y_train (cant ejemplos, datos entrada):  (57, 128, 128, 3)
#
#
# > Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (33, 128, 128, 3)
#  - y_test (cant ejemplos, datos entrada):  (33, 128, 128, 3)

# %% [markdown]
# 5) Creación del modelo DCIGN:

# %%
#@title Establecer modelo

# define la arquitectura de capas del Deep Autoencoder CNN
# teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=IMAGE_SHAPE, name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'enc_'
auxId = 1 
for i in range(len(dae_filters)):  

    # define el nombre de la capa oculta
    auxlayerName = auxName+str(auxId)
    if i==dae_posLayFeat:
        auxlayerName = 'features'
        auxName = 'dec_'        
    else:        
        if auxName == 'enc_':
          auxId = auxId + 1
        else:
          auxId = auxId - 1

    # agrega las capas ocultas
    if auxlayerName.startswith('enc_'):
        if verCapasDecoder == 3:
          # agrega capa Conv2D + LeakyReLU para Encoder
          eachLay = Conv2D(dae_filters[i], dae_kernel_shape, padding='same', name='c_'+auxlayerName)(eachLay) 
          eachLay = LeakyReLU(alpha=0.2, name='cl_'+auxlayerName)(eachLay) 
        else:
          # agrega capa Conv2D para Encoder
          eachLay = Conv2D(dae_filters[i], dae_kernel_shape, activation='relu', padding='same', name='c_'+auxlayerName)(eachLay) 
        # agrega capa MaxPooling para Encoder
        eachLay = MaxPooling2D(dae_pooling_shape, padding='same', name='p_'+auxlayerName)(eachLay)

    elif auxlayerName.startswith('dec_'):
      if verCapasDecoder == 2:
          # Dec v2: agrega capa Conv2DTranspose con BatchNormalization para Decoder        
          eachLay = Conv2DTranspose(dae_filters[i], dae_kernel_shape, strides=2, activation='relu', padding='same', name='d_'+auxlayerName)(eachLay) 
          eachLay = BatchNormalization(name='p_'+auxlayerName)(eachLay)
      elif verCapasDecoder == 3:
          # Dec v3: agrega capa Conv2DTranspose con LeakyReLU y BatchNormalization para Decoder                  
          eachLay = Conv2DTranspose(dae_filters[i], dae_kernel_shape, strides=2, padding='same', name='d_'+auxlayerName)(eachLay) 
          eachLay = LeakyReLU(alpha=0.2, name='dl_'+auxlayerName)(eachLay) 
          eachLay = BatchNormalization(axis=-1, name='dn_'+auxlayerName)(eachLay)
      else: 
          # Dec v1: agrega capa Conv2 + UpSampling2D para Decoder        
          eachLay = Conv2D(dae_filters[i], dae_kernel_shape, activation='relu', padding='same', name='d_'+auxlayerName)(eachLay) 
          eachLay = UpSampling2D(dae_pooling_shape, name='p_'+auxlayerName)(eachLay)

    elif auxlayerName.startswith('features'):
          #  agrega capa Flatten, Dense y Reshape 
          # para ello utiliza la información del shape de la última capa Encoder
          # y la cantidad de canales de la imagen original
          dae_features_shape = (int(eachLay.shape[1]), int(eachLay.shape[2]), IMAGE_SHAPE[2])
          num_features = dae_features_shape[0]*dae_features_shape[1]*dae_features_shape[2]      

          eachLay = Flatten(name='f_'+auxlayerName)(eachLay)
          eachLay = Dense(num_features, activation='sigmoid', name='d_'+auxlayerName)(eachLay)
          features_Lay = eachLay
          eachLay = Reshape(dae_features_shape, name='r_'+auxlayerName)(eachLay)

# agrega la capa de salida usando la cantidad de canales de la imagen como cantidad de filtros   
output_img_Lay = Conv2D(IMAGE_SHAPE[2], dae_kernel_shape, activation='sigmoid', padding='same', name='output_img')(eachLay)  # capa de salida

# genera el modelo Deep Autoencoder
DCIGNmodel = Model(input_img_Lay, output_img_Lay, name='DCIGNmodel')
#DCIGNmodel.compile(optimizer='adam', loss='mse')
#DCIGNmodel.compile(optimizer='adam', loss='binary_crossentropy')
optAdam = Adam(lr=1e-3)
DCIGNmodel.compile(optimizer=optAdam, loss='mse')

print("Modelo DAE CNN creado con ", len(DCIGNmodel.layers), " capas:")
DCIGNmodel.summary()
print("\n")
plot_model(DCIGNmodel, show_layer_names=True, show_shapes=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Modelo DAE CNN creado con  41  capas:
# Model: "DCIGNmodel"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_img (InputLayer)       [(None, 128, 128, 3)]     0
# _________________________________________________________________
# c_enc_1 (Conv2D)             (None, 128, 128, 256)     7168
# _________________________________________________________________
# cl_enc_1 (LeakyReLU)         (None, 128, 128, 256)     0
# _________________________________________________________________
# p_enc_1 (MaxPooling2D)       (None, 64, 64, 256)       0
# _________________________________________________________________
# c_enc_2 (Conv2D)             (None, 64, 64, 128)       295040
# _________________________________________________________________
# cl_enc_2 (LeakyReLU)         (None, 64, 64, 128)       0
# _________________________________________________________________
# p_enc_2 (MaxPooling2D)       (None, 32, 32, 128)       0
# _________________________________________________________________
# c_enc_3 (Conv2D)             (None, 32, 32, 64)        73792
# _________________________________________________________________
# cl_enc_3 (LeakyReLU)         (None, 32, 32, 64)        0
# _________________________________________________________________
# p_enc_3 (MaxPooling2D)       (None, 16, 16, 64)        0
# _________________________________________________________________
# c_enc_4 (Conv2D)             (None, 16, 16, 32)        18464
# _________________________________________________________________
# cl_enc_4 (LeakyReLU)         (None, 16, 16, 32)        0
# _________________________________________________________________
# p_enc_4 (MaxPooling2D)       (None, 8, 8, 32)          0
# _________________________________________________________________
# c_enc_5 (Conv2D)             (None, 8, 8, 16)          4624
# _________________________________________________________________
# cl_enc_5 (LeakyReLU)         (None, 8, 8, 16)          0
# _________________________________________________________________
# p_enc_5 (MaxPooling2D)       (None, 4, 4, 16)          0
# _________________________________________________________________
# c_enc_6 (Conv2D)             (None, 4, 4, 8)           1160
# _________________________________________________________________
# cl_enc_6 (LeakyReLU)         (None, 4, 4, 8)           0
# _________________________________________________________________
# p_enc_6 (MaxPooling2D)       (None, 2, 2, 8)           0
# _________________________________________________________________
# f_features (Flatten)         (None, 32)                0
# _________________________________________________________________
# d_features (Dense)           (None, 12)                396
# _________________________________________________________________
# r_features (Reshape)         (None, 2, 2, 3)           0
# _________________________________________________________________
# d_dec_7 (Conv2DTranspose)    (None, 4, 4, 8)           224
# _________________________________________________________________
# dl_dec_7 (LeakyReLU)         (None, 4, 4, 8)           0
# _________________________________________________________________
# dn_dec_7 (BatchNormalization (None, 4, 4, 8)           32
# _________________________________________________________________
# d_dec_6 (Conv2DTranspose)    (None, 8, 8, 16)          1168
# _________________________________________________________________
# dl_dec_6 (LeakyReLU)         (None, 8, 8, 16)          0
# _________________________________________________________________
# dn_dec_6 (BatchNormalization (None, 8, 8, 16)          64
# _________________________________________________________________
# d_dec_5 (Conv2DTranspose)    (None, 16, 16, 32)        4640
# _________________________________________________________________
# dl_dec_5 (LeakyReLU)         (None, 16, 16, 32)        0
# _________________________________________________________________
# dn_dec_5 (BatchNormalization (None, 16, 16, 32)        128
# _________________________________________________________________
# d_dec_4 (Conv2DTranspose)    (None, 32, 32, 64)        18496
# _________________________________________________________________
# dl_dec_4 (LeakyReLU)         (None, 32, 32, 64)        0
# _________________________________________________________________
# dn_dec_4 (BatchNormalization (None, 32, 32, 64)        256
# _________________________________________________________________
# d_dec_3 (Conv2DTranspose)    (None, 64, 64, 128)       73856
# _________________________________________________________________
# dl_dec_3 (LeakyReLU)         (None, 64, 64, 128)       0
# _________________________________________________________________
# dn_dec_3 (BatchNormalization (None, 64, 64, 128)       512
# _________________________________________________________________
# d_dec_2 (Conv2DTranspose)    (None, 128, 128, 256)     295168
# _________________________________________________________________
# dl_dec_2 (LeakyReLU)         (None, 128, 128, 256)     0
# _________________________________________________________________
# dn_dec_2 (BatchNormalization (None, 128, 128, 256)     1024
# _________________________________________________________________
# output_img (Conv2D)          (None, 128, 128, 3)       6915
# =================================================================
# Total params: 803,127
# Trainable params: 802,119
# Non-trainable params: 1,008
# _________________________________________________________________

# %% [markdown]
# 5) Entrenar el modelo DAE:

# %%
#@title Entrenar

# lleva a cabo el entrenamiento
# usando los mismos datos como entrada y salida
history = DCIGNmodel.fit(x_train, y_train,
                epochs = cantEpocas,
                shuffle=True)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch 1/2500
# 2/2 [==============================] - 10s 4s/step - loss: 0.1347
# Epoch 2/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.1040
# Epoch 3/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0933
# Epoch 4/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0859
# Epoch 5/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0803
# Epoch 6/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0761
# Epoch 7/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0724
# Epoch 8/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0691
# Epoch 9/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0660
# Epoch 10/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0635
# Epoch 11/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0610
# Epoch 12/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0590
# Epoch 13/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0576
# Epoch 14/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0562
# Epoch 15/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0553
# Epoch 16/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0546
# Epoch 17/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0542
# Epoch 18/2500
# 2/2 [==============================] - 1s 518ms/step - loss: 0.0536
# Epoch 19/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0527
# Epoch 20/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0519
# Epoch 21/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0508
# Epoch 22/2500
# 2/2 [==============================] - 1s 518ms/step - loss: 0.0504
# Epoch 23/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0491
# Epoch 24/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0478
# Epoch 25/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0470
# Epoch 26/2500
# 2/2 [==============================] - 1s 517ms/step - loss: 0.0462
# Epoch 27/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0460
# Epoch 28/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0457
# Epoch 29/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0444
# Epoch 30/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0439
# Epoch 31/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0441
# Epoch 32/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0437
# Epoch 33/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0435
# Epoch 34/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0432
# Epoch 35/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0421
# Epoch 36/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0420
# Epoch 37/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0418
# Epoch 38/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0415
# Epoch 39/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0410
# Epoch 40/2500
# 2/2 [==============================] - 1s 517ms/step - loss: 0.0405
# Epoch 41/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0403
# Epoch 42/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0400
# Epoch 43/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0396
# Epoch 44/2500
# 2/2 [==============================] - 1s 517ms/step - loss: 0.0395
# Epoch 45/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0396
# Epoch 46/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0390
# Epoch 47/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0388
# Epoch 48/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0389
# Epoch 49/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0387
# Epoch 50/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0380
# Epoch 51/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0389
# Epoch 52/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0380
# Epoch 53/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0382
# Epoch 54/2500
# 2/2 [==============================] - 1s 522ms/step - loss: 0.0379
# Epoch 55/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0377
# Epoch 56/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0376
# Epoch 57/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0377
# Epoch 58/2500
# 2/2 [==============================] - 1s 516ms/step - loss: 0.0373
# Epoch 59/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0372
# Epoch 60/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0376
# Epoch 61/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0371
# Epoch 62/2500
# 2/2 [==============================] - 1s 518ms/step - loss: 0.0369
# Epoch 63/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0368
# Epoch 64/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0363
# Epoch 65/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0364
# Epoch 66/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0363
# Epoch 67/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0360
# Epoch 68/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0357
# Epoch 69/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0360
# Epoch 70/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0358
# Epoch 71/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0363
# Epoch 72/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0354
# Epoch 73/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0352
# Epoch 74/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0351
# Epoch 75/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0350
# Epoch 76/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0346
# Epoch 77/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0344
# Epoch 78/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0354
# Epoch 79/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0346
# Epoch 80/2500
# 2/2 [==============================] - 1s 520ms/step - loss: 0.0354
# Epoch 81/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0345
# Epoch 82/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0339
# Epoch 83/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0347
# Epoch 84/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0337
# Epoch 85/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0341
# Epoch 86/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0339
# Epoch 87/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0336
# Epoch 88/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0333
# Epoch 89/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0342
# Epoch 90/2500
# 2/2 [==============================] - 1s 516ms/step - loss: 0.0338
# Epoch 91/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0336
# Epoch 92/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0335
# Epoch 93/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0334
# Epoch 94/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0328
# Epoch 95/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0329
# Epoch 96/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0327
# Epoch 97/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0331
# Epoch 98/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0326
# Epoch 99/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0323
# Epoch 100/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0323
# Epoch 101/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0338
# Epoch 102/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0329
# Epoch 103/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0329
# Epoch 104/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0325
# Epoch 105/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0325
# Epoch 106/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0326
# Epoch 107/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0325
# Epoch 108/2500
# 2/2 [==============================] - 1s 522ms/step - loss: 0.0319
# Epoch 109/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0317
# Epoch 110/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0317
# Epoch 111/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0319
# Epoch 112/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0321
# Epoch 113/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0314
# Epoch 114/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0314
# Epoch 115/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0315
# Epoch 116/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0312
# Epoch 117/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0308
# Epoch 118/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0307
# Epoch 119/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0306
# Epoch 120/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0311
# Epoch 121/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0306
# Epoch 122/2500
# 2/2 [==============================] - 1s 516ms/step - loss: 0.0313
# Epoch 123/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0306
# Epoch 124/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0305
# Epoch 125/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0304
# Epoch 126/2500
# 2/2 [==============================] - 1s 524ms/step - loss: 0.0305
# Epoch 127/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0305
# Epoch 128/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0304
# Epoch 129/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0303
# Epoch 130/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0312
# Epoch 131/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0308
# Epoch 132/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0310
# Epoch 133/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0306
# Epoch 134/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0305
# Epoch 135/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0314
# Epoch 136/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0296
# Epoch 137/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0315
# Epoch 138/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0305
# Epoch 139/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0298
# Epoch 140/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0297
# Epoch 141/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0302
# Epoch 142/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0299
# Epoch 143/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0296
# Epoch 144/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0292
# Epoch 145/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0290
# Epoch 146/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0296
# Epoch 147/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0290
# Epoch 148/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0291
# Epoch 149/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0286
# Epoch 150/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0286
# Epoch 151/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0293
# Epoch 152/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0297
# Epoch 153/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0290
# Epoch 154/2500
# 2/2 [==============================] - 1s 519ms/step - loss: 0.0289
# Epoch 155/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0294
# Epoch 156/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0296
# Epoch 157/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0295
# Epoch 158/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0285
# Epoch 159/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0285
# Epoch 160/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0285
# Epoch 161/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0281
# Epoch 162/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0283
# Epoch 163/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0282
# Epoch 164/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0282
# Epoch 165/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0294
# Epoch 166/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0294
# Epoch 167/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0294
# Epoch 168/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0293
# Epoch 169/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0287
# Epoch 170/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0295
# Epoch 171/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0281
# Epoch 172/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0285
# Epoch 173/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0286
# Epoch 174/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0280
# Epoch 175/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0286
# Epoch 176/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0284
# Epoch 177/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0281
# Epoch 178/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0279
# Epoch 179/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0277
# Epoch 180/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0285
# Epoch 181/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0282
# Epoch 182/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0272
# Epoch 183/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0277
# Epoch 184/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0271
# Epoch 185/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0271
# Epoch 186/2500
# 2/2 [==============================] - 1s 519ms/step - loss: 0.0267
# Epoch 187/2500
# 2/2 [==============================] - 1s 497ms/step - loss: 0.0266
# Epoch 188/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0266
# Epoch 189/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0267
# Epoch 190/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0268
# Epoch 191/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0270
# Epoch 192/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0269
# Epoch 193/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0265
# Epoch 194/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0279
# Epoch 195/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0276
# Epoch 196/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0270
# Epoch 197/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0273
# Epoch 198/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0276
# Epoch 199/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0271
# Epoch 200/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0271
# Epoch 201/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0275
# Epoch 202/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0272
# Epoch 203/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0280
# Epoch 204/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0282
# Epoch 205/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0274
# Epoch 206/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0267
# Epoch 207/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0282
# Epoch 208/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0262
# Epoch 209/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0289
# Epoch 210/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0262
# Epoch 211/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0273
# Epoch 212/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0268
# Epoch 213/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0262
# Epoch 214/2500
# 2/2 [==============================] - 1s 520ms/step - loss: 0.0259
# Epoch 215/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0263
# Epoch 216/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0256
# Epoch 217/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0257
# Epoch 218/2500
# 2/2 [==============================] - 1s 516ms/step - loss: 0.0257
# Epoch 219/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0255
# Epoch 220/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0254
# Epoch 221/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0251
# Epoch 222/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0250
# Epoch 223/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0258
# Epoch 224/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0264
# Epoch 225/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0249
# Epoch 226/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0253
# Epoch 227/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0251
# Epoch 228/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0258
# Epoch 229/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0254
# Epoch 230/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0261
# Epoch 231/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0256
# Epoch 232/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0253
# Epoch 233/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0264
# Epoch 234/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0274
# Epoch 235/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0276
# Epoch 236/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0264
# Epoch 237/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0261
# Epoch 238/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0259
# Epoch 239/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0256
# Epoch 240/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0256
# Epoch 241/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0253
# Epoch 242/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0247
# Epoch 243/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0253
# Epoch 244/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0247
# Epoch 245/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0245
# Epoch 246/2500
# 2/2 [==============================] - 1s 516ms/step - loss: 0.0252
# Epoch 247/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0253
# Epoch 248/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0254
# Epoch 249/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0245
# Epoch 250/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0244
# Epoch 251/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0242
# Epoch 252/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0245
# Epoch 253/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0264
# Epoch 254/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0260
# Epoch 255/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0245
# Epoch 256/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0247
# Epoch 257/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0246
# Epoch 258/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0265
# Epoch 259/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0250
# Epoch 260/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0246
# Epoch 261/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0248
# Epoch 262/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0245
# Epoch 263/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0248
# Epoch 264/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0245
# Epoch 265/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0240
# Epoch 266/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0237
# Epoch 267/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0242
# Epoch 268/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0242
# Epoch 269/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0236
# Epoch 270/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0237
# Epoch 271/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0246
# Epoch 272/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0247
# Epoch 273/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0281
# Epoch 274/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0240
# Epoch 275/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0258
# Epoch 276/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0251
# Epoch 277/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0242
# Epoch 278/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0246
# Epoch 279/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0246
# Epoch 280/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0246
# Epoch 281/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0243
# Epoch 282/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0245
# Epoch 283/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0237
# Epoch 284/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0245
# Epoch 285/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0247
# Epoch 286/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0242
# Epoch 287/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0238
# Epoch 288/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0232
# Epoch 289/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0231
# Epoch 290/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0241
# Epoch 291/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0234
# Epoch 292/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0235
# Epoch 293/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0240
# Epoch 294/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0232
# Epoch 295/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0232
# Epoch 296/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0242
# Epoch 297/2500
# 2/2 [==============================] - 1s 516ms/step - loss: 0.0246
# Epoch 298/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0244
# Epoch 299/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0236
# Epoch 300/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0234
# Epoch 301/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0236
# Epoch 302/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0234
# Epoch 303/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0229
# Epoch 304/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0242
# Epoch 305/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0236
# Epoch 306/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0228
# Epoch 307/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0231
# Epoch 308/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0228
# Epoch 309/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0226
# Epoch 310/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0225
# Epoch 311/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0223
# Epoch 312/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0226
# Epoch 313/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0228
# Epoch 314/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0225
# Epoch 315/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0223
# Epoch 316/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0226
# Epoch 317/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0225
# Epoch 318/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0227
# Epoch 319/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0229
# Epoch 320/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0222
# Epoch 321/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0219
# Epoch 322/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0229
# Epoch 323/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0226
# Epoch 324/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0223
# Epoch 325/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0226
# Epoch 326/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0222
# Epoch 327/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0221
# Epoch 328/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0250
# Epoch 329/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0238
# Epoch 330/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0245
# Epoch 331/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0234
# Epoch 332/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0247
# Epoch 333/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0258
# Epoch 334/2500
# 2/2 [==============================] - 1s 517ms/step - loss: 0.0231
# Epoch 335/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0242
# Epoch 336/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0236
# Epoch 337/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0229
# Epoch 338/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0224
# Epoch 339/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0232
# Epoch 340/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0229
# Epoch 341/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0226
# Epoch 342/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0222
# Epoch 343/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0221
# Epoch 344/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0221
# Epoch 345/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0218
# Epoch 346/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0216
# Epoch 347/2500
# 2/2 [==============================] - 1s 517ms/step - loss: 0.0231
# Epoch 348/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0216
# Epoch 349/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0219
# Epoch 350/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0215
# Epoch 351/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0215
# Epoch 352/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0212
# Epoch 353/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0226
# Epoch 354/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0219
# Epoch 355/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0216
# Epoch 356/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0211
# Epoch 357/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0217
# Epoch 358/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0212
# Epoch 359/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0212
# Epoch 360/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0212
# Epoch 361/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0224
# Epoch 362/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0221
# Epoch 363/2500
# 2/2 [==============================] - 1s 496ms/step - loss: 0.0217
# Epoch 364/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0231
# Epoch 365/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0218
# Epoch 366/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0214
# Epoch 367/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0213
# Epoch 368/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0206
# Epoch 369/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0223
# Epoch 370/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0224
# Epoch 371/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0212
# Epoch 372/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0215
# Epoch 373/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0215
# Epoch 374/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0210
# Epoch 375/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0213
# Epoch 376/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0231
# Epoch 377/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0212
# Epoch 378/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0217
# Epoch 379/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0216
# Epoch 380/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0213
# Epoch 381/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0221
# Epoch 382/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0241
# Epoch 383/2500
# 2/2 [==============================] - 1s 518ms/step - loss: 0.0226
# Epoch 384/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0212
# Epoch 385/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0239
# Epoch 386/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0216
# Epoch 387/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0220
# Epoch 388/2500
# 2/2 [==============================] - 1s 517ms/step - loss: 0.0215
# Epoch 389/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0210
# Epoch 390/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0208
# Epoch 391/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0216
# Epoch 392/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0205
# Epoch 393/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0213
# Epoch 394/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0216
# Epoch 395/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0213
# Epoch 396/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0209
# Epoch 397/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0227
# Epoch 398/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0215
# Epoch 399/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0222
# Epoch 400/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0210
# Epoch 401/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0226
# Epoch 402/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0228
# Epoch 403/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0214
# Epoch 404/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0211
# Epoch 405/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0212
# Epoch 406/2500
# 2/2 [==============================] - 1s 516ms/step - loss: 0.0212
# Epoch 407/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0209
# Epoch 408/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0218
# Epoch 409/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0206
# Epoch 410/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0211
# Epoch 411/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0203
# Epoch 412/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0204
# Epoch 413/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0210
# Epoch 414/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0210
# Epoch 415/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0209
# Epoch 416/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0203
# Epoch 417/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0200
# Epoch 418/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0200
# Epoch 419/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0204
# Epoch 420/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0202
# Epoch 421/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0202
# Epoch 422/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0207
# Epoch 423/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0222
# Epoch 424/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0207
# Epoch 425/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0215
# Epoch 426/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0204
# Epoch 427/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0202
# Epoch 428/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0220
# Epoch 429/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0209
# Epoch 430/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0207
# Epoch 431/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0207
# Epoch 432/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0199
# Epoch 433/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0202
# Epoch 434/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0199
# Epoch 435/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0199
# Epoch 436/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0203
# Epoch 437/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0199
# Epoch 438/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0209
# Epoch 439/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0204
# Epoch 440/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0202
# Epoch 441/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0199
# Epoch 442/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0199
# Epoch 443/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0201
# Epoch 444/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0205
# Epoch 445/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0215
# Epoch 446/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0209
# Epoch 447/2500
# 2/2 [==============================] - 1s 518ms/step - loss: 0.0210
# Epoch 448/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0203
# Epoch 449/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0206
# Epoch 450/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0199
# Epoch 451/2500
# 2/2 [==============================] - 1s 519ms/step - loss: 0.0209
# Epoch 452/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0202
# Epoch 453/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0198
# Epoch 454/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0201
# Epoch 455/2500
# 2/2 [==============================] - 1s 520ms/step - loss: 0.0204
# Epoch 456/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0195
# Epoch 457/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0215
# Epoch 458/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0196
# Epoch 459/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0204
# Epoch 460/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0192
# Epoch 461/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0206
# Epoch 462/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0205
# Epoch 463/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0206
# Epoch 464/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0197
# Epoch 465/2500
# 2/2 [==============================] - 1s 496ms/step - loss: 0.0193
# Epoch 466/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0191
# Epoch 467/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0200
# Epoch 468/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0194
# Epoch 469/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0196
# Epoch 470/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0195
# Epoch 471/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0203
# Epoch 472/2500
# 2/2 [==============================] - 1s 519ms/step - loss: 0.0215
# Epoch 473/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0203
# Epoch 474/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0202
# Epoch 475/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0195
# Epoch 476/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0195
# Epoch 477/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0214
# Epoch 478/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0192
# Epoch 479/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0201
# Epoch 480/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0194
# Epoch 481/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0197
# Epoch 482/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0195
# Epoch 483/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0190
# Epoch 484/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0201
# Epoch 485/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0195
# Epoch 486/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0184
# Epoch 487/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0188
# Epoch 488/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0188
# Epoch 489/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0183
# Epoch 490/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0197
# Epoch 491/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0183
# Epoch 492/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0186
# Epoch 493/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0189
# Epoch 494/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0187
# Epoch 495/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0197
# Epoch 496/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0192
# Epoch 497/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0185
# Epoch 498/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0196
# Epoch 499/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0185
# Epoch 500/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0194
# Epoch 501/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0192
# Epoch 502/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0189
# Epoch 503/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0197
# Epoch 504/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0201
# Epoch 505/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0197
# Epoch 506/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0204
# Epoch 507/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0198
# Epoch 508/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0196
# Epoch 509/2500
# 2/2 [==============================] - 1s 518ms/step - loss: 0.0218
# Epoch 510/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0213
# Epoch 511/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0196
# Epoch 512/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0195
# Epoch 513/2500
# 2/2 [==============================] - 1s 517ms/step - loss: 0.0196
# Epoch 514/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0200
# Epoch 515/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0202
# Epoch 516/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0190
# Epoch 517/2500
# 2/2 [==============================] - 1s 519ms/step - loss: 0.0195
# Epoch 518/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0197
# Epoch 519/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0198
# Epoch 520/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0192
# Epoch 521/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0196
# Epoch 522/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0209
# Epoch 523/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0207
# Epoch 524/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0194
# Epoch 525/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0189
# Epoch 526/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0191
# Epoch 527/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0190
# Epoch 528/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0189
# Epoch 529/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0182
# Epoch 530/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0189
# Epoch 531/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0182
# Epoch 532/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0183
# Epoch 533/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0181
# Epoch 534/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0178
# Epoch 535/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0191
# Epoch 536/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0196
# Epoch 537/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0211
# Epoch 538/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0198
# Epoch 539/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0199
# Epoch 540/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0199
# Epoch 541/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0207
# Epoch 542/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0186
# Epoch 543/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0199
# Epoch 544/2500
# 2/2 [==============================] - 1s 518ms/step - loss: 0.0186
# Epoch 545/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0187
# Epoch 546/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0186
# Epoch 547/2500
# 2/2 [==============================] - 1s 517ms/step - loss: 0.0181
# Epoch 548/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0180
# Epoch 549/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0183
# Epoch 550/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0183
# Epoch 551/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0181
# Epoch 552/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0182
# Epoch 553/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0188
# Epoch 554/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0183
# Epoch 555/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0195
# Epoch 556/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0189
# Epoch 557/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0181
# Epoch 558/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0178
# Epoch 559/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0179
# Epoch 560/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0182
# Epoch 561/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0177
# Epoch 562/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0183
# Epoch 563/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0177
# Epoch 564/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0181
# Epoch 565/2500
# 2/2 [==============================] - 1s 519ms/step - loss: 0.0182
# Epoch 566/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0190
# Epoch 567/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0176
# Epoch 568/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0176
# Epoch 569/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0179
# Epoch 570/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0173
# Epoch 571/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0179
# Epoch 572/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0178
# Epoch 573/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0201
# Epoch 574/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0193
# Epoch 575/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0204
# Epoch 576/2500
# 2/2 [==============================] - 1s 529ms/step - loss: 0.0188
# Epoch 577/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0207
# Epoch 578/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0192
# Epoch 579/2500
# ...
# Epoch 2311/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0134
# Epoch 2312/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0103
# Epoch 2313/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0109
# Epoch 2314/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0121
# Epoch 2315/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0107
# Epoch 2316/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0127
# Epoch 2317/2500
# 2/2 [==============================] - 1s 516ms/step - loss: 0.0108
# Epoch 2318/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0107
# Epoch 2319/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0109
# Epoch 2320/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0107
# Epoch 2321/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0105
# Epoch 2322/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0101
# Epoch 2323/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0105
# Epoch 2324/2500
# 2/2 [==============================] - 1s 497ms/step - loss: 0.0111
# Epoch 2325/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0100
# Epoch 2326/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0104
# Epoch 2327/2500
# 2/2 [==============================] - 1s 522ms/step - loss: 0.0107
# Epoch 2328/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0099
# Epoch 2329/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0103
# Epoch 2330/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0098
# Epoch 2331/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0102
# Epoch 2332/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0098
# Epoch 2333/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0101
# Epoch 2334/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0103
# Epoch 2335/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0101
# Epoch 2336/2500
# 2/2 [==============================] - 1s 522ms/step - loss: 0.0119
# Epoch 2337/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0101
# Epoch 2338/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0100
# Epoch 2339/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0107
# Epoch 2340/2500
# 2/2 [==============================] - 1s 523ms/step - loss: 0.0127
# Epoch 2341/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0112
# Epoch 2342/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0100
# Epoch 2343/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0108
# Epoch 2344/2500
# 2/2 [==============================] - 1s 519ms/step - loss: 0.0114
# Epoch 2345/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0104
# Epoch 2346/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0103
# Epoch 2347/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0116
# Epoch 2348/2500
# 2/2 [==============================] - 1s 526ms/step - loss: 0.0105
# Epoch 2349/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0108
# Epoch 2350/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0110
# Epoch 2351/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0104
# Epoch 2352/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0107
# Epoch 2353/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0104
# Epoch 2354/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0099
# Epoch 2355/2500
# 2/2 [==============================] - 1s 516ms/step - loss: 0.0107
# Epoch 2356/2500
# 2/2 [==============================] - 1s 497ms/step - loss: 0.0103
# Epoch 2357/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0108
# Epoch 2358/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0097
# Epoch 2359/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0109
# Epoch 2360/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0109
# Epoch 2361/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0101
# Epoch 2362/2500
# 2/2 [==============================] - 1s 522ms/step - loss: 0.0102
# Epoch 2363/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0104
# Epoch 2364/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0109
# Epoch 2365/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0109
# Epoch 2366/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0106
# Epoch 2367/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0105
# Epoch 2368/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0107
# Epoch 2369/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0097
# Epoch 2370/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0103
# Epoch 2371/2500
# 2/2 [==============================] - 1s 521ms/step - loss: 0.0108
# Epoch 2372/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0103
# Epoch 2373/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0105
# Epoch 2374/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0102
# Epoch 2375/2500
# 2/2 [==============================] - 1s 520ms/step - loss: 0.0161
# Epoch 2376/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0110
# Epoch 2377/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0110
# Epoch 2378/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0108
# Epoch 2379/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0113
# Epoch 2380/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0109
# Epoch 2381/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0115
# Epoch 2382/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0111
# Epoch 2383/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0129
# Epoch 2384/2500
# 2/2 [==============================] - 1s 517ms/step - loss: 0.0101
# Epoch 2385/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0125
# Epoch 2386/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0102
# Epoch 2387/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0106
# Epoch 2388/2500
# 2/2 [==============================] - 1s 526ms/step - loss: 0.0102
# Epoch 2389/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0104
# Epoch 2390/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0097
# Epoch 2391/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0121
# Epoch 2392/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0131
# Epoch 2393/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0104
# Epoch 2394/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0101
# Epoch 2395/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0100
# Epoch 2396/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0099
# Epoch 2397/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0103
# Epoch 2398/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0108
# Epoch 2399/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0104
# Epoch 2400/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0110
# Epoch 2401/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0109
# Epoch 2402/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0108
# Epoch 2403/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0129
# Epoch 2404/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0110
# Epoch 2405/2500
# 2/2 [==============================] - 1s 520ms/step - loss: 0.0112
# Epoch 2406/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0105
# Epoch 2407/2500
# 2/2 [==============================] - 1s 518ms/step - loss: 0.0105
# Epoch 2408/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0113
# Epoch 2409/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0104
# Epoch 2410/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0110
# Epoch 2411/2500
# 2/2 [==============================] - 1s 516ms/step - loss: 0.0124
# Epoch 2412/2500
# 2/2 [==============================] - 1s 523ms/step - loss: 0.0106
# Epoch 2413/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0101
# Epoch 2414/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0102
# Epoch 2415/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0102
# Epoch 2416/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0099
# Epoch 2417/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0097
# Epoch 2418/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0100
# Epoch 2419/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0099
# Epoch 2420/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0115
# Epoch 2421/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0098
# Epoch 2422/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0104
# Epoch 2423/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0104
# Epoch 2424/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0100
# Epoch 2425/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0122
# Epoch 2426/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0104
# Epoch 2427/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0099
# Epoch 2428/2500
# 2/2 [==============================] - 1s 524ms/step - loss: 0.0107
# Epoch 2429/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0106
# Epoch 2430/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0115
# Epoch 2431/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0113
# Epoch 2432/2500
# 2/2 [==============================] - 1s 518ms/step - loss: 0.0100
# Epoch 2433/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0100
# Epoch 2434/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0106
# Epoch 2435/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0137
# Epoch 2436/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0110
# Epoch 2437/2500
# 2/2 [==============================] - 1s 499ms/step - loss: 0.0111
# Epoch 2438/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0106
# Epoch 2439/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0112
# Epoch 2440/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0119
# Epoch 2441/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0104
# Epoch 2442/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0102
# Epoch 2443/2500
# 2/2 [==============================] - 1s 517ms/step - loss: 0.0097
# Epoch 2444/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0096
# Epoch 2445/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0098
# Epoch 2446/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0097
# Epoch 2447/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0103
# Epoch 2448/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0120
# Epoch 2449/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0124
# Epoch 2450/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0110
# Epoch 2451/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0101
# Epoch 2452/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0107
# Epoch 2453/2500
# 2/2 [==============================] - 1s 501ms/step - loss: 0.0107
# Epoch 2454/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0107
# Epoch 2455/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0105
# Epoch 2456/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0102
# Epoch 2457/2500
# 2/2 [==============================] - 1s 520ms/step - loss: 0.0101
# Epoch 2458/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0103
# Epoch 2459/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0101
# Epoch 2460/2500
# 2/2 [==============================] - 1s 508ms/step - loss: 0.0104
# Epoch 2461/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0102
# Epoch 2462/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0144
# Epoch 2463/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0109
# Epoch 2464/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0102
# Epoch 2465/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0098
# Epoch 2466/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0105
# Epoch 2467/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0096
# Epoch 2468/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0102
# Epoch 2469/2500
# 2/2 [==============================] - 1s 498ms/step - loss: 0.0099
# Epoch 2470/2500
# 2/2 [==============================] - 1s 516ms/step - loss: 0.0099
# Epoch 2471/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0106
# Epoch 2472/2500
# 2/2 [==============================] - 1s 521ms/step - loss: 0.0104
# Epoch 2473/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0113
# Epoch 2474/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0124
# Epoch 2475/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0109
# Epoch 2476/2500
# 2/2 [==============================] - 1s 518ms/step - loss: 0.0104
# Epoch 2477/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0105
# Epoch 2478/2500
# 2/2 [==============================] - 1s 517ms/step - loss: 0.0108
# Epoch 2479/2500
# 2/2 [==============================] - 1s 512ms/step - loss: 0.0105
# Epoch 2480/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0114
# Epoch 2481/2500
# 2/2 [==============================] - 1s 505ms/step - loss: 0.0100
# Epoch 2482/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0103
# Epoch 2483/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0102
# Epoch 2484/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0098
# Epoch 2485/2500
# 2/2 [==============================] - 1s 507ms/step - loss: 0.0100
# Epoch 2486/2500
# 2/2 [==============================] - 1s 504ms/step - loss: 0.0104
# Epoch 2487/2500
# 2/2 [==============================] - 1s 510ms/step - loss: 0.0096
# Epoch 2488/2500
# 2/2 [==============================] - 1s 511ms/step - loss: 0.0096
# Epoch 2489/2500
# 2/2 [==============================] - 1s 514ms/step - loss: 0.0101
# Epoch 2490/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0114
# Epoch 2491/2500
# 2/2 [==============================] - 1s 517ms/step - loss: 0.0104
# Epoch 2492/2500
# 2/2 [==============================] - 1s 516ms/step - loss: 0.0106
# Epoch 2493/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0108
# Epoch 2494/2500
# 2/2 [==============================] - 1s 502ms/step - loss: 0.0103
# Epoch 2495/2500
# 2/2 [==============================] - 1s 509ms/step - loss: 0.0099
# Epoch 2496/2500
# 2/2 [==============================] - 1s 515ms/step - loss: 0.0100
# Epoch 2497/2500
# 2/2 [==============================] - 1s 503ms/step - loss: 0.0129
# Epoch 2498/2500
# 2/2 [==============================] - 1s 513ms/step - loss: 0.0104
# Epoch 2499/2500
# 2/2 [==============================] - 1s 506ms/step - loss: 0.0111
# Epoch 2500/2500
# 2/2 [==============================] - 1s 500ms/step - loss: 0.0106

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# 7) Evaluar el modelo DAE entrenado solicitando que reconstruya las imágenes ingresadas:

# %%
#@title Evaluar modelo con imágenes de Entrenamiento

# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, cl, esDAimag):

  # evalua al modelo 
  resEval = DCIGNmodel.evaluate(x, x)
  print("\n>Evaluación del Modelo: ")
  print("    - Error: ", resEval)
  print("\n")

  # procesa las imágenes con el modelo 
  reconstr_imgs = DCIGNmodel.predict(x)

  # muestra las 15 primeras imágenes 
  print("\n>Resultados: ")
  for i in range(len(x)):
    # no muestra las generadas por DA
    #if not esDAimag[i]:
          # prepara para mostrar
          fig = plt.figure()
          fig.suptitle(cl[i])

          # muestra la real
          ax1 = fig.add_subplot(121)
          plot_image(x[i])

          # muestra la generada por el modelo
          ax2 = fig.add_subplot(331)
          plot_image(y[i])

          # muestra la generada por el modelo
          ax3 = fig.add_subplot(122)
          plot_image(reconstr_imgs[i])

          plt.tight_layout()
          fig = plt.gcf()


# prueba con los datos de entrenamiento
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, y_train, classes_train, esDAimag_train)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# 9) Probar el modelo DAE entrenado con otras imágenes:

# %%
#@title Evaluar el modelo con imágenes de Prueba

# prueba con los datos de prueba
print("*** Resultados con datos de Prueba: ")
probarModelo(x_test, y_test, classes_test, esDAimag_test)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
