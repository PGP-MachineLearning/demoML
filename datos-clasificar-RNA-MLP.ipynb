# %% [markdown]
# # Demo RNA Multi-Perceptrón Backpropagation para identificar clases
# Adaptado de https://www.tensorflow.org/tutorials/estimator/premade

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import os
import csv

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Cargar los datos:

# %%
# monta Google Drive:
# Nota: la primera vez se debe confirmar el uso logueandose en "Google Drive File Stream" y obteniendo código de autentificación.
from google.colab import drive
drive.mount('/content/gdrive')

# directorio local en Google Drive
path = '/content/gdrive/My Drive/IA/demoML/datos/'  #@param {type:"string"}
# Out:
# Mounted at /content/gdrive

# %%
## selección de los parámetros 

def cargarNombreClases(path, archivo_datos, atributo_clase, nombre_clases):
  # importa definición de la clase
  arClasesFN = archivo_datos.split('.')[0] + '_nombreClases.txt'
  if os.path.isfile( path + '/' + arClasesFN ):
    with open( path + '/' + arClasesFN, mode='r') as csvfile:
        r = csv.reader(csvfile, delimiter=',')
        auxAtributo = r.__next__()
        auxClases = r.__next__()
    print('\n> Definición de los valores discretos para la clase cargada de ' + arClasesFN +'.\n')
    return auxAtributo[0], ','.join(auxClases)
  else:
    return atributo_clase, nombre_clases

#@markdown ### Archivo de datos a utilizar:
archivo_datos = 'IRIS.csv'  #@param {type:"string"}
#@markdown ### Nombre del atributo clase / objetivo:
atributo_clase = '-' #@param {type:"string"}
#@markdown ### Descripción de los valores del atributo clase / objetivo:  (nota: siempre debe comienzar en 0, por lo que si no tiene valor 0, agregar "na")
nombre_clases = '-' #@param {type:"string"}
#@markdown ### Porcentaje de datos para usar en el entrenamiento:
proporcion_porcentaje_datos_entrenamiento =   70#@param {type:"integer"}

## aplicación de los parámetros elegidos

if atributo_clase == '' or  atributo_clase == '-':
  # trata de obtener la configuración del archivo asociado
  atributo_clase, nombre_clases = cargarNombreClases(path, archivo_datos, atributo_clase, nombre_clases)


# define nombre atributo de CLASE para ejemplo IRIS
ClassAttributeName = atributo_clase

# define valores de clases para ejemplo IRIS
CLASES = [ ]
for val in nombre_clases.split(','):
  CLASES.append( val )

# determina la proporción a usar para entrenar y probar
if proporcion_porcentaje_datos_entrenamiento>100:
  propTrain = 1
elif proporcion_porcentaje_datos_entrenamiento<1:
  propTrain = 0.1
else:
  propTrain = proporcion_porcentaje_datos_entrenamiento/100

print("Configuración definida de ", archivo_datos)
print("Atributo clase: ", ClassAttributeName, ": ", CLASES)
# Out:
# > Definición de los valores discretos para la clase cargada de IRIS_nombreClases.txt.
#
# Configuración definida de  IRIS.csv
# Atributo clase:  Clase :  ['na', 'Setosa', 'Versicolor', 'Virginica']

# %%
#@title Cargar datos

# configura para que muestre todas las columnas y filas
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# Carga los datos del CSV y muestra los primeros
df = pd.read_csv(path + archivo_datos)
print("\n> Cabecera: ")
print(df.head())
print("\n> Características: ")
print(df.describe())


# genera los datos solo con la clase para entrenar y probar
Y = np.array(df.pop(ClassAttributeName))
X = np.array(df)
# Out:
# > Cabecera:
#    LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo  Clase
# 0          5.1          3.5          1.4          0.2      1
# 1          4.9          3.0          1.4          0.2      1
# 2          4.7          3.2          1.3          0.2      1
# 3          4.6          3.1          1.5          0.2      1
# 4          5.0          3.6          1.4          0.2      1
#
# > Características:
#        LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo       Clase
# count   150.000000   150.000000   150.000000   150.000000  150.000000
# mean      5.843333     3.054000     3.758667     1.198667    2.000000
# std       0.828066     0.433594     1.764420     0.763161    0.819232
# min       4.300000     2.000000     1.000000     0.100000    1.000000
# 25%       5.100000     2.800000     1.600000     0.300000    1.000000
# 50%       5.800000     3.000000     4.350000     1.300000    2.000000
# 75%       6.400000     3.300000     5.100000     1.800000    3.000000
# max       7.900000     4.400000     6.900000     2.500000    3.000000

# %%
#@title Normalizar datos de entrada (opcional)

aplica_normalizacion = True #@param {type:"boolean"}
#@markdown Si se aplica, seleccione el tipo de método de normalización a aplicar:
tipo_normalizacion = "Standard Scaler" #@param ["Standard Scaler", "MinMax Scaler", "MaxAbs Scaler", "Robust Scaler"]

if aplica_normalizacion:

  print("10 primeros datos de Entrada antes de normalizar: ")
  print(X[:10])

  from sklearn import preprocessing

  # elegir el método de normalización
  if tipo_normalizacion == "Standard Scaler": 
    scaler = preprocessing.StandardScaler()
  elif tipo_normalizacion == "MinMax Scaler": 
    scaler = preprocessing.MinMaxScaler()
  elif tipo_normalizacion == "MaxMax Scaler": 
    scaler = preprocessing.MaxAbsScaler()
  elif tipo_normalizacion == "Robust Scaler": 
    scaler = preprocessing.RobustScaler()
  
  # normaliza los datos de entrada
  X = scaler.fit_transform(X)

  print("\n\n10 primeros datos de Entrada después de normalizar: ")
  print(X[:10])
# Out:
# 10 primeros datos de Entrada antes de normalizar:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]]
#
#
# 10 primeros datos de Entrada después de normalizar:
# [[-0.90068117  1.03205722 -1.3412724  -1.31297673]
#  [-1.14301691 -0.1249576  -1.3412724  -1.31297673]
#  [-1.38535265  0.33784833 -1.39813811 -1.31297673]
#  [-1.50652052  0.10644536 -1.2844067  -1.31297673]
#  [-1.02184904  1.26346019 -1.3412724  -1.31297673]
#  [-0.53717756  1.95766909 -1.17067529 -1.05003079]
#  [-1.50652052  0.80065426 -1.3412724  -1.18150376]
#  [-1.02184904  0.80065426 -1.2844067  -1.31297673]
#  [-1.74885626 -0.35636057 -1.3412724  -1.31297673]
#  [-1.14301691  0.10644536 -1.2844067  -1.4444497 ]]

# %%
#@title Preparar datos

# separa al azar usando muestreo estratificado con proporción indicada
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=(1-propTrain), stratify=Y)

# genera salida codificada para softMax
y_trainEnc =  np_utils.to_categorical(y_train)
y_testEnc =  np_utils.to_categorical(y_test)

# muestra resultados
print("> Para Ambos: ")
print(" - dictMapeo: ", CLASES)

print("\n> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
print(" - y_train (cant): ", len(y_train))
for i in range(len(CLASES)):
  cant = 0
  for y in y_train:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)

print("\n Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
print(" - y_test (cant): ", len(y_test))
for i in range(len(CLASES)):
  cant = 0
  for y in y_test:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)
# Out:
# > Para Ambos:
#  - dictMapeo:  ['na', 'Setosa', 'Versicolor', 'Virginica']
#
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (104, 4)
#  - y_train (cant):  104
#      na [ 0 ]: 0
#      Setosa [ 1 ]: 35
#      Versicolor [ 2 ]: 35
#      Virginica [ 3 ]: 34
#
#  Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (46, 4)
#  - y_test (cant):  46
#      na [ 0 ]: 0
#      Setosa [ 1 ]: 15
#      Versicolor [ 2 ]: 15
#      Virginica [ 3 ]: 16

# %% [markdown]
# 3) Establecer el modelo para la RNA

# %%
rna_cant_neuronas_capas_ocultas = 'BN, 240, 60, D, 12' #@param {type:"string"}
#@markdown   - Nota: 'D' indica capa Drop-Out y 'BN' indica capa Batch-Normalization
rna_tipo_capa_salida = 'lineal-Numero' #@param ["lineal-Numero", "softmax-MultiClase"]
rna_cant_epocas_entrenamiento =  100#@param {type:"integer"}

# define tamaño de datos de entrada 
num_inputs = x_train.shape[1]

# cantidad de neuronas ocultas 
#hidden_layers = [ num_inputs*3//4, num_inputs//2 ] 
hidden_layers = []
for val in rna_cant_neuronas_capas_ocultas.split(', '):
  if val == "D":
    hidden_layers.append( "DropOut" )  
  elif val == "BN":
    hidden_layers.append( "BatchNormalization" )  
  elif val.isnumeric():
    hidden_layers.append( val )
  else:
    print("Capa ", val, "descartada!")

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (rna_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if rna_cant_epocas_entrenamiento<1 else rna_cant_epocas_entrenamiento)

print("Configuración de RNA MLP Backpropagation definida: \n[", num_inputs, hidden_layers, ("Softmax" if tipo_output_softMax else "Dense[1] ")," ] ")
# Out:
# Configuración de RNA MLP Backpropagation definida:
# [ 4 ['BatchNormalization', '240', '60', 'DropOut', '12'] Dense[1]   ]

# %%
#@title Establecer modelo

opt_tipo = "Adam" #@param ["Gradiente Decreciente", "Adam", "Adadelta", "Adagrad", "Adamax", "Nadam", "FTRL"]
opt_learning_rate = 0.05 #@param {type: "number"}

# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=(num_inputs,), name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'hidd_'
auxId = 1 
for val_hid in hidden_layers:  

  if val_hid == "DropOut":
    eachLay = Dropout(0.2)(eachLay)
  elif val_hid == "BatchNormalization":
    auxlayerName = "bn"+str(auxId)
    auxId = auxId + 1
    eachLay = BatchNormalization(name=auxlayerName)(eachLay)
  elif val_hid.isnumeric():
    # agrega la capa oculta
    auxlayerName = auxName+str(auxId)
    auxId = auxId + 1
    eachLay = Dense(int(val_hid), name=auxlayerName)(eachLay) # capas ocultas

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(CLASES), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida


if opt_tipo == "Gradiente Decreciente":
  opt = keras.optimizers.SGD(learning_rate=opt_learning_rate)
elif opt_tipo == "Adam":
  opt = keras.optimizers.Adam(learning_rate=opt_learning_rate)
elif opt_tipo == "Adadelta":
  opt = keras.optimizers.Adadelta(learning_rate=opt_learning_rate)
elif opt_tipo == "Adagrad":
  opt = keras.optimizers.Adagrad(learning_rate=opt_learning_rate)
elif opt_tipo == "Adamax":
  opt = keras.optimizers.Adamax(learning_rate=opt_learning_rate)
elif opt_tipo == "Nadam":
  opt = keras.optimizers.Nadam(learning_rate=opt_learning_rate)
elif opt_tipo == "FTRL":
  opt = keras.optimizers.Ftrl(learning_rate=opt_learning_rate)
else:
  opt = keras.optimizers.Adam()

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer=opt, loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  7  capas:
# Model: "RNA"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_img (InputLayer)      [(None, 4)]               0
#
#  bn1 (BatchNormalization)    (None, 4)                 16
#
#  hidd_2 (Dense)              (None, 240)               1200
#
#  hidd_3 (Dense)              (None, 60)                14460
#
#  dropout_4 (Dropout)         (None, 60)                0
#
#  hidd_4 (Dense)              (None, 12)                732
#
#  output (Dense)              (None, 1)                 13
#
# =================================================================
# Total params: 16,421
# Trainable params: 16,413
# Non-trainable params: 8
# _________________________________________________________________

# %% [markdown]
# 4) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

activar_corte_por_estabilidad_error_val = False #@param {type:"boolean"}

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(x_train, 
                                       (y_trainEnc if tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

if activar_corte_por_estabilidad_error_val:
  # se agrega un callBack para que corte 
  # si el error de validación no sigue bajando
  # y devuelva los mejores pesos obtenidos
  early_stopping_monitor = keras.callbacks.EarlyStopping(
      monitor='val_loss',
      min_delta=0.01,
      patience=20,
      verbose=0,
      mode='min',
      baseline=None,
      restore_best_weights=True
  )
  callbacksEntr = [early_stopping_monitor]
else:
  early_stopping_monitor = None
  callbacksEntr = []

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,),
          callbacks=callbacksEntr ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  104 ejemplos de entrenamiento:
#             se usan  93 ejemplos para entrenar
#             y  11 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/100
# 3/3 [==============================] - 1s 147ms/step - loss: 129.8534 - accuracy: 0.1505 - val_loss: 99.8058 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 3/3 [==============================] - 0s 27ms/step - loss: 52.9715 - accuracy: 0.0968 - val_loss: 36.8105 - val_accuracy: 0.3636
# Epoch 3/100
# 3/3 [==============================] - 0s 25ms/step - loss: 30.9072 - accuracy: 0.3333 - val_loss: 1.6292 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 3/3 [==============================] - 0s 24ms/step - loss: 14.8013 - accuracy: 0.0000e+00 - val_loss: 11.3740 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 3/3 [==============================] - 0s 24ms/step - loss: 4.6847 - accuracy: 0.1290 - val_loss: 12.7126 - val_accuracy: 0.3636
# Epoch 6/100
# 3/3 [==============================] - 0s 23ms/step - loss: 13.2034 - accuracy: 0.3333 - val_loss: 8.8756 - val_accuracy: 0.3636
# Epoch 7/100
# 3/3 [==============================] - 0s 26ms/step - loss: 5.0218 - accuracy: 0.3011 - val_loss: 1.5781 - val_accuracy: 0.3636
# Epoch 8/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.7188 - accuracy: 0.3118 - val_loss: 0.6369 - val_accuracy: 0.3636
# Epoch 9/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8534 - accuracy: 0.3333 - val_loss: 1.0395 - val_accuracy: 0.3636
# Epoch 10/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1.0336 - accuracy: 0.3333 - val_loss: 1.5157 - val_accuracy: 0.3636
# Epoch 11/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.2062 - accuracy: 0.3333 - val_loss: 0.8402 - val_accuracy: 0.3636
# Epoch 12/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.8242 - accuracy: 0.3333 - val_loss: 0.4012 - val_accuracy: 0.3636
# Epoch 13/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3167 - accuracy: 0.3333 - val_loss: 0.1361 - val_accuracy: 0.3636
# Epoch 14/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.3333 - accuracy: 0.1935 - val_loss: 0.2700 - val_accuracy: 0.0909
# Epoch 15/100
# 3/3 [==============================] - 0s 27ms/step - loss: 0.3676 - accuracy: 0.1398 - val_loss: 0.1969 - val_accuracy: 0.3636
# Epoch 16/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4239 - accuracy: 0.2473 - val_loss: 0.0867 - val_accuracy: 0.3636
# Epoch 17/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.
100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0755 - accuracy: 0.3333 - val_loss: 0.0478 - val_accuracy: 0.3636
# Epoch 77/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0959 - accuracy: 0.3333 - val_loss: 0.0401 - val_accuracy: 0.3636
# Epoch 78/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0893 - accuracy: 0.3333 - val_loss: 0.0210 - val_accuracy: 0.3636
# Epoch 79/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0920 - accuracy: 0.3333 - val_loss: 0.0221 - val_accuracy: 0.3636
# Epoch 80/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1052 - accuracy: 0.3333 - val_loss: 0.0555 - val_accuracy: 0.3636
# Epoch 81/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0694 - accuracy: 0.3333 - val_loss: 0.0252 - val_accuracy: 0.3636
# Epoch 82/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0798 - accuracy: 0.3333 - val_loss: 0.0202 - val_accuracy: 0.3636
# Epoch 83/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1182 - accuracy: 0.3333 - val_loss: 0.0358 - val_accuracy: 0.3636
# Epoch 84/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0804 - accuracy: 0.3333 - val_loss: 0.0328 - val_accuracy: 0.3636
# Epoch 85/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0724 - accuracy: 0.3333 - val_loss: 0.0380 - val_accuracy: 0.3636
# Epoch 86/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0929 - accuracy: 0.3333 - val_loss: 0.0338 - val_accuracy: 0.3636
# Epoch 87/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0930 - accuracy: 0.3333 - val_loss: 0.0233 - val_accuracy: 0.3636
# Epoch 88/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0886 - accuracy: 0.3226 - val_loss: 0.0253 - val_accuracy: 0.3636
# Epoch 89/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0792 - accuracy: 0.3333 - val_loss: 0.0372 - val_accuracy: 0.3636
# Epoch 90/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0956 - accuracy: 0.3226 - val_loss: 0.0341 - val_accuracy: 0.3636
# Epoch 91/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1160 - accuracy: 0.3226 - val_loss: 0.0232 - val_accuracy: 0.3636
# Epoch 92/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0831 - accuracy: 0.3333 - val_loss: 0.0335 - val_accuracy: 0.3636
# Epoch 93/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0748 - accuracy: 0.3333 - val_loss: 0.0632 - val_accuracy: 0.3636
# Epoch 94/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0825 - accuracy: 0.3333 - val_loss: 0.0374 - val_accuracy: 0.3636
# Epoch 95/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0858 - accuracy: 0.3333 - val_loss: 0.0207 - val_accuracy: 0.3636
# Epoch 96/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0946 - accuracy: 0.3226 - val_loss: 0.0165 - val_accuracy: 0.3636
# Epoch 97/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0890 - accuracy: 0.3333 - val_loss: 0.0270 - val_accuracy: 0.3636
# Epoch 98/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0884 - accuracy: 0.3333 - val_loss: 0.0792 - val_accuracy: 0.3636
# Epoch 99/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0777 - accuracy: 0.3333 - val_loss: 0.0420 - val_accuracy: 0.3636
# Epoch 100/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0762 - accuracy: 0.3333 - val_loss: 0.0158 - val_accuracy: 0.3636
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, clases_map):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # prepara salida
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA"
        else:      
            clPred = clases_map[ idclPredRnd ]

        classReal.append( clReal )
        classPreds.append( clPred )

        strTitulo = 'Real: ' + clReal + ' / RNA: ' 
        strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'   
        strTitulo = strTitulo + ": " + ("ok" if (clPred==clReal) else "error!")

        # muestra comparación con la imagen
        print(strTitulo)

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    # agrega para poder mostrar la matrix de confusión completa
    pd.options.display.max_rows = 100
    pd.options.display.max_columns = 100
    print(cmtx)
    print("\n")

    # gráfico de comparación
    plt.title('Gráfico de Confusión:')
    plt.xlabel('Real')
    plt.ylabel('RNA')
    plt.scatter(classReal, classPreds)

# prueba con los datos de entrenamiento
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, y_train, CLASES)
# Out:
# *** Resultados con datos de Entrenamiento:
# Real: Virginica / RNA: Virginica (3.2964058): ok
# Real: Virginica / RNA: Virginica (2.8685915): ok
# Real: Virginica / RNA: Virginica (2.8214266): ok
# Real: Setosa / RNA: Setosa (1.1175131): ok
# Real: Versicolor / RNA: Versicolor (2.1084948): ok
# Real: Versicolor / RNA: Virginica (2.6454816): error!
# Real: Setosa / RNA: Setosa (0.88504386): ok
# Real: Versicolor / RNA: Versicolor (2.4681177): ok
# Real: Setosa / RNA: Setosa (0.98676914): ok
# Real: Versicolor / RNA: Versicolor (2.3448715): ok
# Real: Virginica / RNA: Virginica (3.132823): ok
# Real: Versicolor / RNA: Versicolor (2.3011959): ok
# Real: Versicolor / RNA: Versicolor (2.390049): ok
# Real: Virginica / RNA: Virginica (3.1625872): ok
# Real: Virginica / RNA: Virginica (2.8953502): ok
# Real: Virginica / RNA: Virginica (3.2326636): ok
# Real: Virginica / RNA: Virginica (2.5998683): ok
# Real: Setosa / RNA: Setosa (1.2116103): ok
# Real: Versicolor / RNA: Versicolor (2.4310832): ok
# Real: Setosa / RNA: Setosa (0.9930271): ok
# Real: Virginica / RNA: Virginica (2.9884243): ok
# Real: Setosa / RNA: Setosa (0.9587105): ok
# Real: Versicolor / RNA: Versicolor (2.0470796): ok
# Real: Virginica / RNA: Virginica (3.1260104): ok
# Real: Virginica / RNA: Virginica (2.5115): ok
# Real: Setosa / RNA: Setosa (0.906374): ok
# Real: Virginica / RNA: Virginica (2.595104): ok
# Real: Versicolor / RNA: Versicolor (2.2266202): ok
# Real: Setosa / RNA: Setosa (1.0423417): ok
# Real: Virginica / RNA: Virginica (2.6716793): ok
# Real: Setosa / RNA: Setosa (0.9873377): ok
# Real: Setosa / RNA: Setosa (0.99188995): ok
# Real: Versicolor / RNA: Versicolor (2.3808434): ok
# Real: Versicolor / RNA: Versicolor (2.1314328): ok
# Real: Virginica / RNA: Virginica (3.156456): ok
# Real: Versicolor / RNA: Versicolor (2.2667525): ok
# Real: Virginica / RNA: Virginica (3.1940322): ok
# Real: Setosa / RNA: Setosa (1.2911836): ok
# Real: Setosa / RNA: Setosa (1.0247287): ok
# Real: Versicolor / RNA: Versicolor (2.1583781): ok
# Real: Virginica / RNA: Virginica (2.8534164): ok
# Real: Versicolor / RNA: Versicolor (2.107535): ok
# Real: Setosa / RNA: Setosa (1.0412788): ok
# Real: Setosa / RNA: Setosa (1.0171783): ok
# Real: Setosa / RNA: Setosa (0.9489128): ok
# Real: Versicolor / RNA: Versicolor (1.9759693): ok
# Real: Setosa / RNA: Setosa (0.95351547): ok
# Real: Virginica / RNA: Virginica (3.4138985): ok
# Real: Virginica / RNA: Virginica (2.8214266): ok
# Real: Versicolor / RNA: Versicolor (2.3071418): ok
# Real: Setosa / RNA: Setosa (1.0084906): ok
# Real: Versicolor / RNA: Virginica (2.5474734): error!
# Real: Versicolor / RNA: Versicolor (2.163372): ok
# Real: Versicolor / RNA: Versicolor (2.3483374): ok
# Real: Versicolor / RNA: Versicolor (2.4717605): ok
# Real: Setosa / RNA: Setosa (1.0200229): ok
# Real: Versicolor / RNA: Versicolor (2.3745348): ok
# Real: Virginica / RNA: Virginica (2.7809024): ok
# Real: Versicolor / RNA: Versicolor (2.1853738): ok
# Real: Setosa / RNA: Setosa (1.0945516): ok
# Real: Versicolor / RNA: Versicolor (2.4175391): ok
# Real: Versicolor / RNA: Versicolor (2.233158): ok
# Real: Versicolor / RNA: Versicolor (2.3771152): ok
# Real: Versicolor / RNA: Versicolor (1.9540416): ok
# Real: Virginica / RNA: Virginica (2.8455038): ok
# Real: Virginica / RNA: Virginica (2.9755914): ok
# Real: Versicolor / RNA: Versicolor (1.9758662): ok
# Real: Setosa / RNA: Setosa (1.0365493): ok
# Real: Setosa / RNA: Setosa (0.862236): ok
# Real: Setosa / RNA: Setosa (0.94255203): ok
# Real: Virginica / RNA: Virginica (3.109725): ok
# Real: Versicolor / RNA: Versicolor (2.4756916): ok
# Real: Versicolor / RNA: Virginica (2.5967355): error!
# Real: Virginica / RNA: Virginica (3.1150327): ok
# Real: Setosa / RNA: Setosa (1.0654299): ok
# Real: Setosa / RNA: Setosa (0.955866): ok
# Real: Setosa / RNA: Setosa (0.96437633): ok
# Real: Setosa / RNA: Setosa (1.0554551): ok
# Real: Setosa / RNA: Setosa (1.2620384): ok
# Real: Versicolor / RNA: Versicolor (2.3924282): ok
# Real: Setosa / RNA: Setosa (0.93225956): ok
# Real: Virginica / RNA: Virginica (2.7153282): ok
# Real: Setosa / RNA: Setosa (0.9730134): ok
# Real: Virginica / RNA: Virginica (3.1714015): ok
# Real: Setosa / RNA: Setosa (1.0027034): ok
# Real: Versicolor / RNA: Versicolor (2.3357186): ok
# Real: Virginica / RNA: Virginica (2.8097596): ok
# Real: Virginica / RNA: Virginica (3.2668185): ok
# Real: Virginica / RNA: Virginica (3.0604706): ok
# Real: Setosa / RNA: Setosa (1.0004508): ok
# Real: Virginica / RNA: Virginica (2.741288): ok
# Real: Virginica / RNA: Virginica (2.8691096): ok
# Real: Setosa / RNA: Setosa (1.0476161): ok
# Real: Setosa / RNA: Setosa (0.955866): ok
# Real: Setosa / RNA: Setosa (0.97875327): ok
# Real: Virginica / RNA: Virginica (3.0366235): ok
# Real: Versicolor / RNA: Versicolor (2.2427044): ok
# Real: Versicolor / RNA: Versicolor (2.3718677): ok
# Real: Versicolor / RNA: Versicolor (2.0207553): ok
# Real: Virginica / RNA: Virginica (3.0108175): ok
# Real: Setosa / RNA: Setosa (1.1524745): ok
# Real: Virginica / RNA: Virginica (2.9740982): ok
# Real: Virginica / RNA: Virginica (2.6860561): ok
# Real: Versicolor / RNA: Versicolor (1.9946687): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        35
#   Versicolor       1.00      0.91      0.96        35
#    Virginica       0.92      1.00      0.96        34
#
#     accuracy                           0.97       104
#    macro avg       0.97      0.97      0.97       104
# weighted avg       0.97      0.97      0.97       104
#
#
# Matriz de Confusión:
#               p:na  p:Setosa  p:Versicolor  p:Virginica
# r:na             0         0             0            0
# r:Setosa         0        35             0            0
# r:Versicolor     0         0            32            3
# r:Virginica      0         0             0           34

# %% [markdown]
# 6) Evaluar el modelo de la RNA entrenado con los datos de prueba:

# %%
 #@title Probar red entrenada con datos de prueba
 # evalua al modelo entrenado
resEval = model.evaluate(x_test, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de prueba
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(x_test, y_test, CLASES)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0578 - accuracy: 0.3261
#
# >Evaluación del Modelo:
#     - Error:  0.0578145757317543
#     - Exactitud:  32.608696818351746
#
#
#
#
# *** Resultados con datos de Prueba:
# Real: Versicolor / RNA: Versicolor (2.259408): ok
# Real: Setosa / RNA: Setosa (1.1611115): ok
# Real: Virginica / RNA: Virginica (3.1551557): ok
# Real: Versicolor / RNA: Versicolor (2.1056502): ok
# Real: Versicolor / RNA: Versicolor (2.361628): ok
# Real: Setosa / RNA: Setosa (0.9942167): ok
# Real: Setosa / RNA: Setosa (0.98785573): ok
# Real: Setosa / RNA: Setosa (0.8909393): ok
# Real: Versicolor / RNA: Versicolor (2.4256818): ok
# Real: Virginica / RNA: Virginica (2.6963987): ok
# Real: Setosa / RNA: Setosa (1.0354865): ok
# Real: Versicolor / RNA: Versicolor (2.4430065): ok
# Real: Virginica / RNA: Virginica (2.515357): ok
# Real: Setosa / RNA: Setosa (0.9913721): ok
# Real: Virginica / RNA: Virginica (2.9336772): ok
# Real: Virginica / RNA: Virginica (2.8877487): ok
# Real: Versicolor / RNA: Versicolor (2.1950212): ok
# Real: Virginica / RNA: Virginica (2.763112): ok
# Real: Virginica / RNA: Virginica (3.1042967): ok
# Real: Setosa / RNA: Setosa (0.9740474): ok
# Real: Virginica / RNA: Virginica (2.746927): ok
# Real: Virginica / RNA: Virginica (3.0637221): ok
# Real: Virginica / RNA: Virginica (2.6687238): ok
# Real: Setosa / RNA: Setosa (0.955866): ok
# Real: Versicolor / RNA: Virginica (2.555439): error!
# Real: Setosa / RNA: Setosa (1.0390028): ok
# Real: Setosa / RNA: Setosa (1.0166603): ok
# Real: Virginica / RNA: Virginica (2.9194582): ok
# Real: Versicolor / RNA: Versicolor (2.2686138): ok
# Real: Virginica / RNA: Virginica (3.0943456): ok
# Real: Virginica / RNA: Virginica (3.2968707): ok
# Real: Setosa / RNA: Setosa (1.095638): ok
# Real: Setosa / RNA: Setosa (0.79745793): ok
# Real: Versicolor / RNA: Versicolor (2.210662): ok
# Real: Versicolor / RNA: Versicolor (2.2564604): ok
# Real: Virginica / RNA: Virginica (2.889721): ok
# Real: Virginica / RNA: Virginica (3.2859592): ok
# Real: Setosa / RNA: Setosa (1.0279646): ok
# Real: Versicolor / RNA: Virginica (2.6326327): error!
# Real: Versicolor / RNA: Versicolor (2.273164): ok
# Real: Virginica / RNA: Virginica (3.1145892): ok
# Real: Versicolor / RNA: Versicolor (2.2866921): ok
# Real: Setosa / RNA: Setosa (1.1146414): ok
# Real: Versicolor / RNA: Versicolor (2.0219953): ok
# Real: Setosa / RNA: Setosa (0.9862007): ok
# Real: Versicolor / RNA: Versicolor (2.2340674): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        15
#   Versicolor       1.00      0.87      0.93        15
#    Virginica       0.89      1.00      0.94        16
#
#     accuracy                           0.96        46
#    macro avg       0.96      0.96      0.96        46
# weighted avg       0.96      0.96      0.96        46
#
#
# Matriz de Confusión:
#               p:na  p:Setosa  p:Versicolor  p:Virginica
# r:na             0         0             0            0
# r:Setosa         0        15             0            0
# r:Versicolor     0         0            13            2
# r:Virginica      0         0             0           16

# %%
#@title Inspeccionar influencia de los Atributos de Entrada
# fuente: https://scikit-learn.org/stable/modules/permutation_importance.html

from sklearn.inspection import permutation_importance
from sklearn.metrics import make_scorer

# define la función para calculo del error
# contando la cantidad de diferencias 
# entre clase real y predecida
def calc_error(realClasses, predClasses):
    res = 0
    for i in range(len(realClasses)):
      # determina la clase predecida
      if tipo_output_softMax:
          ## determina clase predecida de acuerdo a la que tiene mayor valor
          idclPred = int( np.argmax(predClasses[i], axis=0) )
          idclPredRnd = idclPred
          idReal = int( np.argmax(realClasses[i], axis=0) )
      else:
          ## determina clase predecida de acuerdo al umbral de clasificación
          idclPred = predClasses[i][0]       
          idclPredRnd = int(idclPred)
          if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(CLASES):
                  idclPredRnd = idclPredRnd + 1
          idReal = int(realClasses[i])
      res = res + abs(idReal-idclPredRnd)
    return res
errorScorer = make_scorer(calc_error, greater_is_better=False)

def realizarInspeccion(tipoDatos, xScoring, yScoring):
  print("")
  # Genera el scoring usando permutaciones 
  # para realizar el cálculo del scoring
  scoring = {'R2 score':'r2', 
             'Error de Clase':errorScorer}
  r_multi  = permutation_importance(model, xScoring, yScoring,
                              n_repeats=30,
                              random_state=0,
                              scoring=scoring)

  # muesta las métricas
  print("> Cálculo de influencia con datos de " + tipoDatos + ":")
  for metric in r_multi:
    print("- Métrica "+metric+":")
    r = r_multi[metric]
    i = 0
    for imp in r.importances:
        print(f"\tAtributo {i:<2} [ {df.columns[i]} ]:  "
              f"{np.mean(imp):.3f} ± {np.std(imp):.3f}"
              f" [ {np.min(imp):.3f}; {np.max(imp):.3f} ]"
              )
        i = i + 1
  return

# Ejecuta con ambos sets de datos
realizarInspeccion(tipoDatos="Entrenamiento",  
                  xScoring = x_train,
                  yScoring = (y_trainEnc if tipo_output_softMax else y_train))

realizarInspeccion(tipoDatos="Prueba",  
                  xScoring = x_test,
                  yScoring = (y_testEnc if tipo_output_softMax else y_test))
# Out:
# > Cálculo de influencia con datos de Entrenamiento:
# - Métrica R2 score:
# 	Atributo 0  [ LargoSepalo ]:  -0.002 ± 0.002 [ -0.007; 0.006 ]
# 	Atributo 1  [ AnchoSepalo ]:  0.017 ± 0.005 [ 0.007; 0.030 ]
# 	Atributo 2  [ LargoPetalo ]:  0.068 ± 0.013 [ 0.043; 0.107 ]
# 	Atributo 3  [ AnchoPetalo ]:  0.959 ± 0.104 [ 0.798; 1.163 ]
# - Métrica Error de Clase:
# 	Atributo 0  [ LargoSepalo ]:  0.333 ± 0.745 [ -1.000; 2.000 ]
# 	Atributo 1  [ AnchoSepalo ]:  3.300 ± 1.441 [ 1.000; 6.000 ]
# 	Atributo 2  [ LargoPetalo ]:  8.633 ± 2.549 [ 3.000; 15.000 ]
# 	Atributo 3  [ AnchoPetalo ]:  66.933 ± 6.027 [ 58.000; 80.000 ]
#
# > Cálculo de influencia con datos de Prueba:
# - Métrica R2 score:
# 	Atributo 0  [ LargoSepalo ]:  0.004 ± 0.004 [ -0.002; 0.010 ]
# 	Atributo 1  [ AnchoSepalo ]:  0.002 ± 0.006 [ -0.011; 0.017 ]
# 	Atributo 2  [ LargoPetalo ]:  0.076 ± 0.019 [ 0.035; 0.112 ]
# 	Atributo 3  [ AnchoPetalo ]:  0.968 ± 0.197 [ 0.613; 1.412 ]
# - Métrica Error de Clase:
# 	Atributo 0  [ LargoSepalo ]:  0.433 ± 0.496 [ 0.000; 1.000 ]
# 	Atributo 1  [ AnchoSepalo ]:  -0.067 ± 0.814 [ -2.000; 2.000 ]
# 	Atributo 2  [ LargoPetalo ]:  3.167 ± 1.267 [ 1.000; 5.000 ]
# 	Atributo 3  [ AnchoPetalo ]:  28.867 ± 4.039 [ 22.000; 36.000 ]
