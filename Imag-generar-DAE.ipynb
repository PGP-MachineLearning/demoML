# %% [markdown]
# # Demo de Deep Autoencoder (DAE) para procesar imágenes e intentar reconstruirlas
# Basado en:
#
# https://blog.keras.io/building-autoencoders-in-keras.html
#
#
# https://towardsdatascience.com/deep-autoencoders-using-tensorflow-c68f075fd1a3

# %% [markdown]
# 1) Importar librerías:

# %%
#@title Librerías a usar
from tensorflow import keras
from keras.layers import Input, Dense
from keras.models import Model
#from keras.utils import plot_model

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

from PIL import Image

print("\nLibrerías importadas")
# Out:
# Librerías importadas

# %% [markdown]
# 2) Definir la configuración del modelo DAE:

# %%
## selección de los parámetros 

# 
#@markdown ### Parámetros de imágenes:
imagen_largo_ancho = 64 #@param {type:"integer"}
imagen_color = True #@param {type:"boolean"}

#@markdown ### Parámetros de la red:
rna_cant_neuronas_capas_ocultas = '6048, 1024,  256, 64, 24' #@param {type:"string"}
rna_cant_neuronas_features =  4#@param {type:"integer"}
rna_cant_epocas_entrenamiento = 1000 #@param {type:"integer"}


## aplicación de los parámetros elegidos

# tamaño de las imágenes
if imagen_largo_ancho<=10:
  imagen_largo_ancho = 10
IMAGE_SHAPE = (imagen_largo_ancho, imagen_largo_ancho, (3 if imagen_color else 1))

# cantidad de neuronas ocultas para features (datos comprimidos o codings)
num_features = (2 if rna_cant_neuronas_features<2 else rna_cant_neuronas_features)

# define tamaño de datos de entrada 
num_inputs = IMAGE_SHAPE[0] * IMAGE_SHAPE[1] * IMAGE_SHAPE[2]
num_outputs = num_inputs

# cantidad de neuronas ocultas 
##hidden_layers = [ num_inputs//5, num_inputs//20, num_inputs//100 ]
dae_layers = []
for val in rna_cant_neuronas_capas_ocultas.split(','):
  dae_layers.append( int(val) )
      
#  agrega la capa de features a las capas
dae_layers.append( num_features ) 

# cantidad de neuronas ocultas para la parte Decoder 
#   (usa la la lista de Encoder inversa)
for eachEncLayer in dae_layers[0:len(dae_layers)-1][::-1]:
  dae_layers.append( eachEncLayer )

# cantidad de épocas del entrenamiento
cantEpocas = (100 if rna_cant_epocas_entrenamiento<1 else rna_cant_epocas_entrenamiento)

print("Configuración del DAE definida: [", num_inputs, dae_layers, num_outputs, "] ")
# Out:
# Configuración del DAE definida: [ 12288 [6048, 1024, 256, 64, 24, 4, 24, 64, 256, 1024, 6048] 12288 ]

# %% [markdown]
# 3) Montar el Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# directorio local en Google Drive
path = 'gdrive/My Drive/IA/demoML/imagenes/ANIMALES' #@param {type:"string"}
path_entrenamiento = '/train'  #@param {type:"string"}
path_prueba = '/test'  #@param {type:"string"}

imagPath_train = path + path_entrenamiento
imagPath_test = path + path_prueba
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 4) Cargar imágenes para entrenar el modelo DAE:

# %%
#@title Cargar Imágenes

# define función para cargar las imágenes
def cargarImagenes(imagPath):
  classes_ori = [] 
  images_ori = []
  esDA_ori = []

  all_dirs = os.listdir( imagPath )
  for each_dir in all_dirs:

      auxiPath = imagPath + '/' + each_dir 
      imagFN  = os.listdir( auxiPath )
      for each_imagFN in imagFN:

            esImagDA = (each_imagFN[:2] == 'da')
            
            # abre la imagen
            imag = Image.open(auxiPath + "/" + each_imagFN)
            
            # ajusta el tamaño
            if IMAGE_SHAPE[2]==1:              
              tipoImage = 'L'
            else:                
              tipoImage = 'RGB'
            imag = imag.convert(tipoImage)
            imag = imag.resize((IMAGE_SHAPE[0], IMAGE_SHAPE[1]), Image.ANTIALIAS)          
            
            # transforma a un vector de nros
            arImag = np.array(imag)
            
            # agrega a los vectores
            classes_ori.append( each_dir )
            images_ori.append( arImag )
            esDA_ori.append( esImagDA )

  return classes_ori, images_ori, esDA_ori, tipoImage

# carga las imagenes de entrenamiento
classes_train, images_train, esDAimag_train, tipoImage_train = cargarImagenes(imagPath_train)
print("> Para Entrenamiento: ")
print("- Clases cargadas: ", len(classes_train))
print("- Imágenes cargadas: ", len(classes_train))

if len(classes_train)>0:
  print("- Ejemplo ", classes_train[0], " ", images_train[0].shape, ": ")
  display( Image.fromarray(images_train[0], tipoImage_train) )

# carga las imagenes de prueba
classes_test, images_test, esDAimag_test, tipoImage_test = cargarImagenes(imagPath_test)
print("\n\n> Para Prueba: ")
print("- Clases cargadas: ", len(classes_test))
print("- Imágenes cargadas: ", len(images_test))

if len(classes_test)>0:
  print("- Ejemplo ", classes_test[0], " ", images_test[0].shape, ": ")
  display( Image.fromarray(images_test[0], tipoImage_test) )
# Out:
# > Para Entrenamiento:
# - Clases cargadas:  144
# - Imágenes cargadas:  144
# - Ejemplo  gato   (64, 64, 3) :
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FC9589D9950>
# > Para Prueba:
# - Clases cargadas:  36
# - Imágenes cargadas:  36
# - Ejemplo  gato   (64, 64, 3) :
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FC9589D0C50>

# %%
#@title Preparar imágenes

# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8))
    plt.gray()
  else:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE).astype(np.uint8))
  plt.axis("off")  

# define función auxiliar para preparar la lista de imágenes a procesar
def prepare_imageList(imagList):    
  auxiAr = np.array(imagList).astype('float32') / 255.
  auxiAr = auxiAr.reshape((len(auxiAr), num_inputs))  
  return np.array(auxiAr)

# define vector auxiliar de datos de entrada para usar en el entrenamiento y prueba
x_train = prepare_imageList(images_train)
x_test = prepare_imageList(images_test)

print("> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
print("\n\n> Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
if len(x_train)>0:
  plot_image(x_train[0])
# Out:
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (144, 12288)
#
#
# > Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (36, 12288)

# %% [markdown]
# 5) Creación del modelo DAE:

# %%
#@title Establecer el modelo
# define la arquitectura de capas del Deep Autoencoder
# teniendo en cuenta la definición dada anteriomente
input_data_Lay = Input(shape=(num_inputs,), name='input_data') # capa de entrada
eachLay = input_data_Lay
auxName = 'enc_'
auxId = 1 
for num_hid in dae_layers:  

    # define el nombre de la capa oculta
    if num_features==num_hid:
        auxlayerName = 'features'
        auxName = 'dec_'
        auxId = auxId - 1
    else:
        auxlayerName = auxName+str(auxId)
        if auxName == 'enc_':
          auxId = auxId + 1
        else:
          auxId = auxId - 1

    # agrega la capa oculta
    eachLay = Dense(num_hid, activation='relu', name=auxlayerName)(eachLay) # capas ocultas

    if num_features==num_hid:
      features_Lay = eachLay

##output_data_Lay = Dense(num_outputs, activation=None, name='output_data')(eachLay) # capa de salida
output_data_Lay = Dense(num_outputs, activation='sigmoid', name='output_data')(eachLay) # capa de salida

# genera el modelo Deep Autoencoder
DAEmodel = Model(input_data_Lay, output_data_Lay, name='DAE')
if imagen_color:
  DAEmodel.compile(optimizer='adam', loss='mse')
else:
  DAEmodel.compile(optimizer='adam', loss='binary_crossentropy')

print("Modelo DAE creado con ", len(DAEmodel.layers), " capas:")
DAEmodel.summary()
print("\n")
#plot_model(DAEmodel, show_layer_names=True, show_shapes=True)
# Out:
# Modelo DAE creado con  13  capas:
# Model: "DAE"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_data (InputLayer)     [(None, 12288)]           0
#
#  enc_1 (Dense)               (None, 6048)              74323872
#
#  enc_2 (Dense)               (None, 1024)              6194176
#
#  enc_3 (Dense)               (None, 256)               262400
#
#  enc_4 (Dense)               (None, 64)                16448
#
#  enc_5 (Dense)               (None, 24)                1560
#
#  features (Dense)            (None, 4)                 100
#
#  dec_5 (Dense)               (None, 24)                120
#
#  dec_4 (Dense)               (None, 64)                1600
#
#  dec_3 (Dense)               (None, 256)               16640
#
#  dec_2 (Dense)               (None, 1024)              263168
#
#  dec_1 (Dense)               (None, 6048)              6199200
#
#  output_data (Dense)         (None, 12288)             74330112
#
# =================================================================
# Total params: 161,609,396
# Trainable params: 161,609,396
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 5) Entrenar el modelo DAE:

# %%
#@title Entrenar

# lleva a cabo el entrenamiento
# usando los mismos datos como entrada y salida
history = DAEmodel.fit(x_train, x_train,
                epochs = cantEpocas,
                shuffle=True)
# Out:
# Epoch 1/1000
# 5/5 [==============================] - 3s 46ms/step - loss: 0.0598
# Epoch 2/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0584
# Epoch 3/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0576
# Epoch 4/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0560
# Epoch 5/1000
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0548
# Epoch 6/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0532
# Epoch 7/1000
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0527
# Epoch 8/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0521
# Epoch 9/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0511
# Epoch 10/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0505
# Epoch 11/1000
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0505
# Epoch 12/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0500
# Epoch 13/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0501
# Epoch 14/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0493
# Epoch 15/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0490
# Epoch 16/1000
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0482
# Epoch 17/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0467
# Epoch 18/1000
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0463
# Epoch 19/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0461
# Epoch 20/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0456
# Epoch 21/1000
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0454
# Epoch 22/1000
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0456
# Epoch 23/1000
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0453
# Epoch 24/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0449
# Epoch 25/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0438
# Epoch 26/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0443
# Epoch 27/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0437
# Epoch 28/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0432
# Epoch 29/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0428
# Epoch 30/1000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0422
# Epoch 31/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0415
# Epoch 32/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0409
# Epoch 33/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0402
# Epoch 34/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0399
# Epoch 35/1000
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0400
# Epoch 36/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0408
# Epoch 37/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0404
# Epoch 38/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0397
# Epoch 39/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0396
# Epoch 40/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0390
# Epoch 41/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0389
# Epoch 42/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.
1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0024
# Epoch 303/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0023
# Epoch 304/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0022
# Epoch 305/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0020
# Epoch 306/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0019
# Epoch 307/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0018
# Epoch 308/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0017
# Epoch 309/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0017
# Epoch 310/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0017
# Epoch 311/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0019
# Epoch 312/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0020
# Epoch 313/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0018
# Epoch 314/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0019
# Epoch 315/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0019
# Epoch 316/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0019
# Epoch 317/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0019
# Epoch 318/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0019
# Epoch 319/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0019
# Epoch 320/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0018
# Epoch 321/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0019
# Epoch 322/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0026
# Epoch 323/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0025
# Epoch 324/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0021
# Epoch 325/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0024
# Epoch 326/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0020
# Epoch 327/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0021
# Epoch 328/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0022
# Epoch 329/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0020
# Epoch 330/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0019
# Epoch 331/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0017
# Epoch 332/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0014
# Epoch 333/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0013
# Epoch 334/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0013
# Epoch 335/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0011
# Epoch 336/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 9.4660e-04
# Epoch 337/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 8.4150e-04
# Epoch 338/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 7.6058e-04
# Epoch 339/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 6.9647e-04
# Epoch 340/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 6.2403e-04
# Epoch 341/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 6.0205e-04
# Epoch 342/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 5.6281e-04
# Epoch 343/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 5.1220e-04
# Epoch 344/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.9623e-04
# Epoch 345/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 4.4860e-04
# Epoch 346/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.2921e-04
# Epoch 347/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.1555e-04
# Epoch 348/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 4.0173e-04
# Epoch 349/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 3.8319e-04
# Epoch 350/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 3.6784e-04
# Epoch 351/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 3.6734e-04
# Epoch 352/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 3.5787e-04
# Epoch 353/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 3.7091e-04
# Epoch 354/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 3.7818e-04
# Epoch 355/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 3.7915e-04
# Epoch 356/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 3.9846e-04
# Epoch 357/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 3.8711e-04
# Epoch 358/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.1049e-04
# Epoch 359/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 4.0642e-04
# Epoch 360/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.6500e-04
# Epoch 361/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 5.3356e-04
# Epoch 362/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 6.3982e-04
# Epoch 363/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 6.6356e-04
# Epoch 364/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 6.8999e-04
# Epoch 365/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 6.1379e-04
# Epoch 366/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 6.4743e-04
# Epoch 367/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0011
# Epoch 368/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0010
# Epoch 369/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0011
# Epoch 370/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0011
# Epoch 371/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0011
# Epoch 372/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0016
# Epoch 373/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0014
# Epoch 374/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0053
# Epoch 375/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0075
# Epoch 376/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0088
# Epoch 377/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0116
# Epoch 378/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0140
# Epoch 379/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0127
# Epoch 380/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0134
# Epoch 381/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0105
# Epoch 382/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0107
# Epoch 383/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0121
# Epoch 384/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0129
# Epoch 385/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0134
# Epoch 386/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0125
# Epoch 387/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0114
# Epoch 388/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0105
# Epoch 389/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0110
# Epoch 390/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0101
# Epoch 391/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0072
# Epoch 392/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0068
# Epoch 393/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0049
# Epoch 394/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0056
# Epoch 395/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0066
# Epoch 396/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0078
# Epoch 397/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0081
# Epoch 398/1000
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0069
# Epoch 399/1000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0047
# Epoch 400/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0042
# Epoch 401/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0040
# Epoch 402/1000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0028
# Epoch 403/1000
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0026
# Epoch 404/1000
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0027
# Epoch 405/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0021
# Epoch 406/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0017
# Epoch 407/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0017
# Epoch 408/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0016
# Epoch 409/1000
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0018
# Epoch 410/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0015
# Epoch 411/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0027
# Epoch 412/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0019
# Epoch 413/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0018
# Epoch 414/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0019
# Epoch 415/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0015
# Epoch 416/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0013
# Epoch 417/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0011
# Epoch 418/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 8.5172e-04
# Epoch 419/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 8.6650e-04
# Epoch 420/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 6.4076e-04
# Epoch 421/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 5.5819e-04
# Epoch 422/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.9076e-04
# Epoch 423/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 3.7528e-04
# Epoch 424/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 3.5262e-04
# Epoch 425/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 3.1693e-04
# Epoch 426/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 2.8630e-04
# Epoch 427/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 2.7124e-04
# Epoch 428/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 2.5674e-04
# Epoch 429/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 2.4568e-04
# Epoch 430/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.4851e-04
# Epoch 431/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 2.3035e-04
# Epoch 432/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 2.2354e-04
# Epoch 433/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.1940e-04
# Epoch 434/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.9837e-04
# Epoch 435/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.0133e-04
# Epoch 436/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.9549e-04
# Epoch 437/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 2.0414e-04
# Epoch 438/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.1287e-04
# Epoch 439/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.9569e-04
# Epoch 440/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.8936e-04
# Epoch 441/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.8433e-04
# Epoch 442/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.8424e-04
# Epoch 443/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.9986e-04
# Epoch 444/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 2.0191e-04
# Epoch 445/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.9706e-04
# Epoch 446/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.9008e-04
# Epoch 447/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.8656e-04
# Epoch 448/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.6898e-04
# Epoch 449/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.7190e-04
# Epoch 450/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.6722e-04
# Epoch 451/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.4744e-04
# Epoch 452/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.3945e-04
# Epoch 453/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2858e-04
# Epoch 454/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2607e-04
# Epoch 455/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2710e-04
# Epoch 456/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.3276e-04
# Epoch 457/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2850e-04
# Epoch 458/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.3389e-04
# Epoch 459/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.3285e-04
# Epoch 460/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2107e-04
# Epoch 461/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.3879e-04
# Epoch 462/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2859e-04
# Epoch 463/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.1910e-04
# Epoch 464/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.1304e-04
# Epoch 465/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0830e-04
# Epoch 466/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.1737e-04
# Epoch 467/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1200e-04
# Epoch 468/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.0162e-04
# Epoch 469/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1103e-04
# Epoch 470/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0766e-04
# Epoch 471/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 9.3579e-05
# Epoch 472/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 7.9943e-05
# Epoch 473/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 7.1521e-05
# Epoch 474/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 6.4790e-05
# Epoch 475/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 6.2112e-05
# Epoch 476/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 5.8305e-05
# Epoch 477/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 5.5463e-05
# Epoch 478/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 5.3109e-05
# Epoch 479/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 5.0866e-05
# Epoch 480/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 4.8996e-05
# Epoch 481/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.6687e-05
# Epoch 482/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.5728e-05
# Epoch 483/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.4396e-05
# Epoch 484/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 4.1999e-05
# Epoch 485/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.0305e-05
# Epoch 486/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 3.9980e-05
# Epoch 487/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.0883e-05
# Epoch 488/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 3.7670e-05
# Epoch 489/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 3.7201e-05
# Epoch 490/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 3.5575e-05
# Epoch 491/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 3.3901e-05
# Epoch 492/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 3.3183e-05
# Epoch 493/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 3.1839e-05
# Epoch 494/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 3.1157e-05
# Epoch 495/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 3.0515e-05
# Epoch 496/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 2.9327e-05
# Epoch 497/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.8848e-05
# Epoch 498/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 2.8733e-05
# Epoch 499/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.7059e-05
# Epoch 500/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.6932e-05
# Epoch 501/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 2.6389e-05
# Epoch 502/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.5501e-05
# Epoch 503/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 2.5360e-05
# Epoch 504/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 2.4640e-05
# Epoch 505/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.4799e-05
# Epoch 506/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 2.4066e-05
# Epoch 507/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.3313e-05
# Epoch 508/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.2694e-05
# Epoch 509/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.2183e-05
# Epoch 510/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 2.1644e-05
# Epoch 511/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.1224e-05
# Epoch 512/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 2.0850e-05
# Epoch 513/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 2.0387e-05
# Epoch 514/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.0235e-05
# Epoch 515/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.9717e-05
# Epoch 516/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.9538e-05
# Epoch 517/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 1.9313e-05
# Epoch 518/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.8945e-05
# Epoch 519/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.8721e-05
# Epoch 520/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.8504e-05
# Epoch 521/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.8326e-05
# Epoch 522/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.8094e-05
# Epoch 523/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.7820e-05
# Epoch 524/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.7541e-05
# Epoch 525/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.7404e-05
# Epoch 526/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.7073e-05
# Epoch 527/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.6787e-05
# Epoch 528/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.6597e-05
# Epoch 529/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.6464e-05
# Epoch 530/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.6161e-05
# Epoch 531/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.5947e-05
# Epoch 532/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.5870e-05
# Epoch 533/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.5573e-05
# Epoch 534/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.5318e-05
# Epoch 535/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.5178e-05
# Epoch 536/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.5021e-05
# Epoch 537/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.4779e-05
# Epoch 538/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.4548e-05
# Epoch 539/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.4362e-05
# Epoch 540/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.4205e-05
# Epoch 541/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.4011e-05
# Epoch 542/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.3864e-05
# Epoch 543/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.3737e-05
# Epoch 544/1000
# 5/5 [==============================] - 0s 42ms/step - loss: 1.3558e-05
# Epoch 545/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 1.3431e-05
# Epoch 546/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.3282e-05
# Epoch 547/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.3145e-05
# Epoch 548/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.3031e-05
# Epoch 549/1000
# 5/5 [==============================] - 0s 37ms/step - loss: 1.2899e-05
# Epoch 550/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2814e-05
# Epoch 551/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.2678e-05
# Epoch 552/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.2519e-05
# Epoch 553/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.2366e-05
# Epoch 554/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2263e-05
# Epoch 555/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.2130e-05
# Epoch 556/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.1978e-05
# Epoch 557/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.1868e-05
# Epoch 558/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.1793e-05
# Epoch 559/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1671e-05
# Epoch 560/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.1621e-05
# Epoch 561/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.1502e-05
# Epoch 562/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.1398e-05
# Epoch 563/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.1406e-05
# Epoch 564/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1364e-05
# Epoch 565/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.1172e-05
# Epoch 566/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0998e-05
# Epoch 567/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.0978e-05
# Epoch 568/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 1.0856e-05
# Epoch 569/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0755e-05
# Epoch 570/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.0620e-05
# Epoch 571/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0541e-05
# Epoch 572/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.0408e-05
# Epoch 573/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0301e-05
# Epoch 574/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0190e-05
# Epoch 575/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0091e-05
# Epoch 576/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 9.9723e-06
# Epoch 577/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 9.9053e-06
# Epoch 578/1000
# ...
# Epoch 815/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.2116e-05
# Epoch 816/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1976e-05
# Epoch 817/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.1851e-05
# Epoch 818/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1714e-05
# Epoch 819/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1591e-05
# Epoch 820/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1454e-05
# Epoch 821/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1328e-05
# Epoch 822/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1210e-05
# Epoch 823/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.1103e-05
# Epoch 824/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.0970e-05
# Epoch 825/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0856e-05
# Epoch 826/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0752e-05
# Epoch 827/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0635e-05
# Epoch 828/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 1.0532e-05
# Epoch 829/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.0432e-05
# Epoch 830/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0319e-05
# Epoch 831/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.0223e-05
# Epoch 832/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.0122e-05
# Epoch 833/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0031e-05
# Epoch 834/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 9.9283e-06
# Epoch 835/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 9.8466e-06
# Epoch 836/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 9.7493e-06
# Epoch 837/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 9.6650e-06
# Epoch 838/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 9.5658e-06
# Epoch 839/1000
# 5/5 [==============================] - 0s 40ms/step - loss:
1000
# 5/5 [==============================] - 0s 40ms/step - loss: 5.2001e-06
# Epoch 928/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 5.2742e-06
# Epoch 929/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 5.1108e-06
# Epoch 930/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 5.0526e-06
# Epoch 931/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 5.0381e-06
# Epoch 932/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 4.9935e-06
# Epoch 933/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.9442e-06
# Epoch 934/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.8691e-06
# Epoch 935/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.8489e-06
# Epoch 936/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 4.8227e-06
# Epoch 937/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.8297e-06
# Epoch 938/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 4.8234e-06
# Epoch 939/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.8983e-06
# Epoch 940/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.8547e-06
# Epoch 941/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 5.0595e-06
# Epoch 942/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.9227e-06
# Epoch 943/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.9001e-06
# Epoch 944/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.9057e-06
# Epoch 945/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.8745e-06
# Epoch 946/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.7815e-06
# Epoch 947/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.7681e-06
# Epoch 948/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.6992e-06
# Epoch 949/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 4.6466e-06
# Epoch 950/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.9163e-06
# Epoch 951/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.9564e-06
# Epoch 952/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 4.5152e-06
# Epoch 953/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.8163e-06
# Epoch 954/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.5853e-06
# Epoch 955/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 4.6197e-06
# Epoch 956/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.8364e-06
# Epoch 957/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.8474e-06
# Epoch 958/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.7307e-06
# Epoch 959/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 4.7126e-06
# Epoch 960/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.6669e-06
# Epoch 961/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 4.8997e-06
# Epoch 962/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 6.3438e-06
# Epoch 963/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 6.0517e-06
# Epoch 964/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.1035e-05
# Epoch 965/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 8.2045e-06
# Epoch 966/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 7.9090e-06
# Epoch 967/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 7.1954e-06
# Epoch 968/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 7.1112e-06
# Epoch 969/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 9.4738e-06
# Epoch 970/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 9.5978e-06
# Epoch 971/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 9.6394e-06
# Epoch 972/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 9.1136e-06
# Epoch 973/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 9.2775e-06
# Epoch 974/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 1.6114e-05
# Epoch 975/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 7.2312e-05
# Epoch 976/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 8.8459e-05
# Epoch 977/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.2067e-04
# Epoch 978/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.4836e-04
# Epoch 979/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.5752e-04
# Epoch 980/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.6256e-04
# Epoch 981/1000
# 5/5 [==============================] - 0s 37ms/step - loss: 1.4802e-04
# Epoch 982/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.2475e-04
# Epoch 983/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0281e-04
# Epoch 984/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 8.6286e-05
# Epoch 985/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 7.0082e-05
# Epoch 986/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 6.9732e-05
# Epoch 987/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 5.5120e-05
# Epoch 988/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 4.6483e-05
# Epoch 989/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 4.2323e-05
# Epoch 990/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 3.3552e-05
# Epoch 991/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 2.5753e-05
# Epoch 992/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 2.1799e-05
# Epoch 993/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.9953e-05
# Epoch 994/1000
# 5/5 [==============================] - 0s 39ms/step - loss: 2.0140e-05
# Epoch 995/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.8941e-05
# Epoch 996/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.9284e-05
# Epoch 997/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.7578e-05
# Epoch 998/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.6652e-05
# Epoch 999/1000
# 5/5 [==============================] - 0s 40ms/step - loss: 1.6460e-05
# Epoch 1000/1000
# 5/5 [==============================] - 0s 38ms/step - loss: 1.4012e-05

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# 7) Evaluar el modelo DAE entrenado solicitando que reconstruya las imágenes ingresadas:

# %%
#@title Evaluar el modelo con las imágenes de entrenamiento

# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, cl, esDAimag):

  # evalua al modelo 
  resEval = DAEmodel.evaluate(x, x)
  print("\n>Evaluación del Modelo: ")
  print("    - Error: ", resEval)
  print("\n")

  # procesa las imágenes con el modelo 
  reconstr_imgs = DAEmodel.predict(x)

  # muestra las 15 primeras imágenes 
  print("\n>Resultados: ")
  for i in range(len(x)):
    # no muestra las generadas por DA
    if not esDAimag[i]:
          # prepara para mostrar
          fig = plt.figure()
          fig.suptitle(cl[i])

          # muestra la real
          ax1 = fig.add_subplot(121)
          plot_image(x[i])

          # muestra la generada por el modelo
          ax2 = fig.add_subplot(122)
          plot_image(reconstr_imgs[i])

          plt.tight_layout()
          fig = plt.gcf()


# prueba con los datos de entrenamiento
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, classes_train, esDAimag_train)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# 9) Probar el modelo DAE entrenado con otras imágenes:

# %%
#@title Evaluar el modelo con las imágenes de prueba

# prueba con los datos de prueba
print("*** Resultados con datos de Prueba: ")
probarModelo(x_test, classes_test, esDAimag_test)
# Out:
# *** Resultados con datos de Prueba:
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0614
#
# >Evaluación del Modelo:
#     - Error:  0.061381127685308456
#
#
#
# >Resultados:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [markdown]
# 8) A partir del modelo DAE entrenado, generar dos sub-modelos Encoder y Decoder:

# %% [markdown]
# *   Generar y usar el modelo Encoder para 'clusterizar' las imágenes de entrenamiento:

# %%
#@title Generar el sub-modelo Encoder para Clustering
## (desde input hasta features)

# reutiliza las capas entrenadas del modelo DAE original
clust_input_Lay = input_data_Lay  # capa de entrada
clust_output_Lay =  features_Lay  # capa de salida

# genera el modelo
CLUSTmodel = Model(input_data_Lay, features_Lay, name='Encoder/Clustering')

print("> Modelo Encoder: ")
CLUSTmodel.summary()
#plot_model(CLUSTmodel, show_layer_names=True, show_shapes=True)
# Out:
# > Modelo Encoder:
# Model: "Encoder/Clustering"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_data (InputLayer)     [(None, 12288)]           0
#
#  enc_1 (Dense)               (None, 6048)              74323872
#
#  enc_2 (Dense)               (None, 1024)              6194176
#
#  enc_3 (Dense)               (None, 256)               262400
#
#  enc_4 (Dense)               (None, 64)                16448
#
#  enc_5 (Dense)               (None, 24)                1560
#
#  features (Dense)            (None, 4)                 100
#
# =================================================================
# Total params: 80,798,556
# Trainable params: 80,798,556
# Non-trainable params: 0
# _________________________________________________________________

# %%
 #@title Generar Clustering
  # Muestra estadísticas y gráfico de los datos codificados

# determina datos a usar
usarDatos = 'Datos Entrenamiento' #@param ["Datos Entrenamiento", "Datos de Prueba"] {allow-input: false}
if usarDatos == 'Datos Entrenamiento':
  datosUsar_prep = x_train
  datosUsar_y = classes_train
else:
  datosUsar_prep = x_test
  datosUsar_y = classes_test

# genera matrix auxiliar para mostrar
CLASES = []
datosUsarNro_y = []
for y in datosUsar_y:
  if y in CLASES:
    aux = CLASES.index(y) 
  else:
    CLASES.append( y )
    aux = len(CLASES)-1
  datosUsarNro_y.append( aux )
     

# procesa los datos para recibir el valor codificado de cada una
x_encoded = CLUSTmodel.predict(datosUsar_prep)

# calcula estadisticas
minArClust = np.empty(num_features)
minArClust.fill(9999.99)
maxArClust = np.empty(num_features)
maxArClust.fill(-9999.99)
sumArClust = np.zeros(num_features)
for val in x_encoded:
  for i in range(num_features):
      sumArClust[i] = sumArClust[i]+val[i]
      if val[i]<minArClust[i]: 
          minArClust[i] = val[i]
      if val[i]>maxArClust[i]: 
          maxArClust[i] = val[i]
print("\n\n> Estadísticas de Clutering de Datos Originales codificado en ", num_features," valores: ")
print("- Mínimos:   ", minArClust)
print("- Máximos:   ", maxArClust)
print("- Totales:   ", sumArClust)
print("- Promedios: ", sumArClust/len(x_encoded))
print("\n\n")


if len(x_encoded)>0 and len(x_encoded[0])>0:
  
  import ipywidgets as widgets
  from ipywidgets import Box, Layout

  colValues = range(len(x_encoded[0]))

  # agrega los combos
  comboColX = widgets.Dropdown(
      options=colValues,
      value=colValues[0],
      description='Columna X:',
      disabled=False,
  )
  if len(colValues)>1:
    valYsel = colValues[1]
  else:
    valYsel = colValues[0]

  comboColY = widgets.Dropdown(
      options=colValues,
      value=valYsel,
      description='Columna Y:',
      disabled=False,
  )


  ui = widgets.HBox([comboColX, comboColY])

  import matplotlib.ticker as ticker
    
  def fmtClases(x, pos):
    return CLASES[int(x)]

  def cambiaSeleccion(x, y):
    # llama a la función 
    # para generar el gráfico con las columnas seleccionadas
    # muestra el gráfico codificado 
    plt.figure(figsize=(15, 8))
    plt.scatter(x_encoded[:,x], x_encoded[:,y], c=datosUsarNro_y, cmap='jet')
    plt.colorbar(format=ticker.FuncFormatter(fmtClases))    
    plt.grid(color='grey', which='major', axis='y', linestyle='solid', linewidth=0.3)
    plt.grid(color='grey', which='major', axis='x', linestyle='solid', linewidth=0.3)
    plt.title("Representación de Datos Clusterizados", fontsize = 20)
    plt.show()


  out = widgets.interactive_output(cambiaSeleccion, {'x': comboColX, 'y': comboColY})
  display(ui, out)
# Out:
# > Estadísticas de Clutering de Datos Originales codificado en  4  valores:
# - Mínimos:    [0. 0. 0. 0.]
# - Máximos:    [110.60359955 144.28700256   8.23867226 138.04029846]
# - Totales:    [3325.65115884 4476.08099908    8.23867226 3722.08161328]
# - Promedios:  [23.09479971 31.08389583  0.057213   25.84778898]
# HBox(children=(Dropdown(description='Columna X:', options=(0, 1, 2, 3), value=0), Dropdown(description='Column…
# Output()

# %% [markdown]
# *   Generar y usar el modelo Decoder para generar nuevas imágenes similares a las entrenadas:

# %%
#@title Generar el sub-modelo Decoder para Generator
## (desde features hasta output)

# genera una copia del modelo DAE original para evitar romperlo
auxiCloneModel = keras.models.model_from_json(DAEmodel.to_json())
#auxiCloneModel.summary()

# genera la nueva estructura del Generator
input_gen = Input(shape=(num_features,), name='input_gen') # nueva capa de entrada
auxLay_gen = input_gen
for pos in range(len(DAEmodel.layers)):

  # obtiene el nombre de la capa actual
  auxName = DAEmodel.layers[pos].name  
  
  # sólo considera las capas luego de features (decoder y output)
  # para copiar los pesos del DAE original y actualizar la estrcutura
  if auxName.startswith('dec_') or auxName=='output_data':
    auxiCloneModel.layers[pos].set_weights(DAEmodel.layers[pos].get_weights()) 
    auxLay_gen = auxiCloneModel.layers[pos](auxLay_gen) 

# crea el nuevo modelo Generator
GENmodel = Model(input_gen, auxLay_gen, name = 'Decoder/Generator')

print("> Modelo Decoder: ")
GENmodel.summary()
#plot_model(GENmodel, show_layer_names=True, show_shapes=True)
# Out:
# > Modelo Decoder:
# Model: "Decoder/Generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_gen (InputLayer)      [(None, 4)]               0
#
#  dec_5 (Dense)               (None, 24)                120
#
#  dec_4 (Dense)               (None, 64)                1600
#
#  dec_3 (Dense)               (None, 256)               16640
#
#  dec_2 (Dense)               (None, 1024)              263168
#
#  dec_1 (Dense)               (None, 6048)              6199200
#
#  output_data (Dense)         (None, 12288)             74330112
#
# =================================================================
# Total params: 80,810,840
# Trainable params: 80,810,840
# Non-trainable params: 0
# _________________________________________________________________

# %%
#@title Ejecutar el Generator
#  usando valores definidos al azar como datos de entrada
cantGenerar = 10 #@param {type:"integer"}

# genera los datos de entrada
# (como la codificación tiene varias posiciones con ceros 
# se considera que sólo se ponen al azar entre 10% y el 70% de los valores, el resto queda en cero,
# --sino se podría hacer con " np.random.rand(cantImagenGenerar, num_features) "-- )
arX = []
minRnd = 1
maxRnd = num_features
for i in range(cantGenerar):
  X = np.zeros(num_features)
  for j in range(np.random.randint(low=minRnd, high=maxRnd)):
      pos = np.random.randint(low=0, high=num_features-1)
      # si están definidas las estadisticas las usa, sino no
      if (minArClust is None or  maxArClust is None):
          X[pos] = np.random.uniform()    
      else:
          X[pos] = np.random.uniform(minArClust[pos], maxArClust[pos])              
      
  arX.append( X )


# ejecuta el modelo Generator
imagOut = GENmodel.predict( np.array(arX).reshape((len(arX), num_features)) )  
 
# muestra las imágenes generadas
print("\n> Resultados: ")
for i in range(len(arX)):

    fig = plt.figure()

    # muestra los datos
    ax1 = fig.add_subplot(121)
    datosMostrar = arX[i].reshape(num_features, 1) 
    ax1.table(cellText=datosMostrar, loc='center')   
    ax1.get_xaxis().set_visible(False)
    ax1.get_yaxis().set_visible(False)  

    #  muestra reconstrucción
    ax2 = fig.add_subplot(122)
    plot_image(imagOut[i])  

    plt.tight_layout()
    fig = plt.gcf()
# Out:
# > Resultados:

# %% [markdown]
# *   Combinar los resultados de los modelos Clustering y Generator para mostrar que funcionan juntos como el DAE original:

# %%
#@title Prueba el modelo Generator usando como entrada los datos de Clustering
pruebaClust = CLUSTmodel.predict( x_train )
pruebaClust_out = GENmodel.predict(  np.array(pruebaClust).reshape((len(pruebaClust), num_features)) )  
 
# muestra las imágenes generadas
print("\n> Resultados (valores de clustering, imagen recounstrida(grande) y original(chica): ")
for i in range(len(x_train)):

    # no muestra las generadas por DA
    if not esDAimag_train[i]:

        fig = plt.figure()

        # muestra los datos
        ax1 = fig.add_subplot(121)
        ax1.table(cellText=pruebaClust[i].reshape(num_features, 1), loc='center')   
        ax1.get_xaxis().set_visible(False)
        ax1.get_yaxis().set_visible(False)  

        #  muestra reconstrucción
        ax2 = fig.add_subplot(122)
        plot_image(pruebaClust_out[i])  

        # muestra imagen original
        ax3 = fig.add_subplot(332)
        plot_image(x_train[i])  

        fig = plt.gcf()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
